# %% [markdown]
# Copyright Jana Schaich Borg/Attribution-NonCommercial 4.0 International (CC BY-NC 4.0)

# %% [markdown]
# # MySQL Exercise 11: Queries that Test Relationships Between Test Completion and Dog Characteristics
#
# This lesson we are going to integrate all the SQL syntax we've learned so far to start addressing questions in our Dognition Analysis Plan.  I summarized the reasons having an analysis plan is so important in the "Start with an Analysis Plan" video accompanying this week's materials.  Analysis plans ensure that you will address questions that are relevant to your business objectives as quickly and efficiently as possible.  The quickest way to narrow in the factors in your analysis plan that are likely to create new insights is to combine simple SQL calculations with visualization programs, like Tableau, to identify which factors under consideration have the strongest effects on the business metric you are tasked with improving.  You can then design more nuanced statistical models in other software, such as R, based on the factors you have confirmed are likely to be important for understanding and changing your business metric.
#
# <img src="https://duke.box.com/shared/static/davndrvd4jb1awwuq6sd1rgt0ck4o8nm.jpg" width=400 alt="SELECT FROM WHERE ORDER BY" />
#
# I describe a method for designing analysis plans in the Data Visualization and Communication with Tableau course earlier in this Specialization.  I call that method Structured Pyramid Analysis Plans, or "sPAPs".  I have provided a skeleton of an sPAP for the Dognition data set with the materials for this course that I will use as a road map for the queries we will design and practice in the next two lessons.  To orient you, the SMART goal of the analysis project is at the top of the pyramid.  This is a specific, measurable, attainable, relevant, and time-bound version of the general project objective, which is to make a recommendation to Dognition about what they could do to increase the number of tests customers complete. The variables you will use to assess the goal should be filled out right under where the SMART goal is written.  Then under those variables, you will see ever-widening layers of categories and sub-categories of issues that will be important to analyze in order to achieve your SMART goal.
#
# In this lesson, we will write queries to address the issues in the left-most branch of the sPAP.  These issues all relate to "Features of Dogs" that could potentially influence the number of tests the dogs will ultimately complete.  We will spend a lot of time discussing and practicing how to translate analysis questions described in words into queries written in SQL syntax.
#
# To begin, load the sql library and database, and make the Dognition database your default database:

# %%
# %load_ext sql
# %sql mysql://studentuser:studentpw@localhost/dognitiondb
# %sql USE dognitiondb
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
#  * mysql://studentuser:***@localhost/dognitiondb
# 0 rows affected.
# []

# %% [markdown]
# <img src="https://duke.box.com/shared/static/p2eucjdttai08eeo7davbpfgqi3zrew0.jpg" width=600 alt="SELECT FROM WHERE" />
#
# ## 1. Assess whether Dognition personality dimensions are related to the number of tests completed
#
# The first variable in the Dognition sPAP we want to investigate is Dognition personality dimensions.  Recall from the "Meet Your Dognition Data" video and the written description of the Dognition Data Set included with the Week 2 materials that Dognition personality dimensions represent distinct combinations of characteristics assessed by the Dognition tests.  It is certainly plausible that certain personalities of dogs might be more or less likely to complete tests.  For example, "einstein" dogs might be particularly likely to complete a lot of tests.
#
# To test the relationship between Dognition personality dimensions and test completion totals, we need a query that will output a summary of the number of tests completed by dogs that have each of the Dognition personality dimensions.  The features you will need to include in your query are foreshadowed by key words in this sentence.  First, the fact that you need a summary of the number of tests completed suggests you will need an aggregation function.  Next, the fact that you want a different summary for each personality dimension suggests that you will need a GROUP BY clause.  Third, the fact that you need a "summary of the number of tests completed" rather than just a "summary of the tests completed" suggests that you might have to have multiple stages of aggegrations, which in turn might mean that you will need to use a subquery.
#
# Let's build the query step by step.
#
# **Question 1: To get a feeling for what kind of values exist in the Dognition personality dimension column, write a query that will output all of the distinct values in the dimension column.  Use your relational schema or the course materials to determine what table the dimension column is in.  Your output should have 11 rows.**

# %%
# %%sql
#
# select Distinct dimension
# from dogs;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 11 rows affected.
# [('charmer',),
#  ('protodog',),
#  (None,),
#  ('einstein',),
#  ('stargazer',),
#  ('maverick',),
#  ('socialite',),
#  ('ace',),
#  ('expert',),
#  ('renaissance-dog',),
#  ('',)]

# %% [markdown]
# The results of the query above illustrate there are NULL values (indicated by the output value "none") in the dimension column.  Keep that in mind in case it is relevant to future queries.
#
# We want a summary of the total number of tests completed by dogs with each personality dimension.  In order to calculate those summaries, we first need to calculate the total number of tests completed by each dog.  We can achieve this using a subquery.  The subquery will require data from both the dogs and the complete_tests table, so the subquery will need to include a join.  We are only interested in dogs who have completed tests, so an inner join is appropriate in this case.
#
# **Question 2: Use the equijoin syntax (described in MySQL Exercise 8) to write a query that will output the Dognition personality dimension and total number of tests completed by each unique DogID.  This query will be used as an inner subquery in the next question.  LIMIT your output to 100 rows for troubleshooting purposes.**

# %%
# %%sql
#
# select Distinct(d.dog_guid) as DogID, d.dimension, count(c.created_at) as numtests
# from dogs d, complete_tests c
# where d.dog_guid = c.dog_guid
# group by DogID
# limit 100
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 100 rows affected.
# [('fd27b272-7144-11e5-ba71-058fbc01cf0b', 'charmer', 21),
#  ('fd27b5ba-7144-11e5-ba71-058fbc01cf0b', 'protodog', 20),
#  ('fd27b6b4-7144-11e5-ba71-058fbc01cf0b', None, 2),
#  ('fd27b79a-7144-11e5-ba71-058fbc01cf0b', None, 11),
#  ('fd27b86c-7144-11e5-ba71-058fbc01cf0b', 'einstein', 31),
#  ('fd27b948-7144-11e5-ba71-058fbc01cf0b', 'stargazer', 20),
#  ('fd27ba1a-7144-11e5-ba71-058fbc01cf0b', 'maverick', 27),
#  ('fd27bbbe-7144-11e5-ba71-058fbc01cf0b', 'protodog', 20),
#  ('fd27c1c2-7144-11e5-ba71-058fbc01cf0b', 'einstein', 20),
#  ('fd27c5be-7144-11e5-ba71-058fbc01cf0b', 'socialite', 20),
#  ('fd27c74e-7144-11e5-ba71-058fbc01cf0b', None, 14),
#  ('fd27c7d0-7144-11e5-ba71-058fbc01cf0b', 'socialite', 20),
#  ('fd27c852-7144-11e5-ba71-058fbc01cf0b', 'stargazer', 20),
#  ('fd27c8d4-7144-11e5-ba71-058fbc01cf0b', 'ace', 20),
#  ('fd27c956-7144-11e5-ba71-058fbc01cf0b', None, 11),
#  ('fd27cb72-7144-11e5-ba71-058fbc01cf0b', 'protodog', 20),
#  ('fd27cd98-7144-11e5-ba71-058fbc01cf0b', 'expert', 20),
#  ('fd27ce1a-7144-11e5-ba71-058fbc01cf0b', None, 7),
#  ('fd27cea6-7144-11e5-ba71-058fbc01cf0b', None, 2),
#  ('fd27cf28-7144-11e5-ba71-058fbc01cf0b', 'charmer', 20),
#  ('fd27cfaa-7144-11e5-ba71-058fbc01cf0b', None, 7),
#  ('fd27d02c-7144-11e5-ba71-058fbc01cf0b', 'stargazer', 20),
#  ('fd27d0b8-7144-11e5-ba71-058fbc01cf0b', 'renaissance-dog', 21),
#  ('fd27d144-7144-11e5-ba71-058fbc01cf0b', None, 7),
#  ('fd27d1c6-7144-11e5-ba71-058fbc01cf0b', None, 7),
#  ('fd27d248-7144-11e5-ba71-058fbc01cf0b', None, 6),
#  ('fd27d2ca-7144-11e5-ba71-058fbc01cf0b', None, 4),
#  ('fd27d34c-7144-11e5-ba71-058fbc01cf0b', None, 4),
#  ('fd27d3d8-7144-11e5-ba71-058fbc01cf0b', None, 4),
#  ('fd27d45a-7144-11e5-ba71-058fbc01cf0b', 'stargazer', 28),
#  ('fd27d4dc-7144-11e5-ba71-058fbc01cf0b', 'maverick', 28),
#  ('fd27d770-7144-11e5-ba71-058fbc01cf0b', 'socialite', 25),
#  ('fd27d9fa-7144-11e5-ba71-058fbc01cf0b', 'einstein', 20),
#  ('fd27db08-7144-11e5-ba71-058fbc01cf0b', None, 14),
#  ('fd27db8a-7144-11e5-ba71-058fbc01cf0b', None, 16),
#  ('fd27dc52-7144-11e5-ba71-058fbc01cf0b', None, 2),
#  ('fd27dd38-7144-11e5-ba71-058fbc01cf0b', None, 4),
#  ('fd27e026-7144-11e5-ba71-058fbc01cf0b', None, 6),
#  ('fd27e0d0-7144-11e5-ba71-058fbc01cf0b', None, 6),
#  ('fd27e1e8-7144-11e5-ba71-058fbc01cf0b', 'charmer', 20),
#  ('fd27e31e-7144-11e5-ba71-058fbc01cf0b', 'socialite', 23),
#  ('fd27e454-7144-11e5-ba71-058fbc01cf0b', 'maverick', 45),
#  ('fd27e580-7144-11e5-ba71-058fbc01cf0b', 'stargazer', 33),
#  ('fd27e9a4-7144-11e5-ba71-058fbc01cf0b', 'protodog', 22),
#  ('fd27eae4-7144-11e5-ba71-058fbc01cf0b', None, 4),
#  ('fd27ed46-7144-11e5-ba71-058fbc01cf0b', 'maverick', 25),
#  ('fd27efb2-7144-11e5-ba71-058fbc01cf0b', 'einstein', 20),
#  ('fd27f110-7144-11e5-ba71-058fbc01cf0b', None, 7),
#  ('fd27f25a-7144-11e5-ba71-058fbc01cf0b', None, 6),
#  ('fd27f4c6-7144-11e5-ba71-058fbc01cf0b', None, 4),
#  ('fd27f732-7144-11e5-ba71-058fbc01cf0b', None, 4),
#  ('fd27f868-7144-11e5-ba71-058fbc01cf0b', None, 4),
#  ('fd27f9a8-7144-11e5-ba71-058fbc01cf0b', None, 3),
#  ('fd28010a-7144-11e5-ba71-058fbc01cf0b', None, 2),
#  ('fd280236-7144-11e5-ba71-058fbc01cf0b', None, 2),
#  ('fd280344-7144-11e5-ba71-058fbc01cf0b', None, 6),
#  ('fd280826-7144-11e5-ba71-058fbc01cf0b', None, 4),
#  ('fd2808b2-7144-11e5-ba71-058fbc01cf0b', None, 11),
#  ('fd28093e-7144-11e5-ba71-058fbc01cf0b', None, 2),
#  ('fd2809c0-7144-11e5-ba71-058fbc01cf0b', None, 4),
#  ('fd3ccd24-7144-11e5-ba71-058fbc01cf0b', None, 4),
#  ('fd3ccf2c-7144-11e5-ba71-058fbc01cf0b', 'einstein', 22),
#  ('fd3cd40e-7144-11e5-ba71-058fbc01cf0b', None, 10),
#  ('fd3cd4d6-7144-11e5-ba71-058fbc01cf0b', 'charmer', 20),
#  ('fd3cd8d2-7144-11e5-ba71-058fbc01cf0b', None, 7),
#  ('fd3cd99a-7144-11e5-ba71-058fbc01cf0b', 'renaissance-dog', 20),
#  ('fd3cec50-7144-11e5-ba71-058fbc01cf0b', None, 4),
#  ('fd3cf5c4-7144-11e5-ba71-058fbc01cf0b', None, 4),
#  ('fd3cf678-7144-11e5-ba71-058fbc01cf0b', None, 7),
#  ('fd3cf718-7144-11e5-ba71-058fbc01cf0b', None, 17),
#  ('fd3cf8ee-7144-11e5-ba71-058fbc01cf0b', 'protodog', 20),
#  ('fd3cf984-7144-11e5-ba71-058fbc01cf0b', None, 4),
#  ('fd3cfa1a-7144-11e5-ba71-058fbc01cf0b', None, 4),
#  ('fd3cfab0-7144-11e5-ba71-058fbc01cf0b', 'charmer', 38),
#  ('fd3cfcfe-7144-11e5-ba71-058fbc01cf0b', 'socialite', 20),
#  ('fd3cfd94-7144-11e5-ba71-058fbc01cf0b', 'expert', 20),
#  ('fd3cfe2a-7144-11e5-ba71-058fbc01cf0b', 'socialite', 20),
#  ('fd3cfeb6-7144-11e5-ba71-058fbc01cf0b', 'protodog', 20),
#  ('fd3cff4c-7144-11e5-ba71-058fbc01cf0b', 'charmer', 21),
#  ('fd3d0078-7144-11e5-ba71-058fbc01cf0b', None, 10),
#  ('fd3d01ae-7144-11e5-ba71-058fbc01cf0b', None, 11),
#  ('fd3d03fc-7144-11e5-ba71-058fbc01cf0b', None, 4),
#  ('fd3d0492-7144-11e5-ba71-058fbc01cf0b', None, 14),
#  ('fd3d05be-7144-11e5-ba71-058fbc01cf0b', None, 11),
#  ('fd3d064a-7144-11e5-ba71-058fbc01cf0b', None, 16),
#  ('fd3d06e0-7144-11e5-ba71-058fbc01cf0b', None, 16),
#  ('fd3d0776-7144-11e5-ba71-058fbc01cf0b', 'einstein', 20),
#  ('fd3d080c-7144-11e5-ba71-058fbc01cf0b', None, 4),
#  ('fd3d0898-7144-11e5-ba71-058fbc01cf0b', 'socialite', 45),
#  ('fd3d0938-7144-11e5-ba71-058fbc01cf0b', 'socialite', 20),
#  ('fd3d09ce-7144-11e5-ba71-058fbc01cf0b', 'ace', 20),
#  ('fd3d0b7c-7144-11e5-ba71-058fbc01cf0b', None, 7),
#  ('fd3d0c12-7144-11e5-ba71-058fbc01cf0b', None, 4),
#  ('fd3d0cb2-7144-11e5-ba71-058fbc01cf0b', None, 5),
#  ('fd3d0d48-7144-11e5-ba71-058fbc01cf0b', 'expert', 20),
#  ('fd3d0dde-7144-11e5-ba71-058fbc01cf0b', None, 14),
#  ('fd3d0f00-7144-11e5-ba71-058fbc01cf0b', 'expert', 20),
#  ('fd3d0f96-7144-11e5-ba71-058fbc01cf0b', 'socialite', 20),
#  ('fd3d102c-7144-11e5-ba71-058fbc01cf0b', 'charmer', 20),
#  ('fd3d10cc-7144-11e5-ba71-058fbc01cf0b', 'ace', 20)]

# %% [markdown]
# **Question 3: Re-write the query in Question 2 using traditional join syntax (described in MySQL Exercise 8).**

# %%
# %%sql
# select Distinct(d.dog_guid) as DogID, d.dimension, count(c.created_at) as numtests
# from dogs d join complete_tests c on d.dog_guid = c.dog_guid
# group by DogID
# limit 2;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 2 rows affected.
# [('fd27b272-7144-11e5-ba71-058fbc01cf0b', 'charmer', 21),
#  ('fd27b5ba-7144-11e5-ba71-058fbc01cf0b', 'protodog', 20)]

# %% [markdown]
# Now we need to summarize the total number of tests completed by each unique DogID within each Dognition personality dimension.  To do this we will need to choose an appropriate aggregation function for the count column of the query we just wrote.
#
# **Question 4: To start, write a query that will output the average number of tests completed by unique dogs in each Dognition personality dimension.  Choose either the query in Question 2 or 3 to serve as an inner query in your main query.  If you have trouble, make sure you use the appropriate aliases in your GROUP BY and SELECT statements.**

# %%
# %%sql
# select dimension, avg(numtests) as avg_numtests
# from (select Distinct(d.dog_guid) as DogID, d.dimension, count(c.created_at) as numtests
# from dogs d, complete_tests c
# where d.dog_guid = c.dog_guid
# group by DogID) as total_tests
# group by dimension
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 11 rows affected.
# [(None, Decimal('6.9416')),
#  ('', Decimal('9.5352')),
#  ('ace', Decimal('23.3878')),
#  ('charmer', Decimal('23.2594')),
#  ('einstein', Decimal('23.2171')),
#  ('expert', Decimal('23.3926')),
#  ('maverick', Decimal('22.8199')),
#  ('protodog', Decimal('22.9336')),
#  ('renaissance-dog', Decimal('23.0157')),
#  ('socialite', Decimal('23.1194')),
#  ('stargazer', Decimal('22.7368'))]

# %% [markdown]
# You should retrieve an output of 11 rows with one of the dimensions labeled "None" and another labeled "" (nothing is between the quotation marks).
#
# **Question 5: How many unique DogIDs are summarized in the Dognition dimensions labeled "None" or ""? (You should retrieve values of 13,705 and 71)**

# %%
# %%sql
# select dimension, count(DogID)
# from (select Distinct(d.dog_guid) as DogID, d.dimension, count(c.created_at) as numtests
# from dogs d, complete_tests c
# where d.dog_guid = c.dog_guid
# group by DogID) as total_tests
# group by dimension
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 11 rows affected.
# [(None, 13705),
#  ('', 71),
#  ('ace', 477),
#  ('charmer', 690),
#  ('einstein', 129),
#  ('expert', 298),
#  ('maverick', 272),
#  ('protodog', 602),
#  ('renaissance-dog', 510),
#  ('socialite', 871),
#  ('stargazer', 361)]

# %% [markdown]
# It makes sense there would be many dogs with NULL values in the dimension column, because we learned from Dognition that personality dimensions can only be assigned after the initial "Dognition Assessment" is completed, which is comprised of the first 20 Dognition tests.  If dogs did not complete the first 20 tests, they would retain a NULL value in the dimension column.
#
# The non-NULL empty string values are more curious.  It is not clear where those values would come from.
#
# **Question 6: To determine whether there are any features that are common to all dogs that have non-NULL empty strings in the dimension column, write a query that outputs the breed, weight, value in the "exclude" column, first or minimum time stamp in the complete_tests table, last or maximum time stamp in the complete_tests table, and total number of tests completed by each unique DogID that has a non-NULL empty string in the dimension column.**

# %%
# %%sql
#
# select d.dog_guid, d.breed, d.weight, d.exclude, d.dimension, min(c.created_at) as first, max(c.created_at) as last,
# count(c.created_at) as numtests
# from dogs d, complete_tests c
# where d.dimension='' and d.dog_guid = c.dog_guid
# group by d.dog_guid
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 71 rows affected.
# [('fd45154c-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 30, 0, '', datetime.datetime(2013, 5, 23, 7, 6, 21), datetime.datetime(2013, 7, 2, 12, 15, 18), 17),
#  ('fd51daac-7144-11e5-ba71-058fbc01cf0b', 'Dachshund', 10, 1, '', datetime.datetime(2014, 10, 21, 18, 53, 2), datetime.datetime(2014, 10, 21, 19, 10, 7), 3),
#  ('fd5d7d3a-7144-11e5-ba71-058fbc01cf0b', 'Border Collie-Labrador Retriever Mix', 50, 0, '', datetime.datetime(2013, 11, 16, 2, 26, 15), datetime.datetime(2013, 11, 16, 2, 38, 57), 4),
#  ('fd680124-7144-11e5-ba71-058fbc01cf0b', 'Belgian Tervuren', 70, 1, '', datetime.datetime(2014, 11, 10, 21, 21, 6), datetime.datetime(2014, 12, 16, 1, 13, 28), 13),
#  ('fd699c28-7144-11e5-ba71-058fbc01cf0b', 'Pembroke Welsh Corgi', 20, 1, '', datetime.datetime(2014, 9, 19, 17, 42, 37), datetime.datetime(2014, 9, 22, 17, 58, 25), 4),
#  ('fd6a7774-7144-11e5-ba71-058fbc01cf0b', 'Chihuahua', 0, 1, '', datetime.datetime(2014, 10, 6, 0, 57, 46), datetime.datetime(2014, 10, 9, 22, 55, 51), 2),
#  ('fd6bf766-7144-11e5-ba71-058fbc01cf0b', 'Australian Shepherd', 50, 1, '', datetime.datetime(2014, 10, 6, 1, 54, 49), datetime.datetime(2014, 10, 30, 2, 16, 12), 14),
#  ('fd6cfd96-7144-11e5-ba71-058fbc01cf0b', 'Mixed', 60, 1, '', datetime.datetime(2014, 10, 10, 1, 1, 21), datetime.datetime(2014, 10, 10, 12, 33, 52), 4),
#  ('fd6d1182-7144-11e5-ba71-058fbc01cf0b', 'Portuguese Water Dog', 60, 1, '', datetime.datetime(2014, 10, 10, 13, 22, 58), datetime.datetime(2014, 10, 10, 13, 36, 17), 3),
#  ('fd6d1ea2-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 50, 1, '', datetime.datetime(2014, 10, 6, 15, 28, 42), datetime.datetime(2014, 10, 23, 20, 24, 20), 7),
#  ('fd6d6718-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 70, 1, '', datetime.datetime(2014, 10, 6, 17, 27, 41), datetime.datetime(2014, 12, 10, 1, 35, 43), 14),
#  ('fd6e0286-7144-11e5-ba71-058fbc01cf0b', 'Poodle', 50, 1, '', datetime.datetime(2014, 10, 9, 5, 29, 7), datetime.datetime(2014, 11, 3, 3, 10, 19), 16),
#  ('fd6e28e2-7144-11e5-ba71-058fbc01cf0b', 'Other', 30, 1, '', datetime.datetime(2014, 10, 21, 2, 5, 28), datetime.datetime(2014, 10, 21, 2, 12, 10), 2),
#  ('fd6e94d0-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 70, 1, '', datetime.datetime(2014, 10, 7, 2, 4, 42), datetime.datetime(2014, 10, 23, 2, 6, 2), 10),
#  ('fd6ef2cc-7144-11e5-ba71-058fbc01cf0b', 'West Highland White Terrier', 10, 1, '', datetime.datetime(2014, 10, 7, 13, 7, 18), datetime.datetime(2014, 10, 11, 21, 57, 57), 19),
#  ('fd6efce0-7144-11e5-ba71-058fbc01cf0b', 'Brittany', 30, 1, '', datetime.datetime(2014, 10, 12, 18, 9), datetime.datetime(2015, 1, 4, 20, 38, 26), 11),
#  ('fd6f5c4e-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 50, 1, '', datetime.datetime(2014, 10, 7, 16, 58, 19), datetime.datetime(2014, 10, 8, 15, 56, 42), 4),
#  ('fd6f6c84-7144-11e5-ba71-058fbc01cf0b', 'Miniature Schnauzer', 10, 1, '', datetime.datetime(2014, 10, 16, 20, 42, 50), datetime.datetime(2014, 10, 21, 17, 29, 14), 6),
#  ('fd6f7260-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu-Bichon Frise Mix', 10, 1, '', datetime.datetime(2014, 10, 8, 22, 48, 34), datetime.datetime(2015, 3, 8, 18, 33, 37), 17),
#  ('fd6f790e-7144-11e5-ba71-058fbc01cf0b', 'Mixed', 30, 1, '', datetime.datetime(2014, 10, 18, 14, 0, 16), datetime.datetime(2014, 10, 25, 14, 18, 48), 16),
#  ('fd702b7e-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 10, 1, '', datetime.datetime(2014, 10, 9, 1, 18, 26), datetime.datetime(2014, 11, 11, 1, 39, 17), 19),
#  ('fd7039a2-7144-11e5-ba71-058fbc01cf0b', 'Mixed', 60, 1, '', datetime.datetime(2014, 10, 16, 11, 5, 12), datetime.datetime(2014, 10, 25, 13, 47, 46), 12),
#  ('fd7040a0-7144-11e5-ba71-058fbc01cf0b', 'Collie-Golden Retriever Mix', 40, 1, '', datetime.datetime(2014, 10, 8, 18, 57, 6), datetime.datetime(2014, 10, 10, 20, 22, 20), 15),
#  ('fd70a7de-7144-11e5-ba71-058fbc01cf0b', 'Mixed', 40, 1, '', datetime.datetime(2014, 10, 10, 11, 51, 24), datetime.datetime(2014, 12, 1, 13, 41, 37), 19),
#  ('fd70ad42-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 190, 1, '', datetime.datetime(2014, 10, 9, 17, 42, 21), datetime.datetime(2014, 10, 9, 17, 48, 4), 5),
#  ('fd70d43e-7144-11e5-ba71-058fbc01cf0b', 'Bichon Frise-Poodle Mix', 10, 1, '', datetime.datetime(2014, 10, 18, 22, 55, 21), datetime.datetime(2014, 12, 2, 23, 8, 20), 12),
#  ('fd70e924-7144-11e5-ba71-058fbc01cf0b', 'Mixed', 30, 1, '', datetime.datetime(2014, 10, 13, 23, 45, 26), datetime.datetime(2015, 4, 3, 10, 58, 59), 8),
#  ('fd70fd2e-7144-11e5-ba71-058fbc01cf0b', 'Australian Shepherd-Australian Cattle Dog Mix', 40, 1, '', datetime.datetime(2014, 10, 12, 6, 24, 53), datetime.datetime(2014, 10, 24, 7, 47, 32), 7),
#  ('fd719e14-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 10, 1, '', datetime.datetime(2014, 10, 11, 18, 27, 25), datetime.datetime(2014, 10, 11, 19, 33, 14), 7),
#  ('fd71a292-7144-11e5-ba71-058fbc01cf0b', 'Norwegian Elkhound', 50, 1, '', datetime.datetime(2014, 10, 11, 18, 52, 21), datetime.datetime(2014, 10, 19, 21, 52, 3), 11),
#  ('fd7200e8-7144-11e5-ba71-058fbc01cf0b', 'Golden Doodle', 50, 1, '', datetime.datetime(2014, 10, 12, 16, 7, 21), datetime.datetime(2014, 11, 1, 17, 20, 7), 16),
#  ('fd7209ee-7144-11e5-ba71-058fbc01cf0b', 'Miniature Schnauzer', 10, 1, '', datetime.datetime(2014, 10, 12, 18, 0, 27), datetime.datetime(2014, 10, 22, 23, 46, 24), 12),
#  ('fd722ae6-7144-11e5-ba71-058fbc01cf0b', 'Chow Chow-Labrador Retriever Mix', 160, 1, '', datetime.datetime(2014, 10, 12, 23, 37, 23), datetime.datetime(2014, 10, 16, 15, 41, 43), 7),
#  ('fd724670-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 50, 1, '', datetime.datetime(2014, 10, 13, 15, 30, 26), datetime.datetime(2014, 10, 15, 4, 23, 56), 7),
#  ('fd72dc20-7144-11e5-ba71-058fbc01cf0b', 'Mixed', 0, 1, '', datetime.datetime(2014, 10, 16, 13, 52, 40), datetime.datetime(2014, 12, 19, 21, 29, 15), 7),
#  ('fd72e490-7144-11e5-ba71-058fbc01cf0b', 'Karelian Bear Dog', 10, 0, '', datetime.datetime(2014, 11, 7, 13, 4, 1), datetime.datetime(2015, 7, 11, 16, 58, 35), 6),
#  ('fd72e79c-7144-11e5-ba71-058fbc01cf0b', 'Shetland Sheepdog', 10, 1, '', datetime.datetime(2014, 10, 16, 16, 53, 38), datetime.datetime(2014, 10, 18, 17, 21, 41), 16),
#  ('fd72f048-7144-11e5-ba71-058fbc01cf0b', 'Brittany', 40, 1, '', datetime.datetime(2014, 11, 10, 21, 57, 8), datetime.datetime(2015, 5, 3, 22, 24, 56), 16),
#  ('fd730d94-7144-11e5-ba71-058fbc01cf0b', 'Flat-Coated Retriever', 60, 1, '', datetime.datetime(2014, 10, 17, 3, 59, 18), datetime.datetime(2014, 10, 18, 14, 6, 50), 12),
#  ('fd737b44-7144-11e5-ba71-058fbc01cf0b', 'American Staffordshire Terrier', 60, 1, '', datetime.datetime(2014, 10, 21, 0, 17, 3), datetime.datetime(2014, 11, 29, 17, 35, 30), 17),
#  ('fd738710-7144-11e5-ba71-058fbc01cf0b', 'Rottweiler', 30, 1, '', datetime.datetime(2014, 10, 19, 18, 52, 8), datetime.datetime(2014, 10, 20, 23, 4, 14), 8),
#  ('fd73b53c-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 190, 1, '', datetime.datetime(2014, 10, 21, 19, 24, 18), datetime.datetime(2014, 10, 21, 19, 37, 54), 9),
#  ('fd73fbfa-7144-11e5-ba71-058fbc01cf0b', 'Ibizan Hound-Greyhound Mix', 50, 1, '', datetime.datetime(2014, 10, 27, 21, 24, 56), datetime.datetime(2014, 11, 9, 21, 32, 19), 13),
#  ('fd744fe2-7144-11e5-ba71-058fbc01cf0b', 'Mixed', 40, 1, '', datetime.datetime(2014, 10, 26, 18, 47, 56), datetime.datetime(2015, 5, 11, 21, 5, 1), 15),
#  ('fd74b84c-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 90, 1, '', datetime.datetime(2014, 11, 1, 8, 54, 40), datetime.datetime(2015, 2, 5, 4, 59, 26), 7),
#  ('fd74c602-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 100, 1, '', datetime.datetime(2015, 1, 29, 3, 23, 32), datetime.datetime(2015, 2, 10, 3, 14, 8), 11),
#  ('fd754cd0-7144-11e5-ba71-058fbc01cf0b', 'Mixed', 30, 1, '', datetime.datetime(2014, 11, 10, 0, 12, 10), datetime.datetime(2014, 11, 23, 21, 48, 17), 3),
#  ('fd75c55c-7144-11e5-ba71-058fbc01cf0b', 'American Staffordshire Terrier-Whippet Mix', 40, 1, '', datetime.datetime(2014, 11, 12, 2, 11, 45), datetime.datetime(2014, 11, 20, 16, 36, 38), 4),
#  ('fd76286c-7144-11e5-ba71-058fbc01cf0b', 'Australian Shepherd-Border Collie Mix', 30, 1, '', datetime.datetime(2014, 11, 16, 0, 29, 35), datetime.datetime(2014, 12, 3, 20, 44, 14), 4),
#  ('fd76bef8-7144-11e5-ba71-058fbc01cf0b', 'Mixed', 60, 1, '', datetime.datetime(2014, 11, 27, 16, 58, 49), datetime.datetime(2014, 11, 27, 17, 6, 1), 3),
#  ('fd76c27c-7144-11e5-ba71-058fbc01cf0b', 'Rottweiler-Labrador Retriever Mix', 80, 1, '', datetime.datetime(2014, 11, 27, 2, 0, 54), datetime.datetime(2014, 11, 27, 17, 3, 25), 4),
#  ('fd76d35c-7144-11e5-ba71-058fbc01cf0b', 'Australian Shepherd', 40, 1, '', datetime.datetime(2014, 11, 30, 4, 58, 36), datetime.datetime(2014, 12, 10, 16, 33, 40), 11),
#  ('fd7710b0-7144-11e5-ba71-058fbc01cf0b', 'Redbone Coonhound', 60, 1, '', datetime.datetime(2014, 11, 30, 23, 17, 20), datetime.datetime(2014, 12, 1, 22, 47, 3), 4),
#  ('fd771542-7144-11e5-ba71-058fbc01cf0b', 'Border Collie', 40, 1, '', datetime.datetime(2014, 12, 1, 13, 15, 43), datetime.datetime(2014, 12, 1, 13, 32, 40), 4),
#  ('fd7b0c38-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 20, 1, '', datetime.datetime(2015, 2, 16, 20, 0, 4), datetime.datetime(2015, 2, 19, 6, 10, 30), 4),
#  ('fd7bc9c0-7144-11e5-ba71-058fbc01cf0b', 'Shetland Sheepdog', 30, 0, '', datetime.datetime(2015, 4, 11, 17, 42, 12), datetime.datetime(2015, 5, 6, 14, 18, 3), 18),
#  ('fd7cab74-7144-11e5-ba71-058fbc01cf0b', 'Mixed', 10, 0, '', datetime.datetime(2015, 5, 20, 23, 19, 5), datetime.datetime(2015, 7, 12, 17, 35, 11), 15),
#  ('fd7e0f32-7144-11e5-ba71-058fbc01cf0b', 'Doberman Pinscher-Rottweiler Mix', 70, 1, '', datetime.datetime(2015, 5, 26, 16, 7, 21), datetime.datetime(2015, 5, 26, 16, 7, 21), 1),
#  ('fd7ea564-7144-11e5-ba71-058fbc01cf0b', 'English Springer Spaniel', 40, 1, '', datetime.datetime(2015, 5, 16, 21, 24, 4), datetime.datetime(2015, 5, 16, 22, 13, 23), 12),
#  ('fd80b836-7144-11e5-ba71-058fbc01cf0b', "I Don't Know", 0, 0, '', datetime.datetime(2015, 5, 19, 23, 28, 44), datetime.datetime(2015, 5, 20, 2, 34, 48), 16),
#  ('fd8193c8-7144-11e5-ba71-058fbc01cf0b', 'Mixed', 100, 1, '', datetime.datetime(2015, 7, 1, 17, 17, 51), datetime.datetime(2015, 7, 1, 18, 2, 26), 14),
#  ('fd8942a8-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever-Poodle Mix', 70, 1, '', datetime.datetime(2015, 5, 29, 13, 45, 39), datetime.datetime(2015, 5, 29, 16, 3, 43), 6),
#  ('fd89f112-7144-11e5-ba71-058fbc01cf0b', 'Italian Greyhound-Miniature Pinscher Mix', 0, 0, '', datetime.datetime(2015, 6, 2, 22, 44, 2), datetime.datetime(2015, 6, 15, 19, 38, 53), 14),
#  ('fda99508-7144-11e5-ba71-058fbc01cf0b', 'Mixed', 50, 1, '', datetime.datetime(2015, 6, 14, 1, 50, 27), datetime.datetime(2015, 6, 14, 1, 53, 58), 4),
#  ('fda9dac2-7144-11e5-ba71-058fbc01cf0b', "I Don't Know", 30, 1, '', datetime.datetime(2015, 6, 28, 17, 43, 10), datetime.datetime(2015, 7, 17, 23, 42, 10), 14),
#  ('fdaab834-7144-11e5-ba71-058fbc01cf0b', 'Mixed', 40, 1, '', datetime.datetime(2015, 6, 16, 23, 47, 21), datetime.datetime(2015, 6, 18, 23, 28, 35), 3),
#  ('fdabbefa-7144-11e5-ba71-058fbc01cf0b', 'Australian Labradoodle', 20, 1, '', datetime.datetime(2015, 7, 7, 3, 18, 50), datetime.datetime(2015, 7, 7, 3, 51, 1), 11),
#  ('fdabf672-7144-11e5-ba71-058fbc01cf0b', 'Mixed', 30, 0, '', datetime.datetime(2015, 6, 16, 23, 58, 36), datetime.datetime(2015, 6, 25, 23, 21, 39), 7),
#  ('fdadfad0-7144-11e5-ba71-058fbc01cf0b', 'Golden Doodle', 20, 1, '', datetime.datetime(2015, 6, 20, 14, 43, 54), datetime.datetime(2015, 8, 11, 3, 32, 16), 13),
#  ('fdae85b8-7144-11e5-ba71-058fbc01cf0b', 'Bichon Frise', 10, 1, '', datetime.datetime(2015, 6, 24, 14, 40, 3), datetime.datetime(2015, 6, 24, 14, 50, 17), 6),
#  ('fdbc1692-7144-11e5-ba71-058fbc01cf0b', "I Don't Know", 20, 0, '', datetime.datetime(2015, 10, 3, 18, 22, 6), datetime.datetime(2015, 10, 3, 18, 28, 19), 2)]

# %% [markdown]
# A quick inspection of the output from the last query illustrates that almost all of the entries that have non-NULL empty strings in the dimension column also have "exclude" flags of 1, meaning that the entries are meant to be excluded due to factors monitored by the Dognition team.  This provides a good argument for excluding the entire category of entries that have non-NULL empty strings in the dimension column from our analyses.
#
# **Question 7: Rewrite the query in Question 4 to exclude DogIDs with (1) non-NULL empty strings in the dimension column, (2) NULL values in the dimension column, and (3) values of "1" in the exclude column.  NOTES AND HINTS: You cannot use a clause that says d.exclude does not equal 1 to remove rows that have exclude flags, because Dognition clarified that both NULL values and 0 values in the "exclude" column are valid data.  A clause that says you should only include values that are not equal to 1 would remove the rows that have NULL values in the exclude column, because NULL values are never included in equals statements (as we learned in the join lessons).  In addition, although it should not matter for this query, practice including parentheses with your OR and AND statements that accurately reflect the logic you intend.  Your results should return 402 DogIDs in the ace dimension and 626 dogs in the charmer dimension.**

# %%
# %%sql
# select dimension, avg(total_tests.numtests) as avg_numtests, count(DISTINCT DogID)
# from (  select d.dog_guid as DogID, d.dimension, count(c.created_at) as numtests
#         from dogs d join complete_tests c on d.dog_guid = c.dog_guid
#         where (dimension IS NOT NULL and dimension!='') and (d.exclude=0)
#         group by DogID)
#     as total_tests
# group by dimension
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 9 rows affected.
# [('ace', Decimal('24.6471'), 17),
#  ('charmer', Decimal('24.2308'), 13),
#  ('einstein', Decimal('25.6667'), 15),
#  ('expert', Decimal('25.6429'), 14),
#  ('maverick', Decimal('23.0588'), 17),
#  ('protodog', Decimal('24.7692'), 13),
#  ('renaissance-dog', Decimal('25.6667'), 21),
#  ('socialite', Decimal('26.0588'), 17),
#  ('stargazer', Decimal('24.0000'), 16)]

# %% [markdown]
# The results of Question 7 suggest there are not appreciable differences in the number of tests completed by dogs with different Dognition personality dimensions.  Although these analyses are not definitive on their own, these results suggest focusing on Dognition personality dimensions will not likely lead to significant insights about how to improve Dognition completion rates.
#
#
#
# ## 2. Assess whether dog breeds are related to the number of tests completed
#
# The next variable in the Dognition sPAP we want to investigate is Dog Breed.  We will run one analysis with Breed Group and one analysis with Breed Type.
#
# First, determine how many distinct breed groups there are.
#
# **Questions 8: Write a query that will output all of the distinct values in the breed_group field.**

# %%
# %%sql
#
# select DISTINCT(breed_group)
# from dogs
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 9 rows affected.
# [('Sporting',),
#  ('Herding',),
#  ('Toy',),
#  ('Working',),
#  (None,),
#  ('Hound',),
#  ('Non-Sporting',),
#  ('Terrier',),
#  ('',)]

# %% [markdown]
# You can see that there are NULL values in the breed_group field.  Let's examine the properties of these entries with NULL values to determine whether they should be excluded from our analysis.
#
# **Question 9: Write a query that outputs the breed, weight, value in the "exclude" column, first or minimum time stamp in the complete_tests table, last or maximum time stamp in the complete_tests table, and total number of tests completed by each unique DogID that has a NULL value in the breed_group column.**

# %%
# %%sql
#
# select d.dog_guid, d.breed, d.weight, d.exclude, min(c.created_at) as first_test, max(c.created_at) as last_test, count(c.created_at) as numtests
# from dogs d, complete_tests c
# where d.dog_guid = c.dog_guid and (d.breed_group is not NULL)
# group by d.dog_guid
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 9170 rows affected.
# [('fd27b272-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 50, None, datetime.datetime(2013, 2, 10, 1, 14, 3), datetime.datetime(2014, 8, 28, 1, 45, 2), 21),
#  ('fd27b5ba-7144-11e5-ba71-058fbc01cf0b', 'Shetland Sheepdog', 20, None, datetime.datetime(2013, 2, 5, 22, 23, 49), datetime.datetime(2013, 2, 13, 18, 51, 54), 20),
#  ('fd27b6b4-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 70, None, datetime.datetime(2013, 2, 8, 1, 26, 18), datetime.datetime(2013, 2, 8, 1, 39, 27), 2),
#  ('fd27b79a-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 70, None, datetime.datetime(2013, 2, 28, 16, 7, 37), datetime.datetime(2014, 9, 12, 19, 46, 12), 11),
#  ('fd27b86c-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 190, 1, datetime.datetime(2013, 2, 5, 18, 26, 54), datetime.datetime(2013, 9, 25, 19, 6, 41), 31),
#  ('fd27b948-7144-11e5-ba71-058fbc01cf0b', 'Siberian Husky', 60, None, datetime.datetime(2013, 2, 5, 21, 58, 19), datetime.datetime(2013, 2, 9, 7, 24, 28), 20),
#  ('fd27ba1a-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 190, 1, datetime.datetime(2013, 2, 5, 20, 35, 47), datetime.datetime(2013, 7, 16, 19, 31, 28), 27),
#  ('fd27c1c2-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 70, None, datetime.datetime(2013, 2, 7, 4, 41, 21), datetime.datetime(2013, 2, 20, 4, 38, 27), 20),
#  ('fd27c7d0-7144-11e5-ba71-058fbc01cf0b', 'Vizsla', 60, None, datetime.datetime(2013, 2, 6, 3, 55, 52), datetime.datetime(2013, 2, 6, 6, 23), 20),
#  ('fd27c852-7144-11e5-ba71-058fbc01cf0b', 'Pug', 20, None, datetime.datetime(2013, 2, 5, 23, 35, 48), datetime.datetime(2013, 2, 6, 23, 5, 10), 20),
#  ('fd27c8d4-7144-11e5-ba71-058fbc01cf0b', 'Boxer', 50, None, datetime.datetime(2013, 2, 5, 23, 54, 40), datetime.datetime(2013, 2, 9, 0, 13, 4), 20),
#  ('fd27cb72-7144-11e5-ba71-058fbc01cf0b', 'Beagle', 40, None, datetime.datetime(2013, 2, 18, 17, 13, 39), datetime.datetime(2013, 3, 30, 21, 2, 23), 20),
#  ('fd27cd98-7144-11e5-ba71-058fbc01cf0b', 'Beagle', 30, None, datetime.datetime(2013, 2, 10, 16, 56, 35), datetime.datetime(2013, 2, 17, 1, 53, 26), 20),
#  ('fd27ce1a-7144-11e5-ba71-058fbc01cf0b', 'Beagle', 20, None, datetime.datetime(2013, 3, 17, 19, 12, 35), datetime.datetime(2013, 3, 17, 19, 36, 55), 7),
#  ('fd27cf28-7144-11e5-ba71-058fbc01cf0b', 'Chesapeake Bay Retriever', 60, None, datetime.datetime(2013, 2, 6, 2, 39, 41), datetime.datetime(2013, 3, 27, 3, 47, 10), 20),
#  ('fd27cfaa-7144-11e5-ba71-058fbc01cf0b', 'Border Collie', 40, None, datetime.datetime(2013, 2, 7, 2, 2, 41), datetime.datetime(2013, 2, 21, 2, 32, 43), 7),
#  ('fd27d02c-7144-11e5-ba71-058fbc01cf0b', 'Belgian Malinois', 20, None, datetime.datetime(2013, 2, 6, 13, 47, 7), datetime.datetime(2013, 2, 9, 16, 5, 14), 20),
#  ('fd27d144-7144-11e5-ba71-058fbc01cf0b', 'Poodle', 50, None, datetime.datetime(2014, 4, 26, 16, 2, 1), datetime.datetime(2014, 9, 20, 17, 29, 57), 7),
#  ('fd27d1c6-7144-11e5-ba71-058fbc01cf0b', 'Poodle', 40, 1, datetime.datetime(2014, 4, 26, 22, 20, 49), datetime.datetime(2014, 9, 20, 17, 39, 43), 7),
#  ('fd27d2ca-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 80, None, datetime.datetime(2015, 7, 31, 3, 46, 57), datetime.datetime(2015, 7, 31, 4, 0, 31), 4),
#  ('fd27d34c-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 20, None, datetime.datetime(2013, 9, 1, 10, 12, 39), datetime.datetime(2013, 9, 1, 10, 28, 18), 4),
#  ('fd27d3d8-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 30, None, datetime.datetime(2013, 9, 1, 10, 45, 43), datetime.datetime(2013, 9, 1, 10, 51, 24), 4),
#  ('fd27d45a-7144-11e5-ba71-058fbc01cf0b', 'Weimaraner', 80, None, datetime.datetime(2013, 2, 10, 3, 50, 5), datetime.datetime(2013, 7, 20, 2, 21, 33), 28),
#  ('fd27d770-7144-11e5-ba71-058fbc01cf0b', 'Bouvier des Flandres', 60, 1, datetime.datetime(2013, 2, 10, 15, 10, 37), datetime.datetime(2013, 5, 15, 0, 11, 1), 25),
#  ('fd27db08-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 80, None, datetime.datetime(2013, 2, 6, 18, 12, 5), datetime.datetime(2013, 2, 8, 16, 0, 54), 14),
#  ('fd27db8a-7144-11e5-ba71-058fbc01cf0b', 'Beagle', 10, None, datetime.datetime(2013, 2, 9, 6, 32, 20), datetime.datetime(2013, 2, 11, 3, 35, 37), 16),
#  ('fd27e026-7144-11e5-ba71-058fbc01cf0b', 'Dalmatian', 20, None, datetime.datetime(2013, 2, 6, 21, 56, 44), datetime.datetime(2013, 2, 6, 22, 35, 27), 6),
#  ('fd27e1e8-7144-11e5-ba71-058fbc01cf0b', 'Border Collie-Labrador Retriever Mix', 40, None, datetime.datetime(2013, 2, 11, 15, 49, 57), datetime.datetime(2013, 2, 22, 12, 59, 46), 20),
#  ('fd27e31e-7144-11e5-ba71-058fbc01cf0b', 'Belgian Tervuren', 20, None, datetime.datetime(2013, 2, 11, 16, 30, 8), datetime.datetime(2013, 3, 31, 15, 11, 1), 23),
#  ('fd27e580-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 70, None, datetime.datetime(2013, 2, 10, 4, 24, 55), datetime.datetime(2014, 2, 17, 4, 54, 23), 33),
#  ('fd27e9a4-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 190, 1, datetime.datetime(2013, 3, 22, 16, 13, 32), datetime.datetime(2013, 7, 16, 19, 37, 33), 22),
#  ('fd27eae4-7144-11e5-ba71-058fbc01cf0b', 'Australian Terrier', 10, None, datetime.datetime(2013, 2, 7, 0, 57), datetime.datetime(2013, 2, 7, 1, 17, 1), 4),
#  ('fd27ed46-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 190, 1, datetime.datetime(2013, 2, 6, 20, 14, 43), datetime.datetime(2013, 5, 21, 15, 37, 58), 25),
#  ('fd27efb2-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 80, None, datetime.datetime(2013, 2, 7, 2, 50, 52), datetime.datetime(2013, 2, 8, 2, 52, 4), 20),
#  ('fd27f110-7144-11e5-ba71-058fbc01cf0b', 'Bernese Mountain Dog', 100, None, datetime.datetime(2013, 2, 7, 4, 32, 59), datetime.datetime(2014, 5, 25, 20, 25, 18), 7),
#  ('fd27f4c6-7144-11e5-ba71-058fbc01cf0b', 'Shetland Sheepdog', 10, None, datetime.datetime(2013, 3, 7, 15, 15, 35), datetime.datetime(2013, 3, 7, 15, 37, 53), 4),
#  ('fd27f732-7144-11e5-ba71-058fbc01cf0b', 'Shetland Sheepdog', 10, None, datetime.datetime(2013, 3, 7, 15, 22, 56), datetime.datetime(2013, 3, 7, 15, 47, 13), 4),
#  ('fd28010a-7144-11e5-ba71-058fbc01cf0b', 'Finnish Spitz', 20, None, datetime.datetime(2013, 3, 3, 3, 4, 6), datetime.datetime(2013, 3, 3, 3, 10, 50), 2),
#  ('fd280236-7144-11e5-ba71-058fbc01cf0b', 'Siberian Husky', 50, None, datetime.datetime(2013, 2, 11, 14, 37, 32), datetime.datetime(2013, 2, 11, 15, 18, 20), 2),
#  ('fd280344-7144-11e5-ba71-058fbc01cf0b', 'Rottweiler', 80, None, datetime.datetime(2013, 2, 9, 17, 41, 37), datetime.datetime(2013, 2, 9, 18, 8, 39), 6),
#  ('fd280826-7144-11e5-ba71-058fbc01cf0b', 'Pembroke Welsh Corgi', 10, None, datetime.datetime(2013, 2, 7, 15, 5, 9), datetime.datetime(2013, 2, 7, 15, 26, 1), 4),
#  ('fd2808b2-7144-11e5-ba71-058fbc01cf0b', 'Brussels Griffon', 10, None, datetime.datetime(2013, 2, 13, 15, 39, 5), datetime.datetime(2013, 3, 20, 14, 37, 33), 11),
#  ('fd2809c0-7144-11e5-ba71-058fbc01cf0b', 'French Bulldog', 10, None, datetime.datetime(2013, 2, 7, 16, 4, 42), datetime.datetime(2013, 2, 7, 16, 16, 27), 4),
#  ('fd3ccd24-7144-11e5-ba71-058fbc01cf0b', 'French Bulldog', 20, None, datetime.datetime(2013, 2, 7, 16, 26, 21), datetime.datetime(2013, 2, 7, 16, 33, 51), 4),
#  ('fd3ccf2c-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 190, 1, datetime.datetime(2013, 10, 10, 18, 47, 21), datetime.datetime(2014, 7, 21, 17, 6, 17), 22),
#  ('fd3cd40e-7144-11e5-ba71-058fbc01cf0b', 'Doberman Pinscher', 80, None, datetime.datetime(2013, 2, 7, 17, 36, 58), datetime.datetime(2013, 2, 7, 18, 32, 59), 10),
#  ('fd3cd4d6-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 70, None, datetime.datetime(2013, 2, 7, 16, 18, 20), datetime.datetime(2013, 2, 13, 20, 33, 40), 20),
#  ('fd3cd8d2-7144-11e5-ba71-058fbc01cf0b', 'Pembroke Welsh Corgi', 20, None, datetime.datetime(2013, 2, 7, 22, 30, 37), datetime.datetime(2013, 2, 21, 16, 44, 40), 7),
#  ('fd3cec50-7144-11e5-ba71-058fbc01cf0b', 'Rottweiler', 70, None, datetime.datetime(2013, 3, 10, 22, 44, 51), datetime.datetime(2013, 3, 10, 23, 22, 52), 4),
#  ('fd3cf5c4-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 80, None, datetime.datetime(2013, 3, 10, 23, 4, 39), datetime.datetime(2013, 3, 10, 23, 15, 47), 4),
#  ('fd3cf718-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 190, 1, datetime.datetime(2013, 2, 7, 18, 19, 34), datetime.datetime(2013, 2, 27, 20, 40, 37), 17),
#  ('fd3cf8ee-7144-11e5-ba71-058fbc01cf0b', 'Bedlington Terrier', 10, None, datetime.datetime(2013, 2, 7, 23, 17, 4), datetime.datetime(2013, 2, 10, 23, 9, 4), 20),
#  ('fd3cf984-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 100, None, datetime.datetime(2013, 2, 27, 20, 41, 53), datetime.datetime(2013, 2, 27, 20, 53, 46), 4),
#  ('fd3cfa1a-7144-11e5-ba71-058fbc01cf0b', 'Russell Terrier', 10, None, datetime.datetime(2013, 2, 27, 20, 20, 49), datetime.datetime(2013, 2, 27, 20, 32, 55), 4),
#  ('fd3cfab0-7144-11e5-ba71-058fbc01cf0b', 'Poodle', 10, None, datetime.datetime(2013, 3, 13, 15, 11, 14), datetime.datetime(2015, 3, 27, 23, 10, 45), 38),
#  ('fd3cfcfe-7144-11e5-ba71-058fbc01cf0b', 'Irish Setter', 80, None, datetime.datetime(2013, 2, 8, 11, 36, 17), datetime.datetime(2013, 2, 14, 23, 43, 35), 20),
#  ('fd3cfd94-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 80, None, datetime.datetime(2013, 2, 11, 16, 48, 36), datetime.datetime(2013, 5, 24, 13, 13, 51), 20),
#  ('fd3cfe2a-7144-11e5-ba71-058fbc01cf0b', 'Irish Setter', 80, None, datetime.datetime(2013, 2, 8, 23, 13, 41), datetime.datetime(2013, 2, 15, 0, 0, 20), 20),
#  ('fd3cfeb6-7144-11e5-ba71-058fbc01cf0b', 'Poodle', 50, None, datetime.datetime(2013, 2, 11, 17, 25, 52), datetime.datetime(2013, 7, 5, 13, 54, 31), 20),
#  ('fd3cff4c-7144-11e5-ba71-058fbc01cf0b', 'Irish Red and White Setter', 40, None, datetime.datetime(2013, 2, 8, 23, 20, 15), datetime.datetime(2013, 3, 24, 0, 15, 43), 21),
#  ('fd3d01ae-7144-11e5-ba71-058fbc01cf0b', 'American Pit Bull Terrier', 70, None, datetime.datetime(2013, 3, 11, 19, 51, 30), datetime.datetime(2013, 10, 5, 22, 54, 34), 11),
#  ('fd3d03fc-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 50, None, datetime.datetime(2013, 12, 21, 0, 2, 47), datetime.datetime(2013, 12, 21, 0, 12, 14), 4),
#  ('fd3d05be-7144-11e5-ba71-058fbc01cf0b', 'Greyhound', 50, None, datetime.datetime(2013, 2, 10, 21, 58, 7), datetime.datetime(2013, 2, 10, 22, 48, 2), 11),
#  ('fd3d0776-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 50, 0, datetime.datetime(2013, 3, 30, 15, 25, 5), datetime.datetime(2013, 5, 24, 18, 48, 49), 20),
#  ('fd3d0b7c-7144-11e5-ba71-058fbc01cf0b', 'Boxer', 40, None, datetime.datetime(2013, 2, 9, 1, 34, 24), datetime.datetime(2014, 3, 15, 16, 17, 56), 7),
#  ('fd3d0c12-7144-11e5-ba71-058fbc01cf0b', 'Pug', 20, None, datetime.datetime(2013, 2, 8, 13, 28, 3), datetime.datetime(2013, 2, 8, 13, 41, 19), 4),
#  ('fd3d0cb2-7144-11e5-ba71-058fbc01cf0b', 'French Bulldog', 20, None, datetime.datetime(2013, 2, 9, 3, 34, 26), datetime.datetime(2014, 10, 30, 12, 12, 41), 5),
#  ('fd3d102c-7144-11e5-ba71-058fbc01cf0b', 'Pembroke Welsh Corgi', 30, None, datetime.datetime(2013, 2, 23, 19, 8, 36), datetime.datetime(2013, 2, 26, 16, 14, 59), 20),
#  ('fd3d10cc-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 60, None, datetime.datetime(2013, 2, 23, 19, 44, 3), datetime.datetime(2013, 2, 26, 16, 33, 2), 20),
#  ('fd3d1162-7144-11e5-ba71-058fbc01cf0b', 'Cocker Spaniel', 20, None, datetime.datetime(2013, 2, 8, 23, 47, 32), datetime.datetime(2013, 2, 16, 18, 21, 40), 20),
#  ('fd3d12fc-7144-11e5-ba71-058fbc01cf0b', 'Rottweiler', 100, None, datetime.datetime(2013, 2, 17, 3, 52), datetime.datetime(2013, 2, 17, 3, 57, 57), 3),
#  ('fd3d18a6-7144-11e5-ba71-058fbc01cf0b', 'English Springer Spaniel', 40, None, datetime.datetime(2013, 2, 12, 1, 6, 48), datetime.datetime(2013, 2, 12, 1, 23, 29), 4),
#  ('fd3d1982-7144-11e5-ba71-058fbc01cf0b', 'English Springer Spaniel', 40, None, datetime.datetime(2013, 2, 10, 22, 48, 14), datetime.datetime(2013, 2, 10, 22, 51, 47), 2),
#  ('fd3d1b44-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 190, 1, datetime.datetime(2013, 5, 13, 16, 17, 4), datetime.datetime(2013, 7, 10, 17, 34, 14), 20),
#  ('fd3d1d06-7144-11e5-ba71-058fbc01cf0b', 'Neapolitan Mastiff', 40, None, datetime.datetime(2013, 2, 9, 19, 57, 54), datetime.datetime(2013, 2, 15, 21, 18, 36), 15),
#  ('fd3d2116-7144-11e5-ba71-058fbc01cf0b', 'Border Terrier', 10, None, datetime.datetime(2013, 2, 9, 12, 53, 6), datetime.datetime(2013, 2, 13, 1, 25, 34), 20),
#  ('fd3d22d8-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 80, None, datetime.datetime(2013, 2, 10, 1, 5, 51), datetime.datetime(2013, 2, 10, 23, 14, 39), 20),
#  ('fd3d2530-7144-11e5-ba71-058fbc01cf0b', 'Dachshund', 10, None, datetime.datetime(2013, 2, 9, 10, 12, 46), datetime.datetime(2013, 2, 18, 12, 6, 18), 20),
#  ('fd3d25c6-7144-11e5-ba71-058fbc01cf0b', 'Dachshund', 10, None, datetime.datetime(2013, 2, 9, 13, 51, 50), datetime.datetime(2013, 2, 18, 12, 18, 35), 20),
#  ('fd3d26f2-7144-11e5-ba71-058fbc01cf0b', 'Beagle', 20, None, datetime.datetime(2013, 2, 25, 1, 8, 33), datetime.datetime(2013, 3, 31, 1, 13, 32), 20),
#  ('fd3d2788-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 70, None, datetime.datetime(2013, 2, 9, 18, 7, 31), datetime.datetime(2013, 2, 9, 20, 6, 22), 20),
#  ('fd3d28aa-7144-11e5-ba71-058fbc01cf0b', 'Papillon', 0, None, datetime.datetime(2013, 2, 11, 0, 41, 40), datetime.datetime(2013, 3, 7, 2, 49, 12), 20),
#  ('fd3d2940-7144-11e5-ba71-058fbc01cf0b', 'Pomeranian', 0, None, datetime.datetime(2013, 3, 2, 16, 44, 8), datetime.datetime(2014, 8, 17, 15, 52, 57), 16),
#  ('fd3d2a6c-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 70, None, datetime.datetime(2013, 2, 10, 14, 44, 2), datetime.datetime(2013, 2, 10, 15, 32, 4), 9),
#  ('fd3d2c24-7144-11e5-ba71-058fbc01cf0b', 'Australian Shepherd', 30, None, datetime.datetime(2013, 2, 9, 18, 11, 54), datetime.datetime(2013, 2, 17, 19, 7, 6), 11),
#  ('fd3d2d46-7144-11e5-ba71-058fbc01cf0b', 'Shiba Inu', 20, None, datetime.datetime(2013, 2, 16, 21, 21, 56), datetime.datetime(2015, 5, 18, 2, 10, 6), 18),
#  ('fd3d2e72-7144-11e5-ba71-058fbc01cf0b', 'Poodle', 0, None, datetime.datetime(2013, 2, 10, 1, 26, 58), datetime.datetime(2013, 2, 13, 1, 31, 32), 20),
#  ('fd3d2f9e-7144-11e5-ba71-058fbc01cf0b', 'Poodle', 40, 1, datetime.datetime(2013, 2, 9, 21, 48, 46), datetime.datetime(2013, 2, 9, 23, 1, 20), 20),
#  ('fd3d33a4-7144-11e5-ba71-058fbc01cf0b', 'Chihuahua', 0, None, datetime.datetime(2013, 2, 10, 14, 4, 10), datetime.datetime(2013, 2, 10, 17, 45, 35), 7),
#  ('fd3d34d0-7144-11e5-ba71-058fbc01cf0b', 'Parson Russell Terrier', 10, None, datetime.datetime(2013, 2, 10, 18, 10), datetime.datetime(2015, 1, 21, 0, 57, 13), 37),
#  ('fd3d35f2-7144-11e5-ba71-058fbc01cf0b', 'Rhodesian Ridgeback', 70, None, datetime.datetime(2013, 2, 10, 20, 13, 34), datetime.datetime(2013, 7, 14, 17, 57, 19), 31),
#  ('fd3d37b4-7144-11e5-ba71-058fbc01cf0b', 'Chihuahua', 0, None, datetime.datetime(2013, 2, 11, 1, 22, 35), datetime.datetime(2013, 2, 25, 1, 43, 5), 16),
#  ('fd3d3840-7144-11e5-ba71-058fbc01cf0b', 'West Highland White Terrier', 0, None, datetime.datetime(2013, 2, 10, 21, 6, 52), datetime.datetime(2013, 4, 9, 23, 56, 17), 20),
#  ('fd3d3a8e-7144-11e5-ba71-058fbc01cf0b', 'Vizsla', 40, None, datetime.datetime(2013, 3, 30, 15, 35, 46), datetime.datetime(2013, 4, 1, 0, 1, 27), 20),
#  ('fd3d3b24-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 80, None, datetime.datetime(2015, 3, 11, 16, 4, 41), datetime.datetime(2015, 3, 11, 16, 15, 52), 4),
#  ('fd3d424a-7144-11e5-ba71-058fbc01cf0b', 'Bernese Mountain Dog', 70, None, datetime.datetime(2013, 3, 25, 19, 0, 13), datetime.datetime(2013, 4, 4, 18, 23, 47), 20),
#  ('fd3d42ea-7144-11e5-ba71-058fbc01cf0b', 'Bernese Mountain Dog', 100, None, datetime.datetime(2013, 2, 25, 17, 8, 41), datetime.datetime(2013, 2, 25, 20, 30, 26), 20),
#  ('fd3d4376-7144-11e5-ba71-058fbc01cf0b', 'Bernese Mountain Dog', 90, None, datetime.datetime(2013, 2, 11, 17, 5, 34), datetime.datetime(2013, 2, 11, 21, 20, 29), 20),
#  ('fd3d440c-7144-11e5-ba71-058fbc01cf0b', 'Yorkshire Terrier', 0, None, datetime.datetime(2013, 2, 11, 17, 31, 4), datetime.datetime(2013, 3, 16, 23, 36, 53), 20),
#  ('fd3d45ce-7144-11e5-ba71-058fbc01cf0b', 'Flat-Coated Retriever', 60, None, datetime.datetime(2013, 2, 17, 22, 30, 2), datetime.datetime(2013, 2, 17, 22, 44, 8), 4),
#  ('fd3d48c6-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 80, None, datetime.datetime(2013, 12, 4, 20, 22, 47), datetime.datetime(2015, 2, 14, 21, 35, 5), 20),
#  ('fd3d4b8c-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 70, None, datetime.datetime(2013, 2, 14, 20, 25, 14), datetime.datetime(2013, 3, 13, 20, 45, 9), 20),
#  ('fd3d515e-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 80, None, datetime.datetime(2013, 2, 17, 23, 50, 9), datetime.datetime(2013, 2, 18, 4, 1, 4), 20),
#  ('fd3d587a-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 190, 1, datetime.datetime(2013, 2, 22, 17, 0, 49), datetime.datetime(2013, 4, 2, 20, 38, 1), 22),
#  ('fd3d5a1e-7144-11e5-ba71-058fbc01cf0b', 'American Staffordshire Terrier', 80, None, datetime.datetime(2013, 3, 2, 2, 58, 37), datetime.datetime(2013, 3, 2, 3, 6, 39), 4),
#  ('fd3d5aa0-7144-11e5-ba71-058fbc01cf0b', 'Bulldog', 50, None, datetime.datetime(2013, 3, 2, 3, 11, 6), datetime.datetime(2013, 3, 2, 3, 18, 42), 4),
#  ('fd3f83d4-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 60, None, datetime.datetime(2013, 2, 13, 4, 41, 34), datetime.datetime(2013, 2, 13, 6, 42, 14), 20),
#  ('fd3f8514-7144-11e5-ba71-058fbc01cf0b', 'Beagle', 30, None, datetime.datetime(2013, 2, 13, 6, 40, 12), datetime.datetime(2013, 7, 2, 3, 54, 33), 23),
#  ('fd3f8aa0-7144-11e5-ba71-058fbc01cf0b', 'Beagle', 30, 1, datetime.datetime(2013, 2, 13, 6, 22, 47), datetime.datetime(2013, 7, 2, 3, 51, 27), 23),
#  ('fd3f90fe-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 90, None, datetime.datetime(2013, 2, 16, 15, 45, 30), datetime.datetime(2013, 12, 8, 21, 13, 46), 25),
#  ('fd3f9c2a-7144-11e5-ba71-058fbc01cf0b', 'Doberman Pinscher', 80, None, datetime.datetime(2013, 2, 18, 19, 1, 34), datetime.datetime(2013, 2, 20, 15, 57, 17), 7),
#  ('fd3fb0f2-7144-11e5-ba71-058fbc01cf0b', 'Shetland Sheepdog', 20, None, datetime.datetime(2013, 3, 10, 16, 11, 43), datetime.datetime(2013, 3, 10, 21, 40, 43), 6),
#  ('fd3fb76e-7144-11e5-ba71-058fbc01cf0b', 'Beagle', 30, None, datetime.datetime(2013, 2, 17, 18, 59, 51), datetime.datetime(2013, 2, 17, 19, 4), 2),
#  ('fd3fb8fe-7144-11e5-ba71-058fbc01cf0b', 'Rhodesian Ridgeback', 40, None, datetime.datetime(2013, 2, 14, 8, 47, 53), datetime.datetime(2013, 2, 14, 8, 47, 53), 1),
#  ('fd3fb9c6-7144-11e5-ba71-058fbc01cf0b', 'Miniature Schnauzer', 10, None, datetime.datetime(2013, 2, 14, 11, 2, 1), datetime.datetime(2014, 5, 20, 1, 48, 42), 45),
#  ('fd3fbfe8-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 190, 1, datetime.datetime(2013, 2, 27, 20, 25, 37), datetime.datetime(2013, 2, 28, 20, 55, 24), 4),
#  ('fd3fc0ce-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 190, 1, datetime.datetime(2013, 2, 14, 17, 44, 23), datetime.datetime(2013, 2, 14, 18, 7, 27), 20),
#  ('fd3fc1be-7144-11e5-ba71-058fbc01cf0b', 'English Cocker Spaniel', 30, None, datetime.datetime(2013, 5, 24, 16, 41, 3), datetime.datetime(2013, 5, 24, 16, 57, 45), 4),
#  ('fd3fc628-7144-11e5-ba71-058fbc01cf0b', 'Australian Shepherd', 40, None, datetime.datetime(2013, 4, 15, 3, 30, 52), datetime.datetime(2013, 4, 15, 3, 40, 40), 2),
#  ('fd3fc704-7144-11e5-ba71-058fbc01cf0b', 'Parson Russell Terrier', 10, None, datetime.datetime(2013, 4, 15, 3, 34, 18), datetime.datetime(2013, 4, 15, 3, 47, 9), 2),
#  ('fd3fc7ea-7144-11e5-ba71-058fbc01cf0b', 'Boxer', 60, None, datetime.datetime(2013, 2, 15, 2, 25, 39), datetime.datetime(2015, 2, 24, 22, 47, 44), 16),
#  ('fd3fc9fc-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 50, None, datetime.datetime(2013, 2, 15, 2, 9, 7), datetime.datetime(2013, 7, 2, 1, 12, 30), 27),
#  ('fd3fcd58-7144-11e5-ba71-058fbc01cf0b', 'Australian Cattle Dog', 60, None, datetime.datetime(2013, 2, 15, 17, 51, 15), datetime.datetime(2013, 2, 18, 20, 52, 16), 10),
#  ('fd3fd140-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 190, 1, datetime.datetime(2015, 2, 19, 18, 55, 16), datetime.datetime(2015, 2, 19, 18, 55, 16), 1),
#  ('fd3fd1fe-7144-11e5-ba71-058fbc01cf0b', 'Miniature Schnauzer', 10, None, datetime.datetime(2013, 2, 15, 14, 51, 34), datetime.datetime(2013, 2, 15, 15, 5, 38), 4),
#  ('fd3fd3de-7144-11e5-ba71-058fbc01cf0b', 'Poodle', 60, None, datetime.datetime(2013, 2, 17, 20, 32, 20), datetime.datetime(2013, 2, 17, 20, 40, 51), 4),
#  ('fd3fd474-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 80, None, datetime.datetime(2013, 2, 24, 19, 5, 6), datetime.datetime(2013, 2, 25, 23, 8, 53), 20),
#  ('fd3fd988-7144-11e5-ba71-058fbc01cf0b', 'Italian Greyhound', 0, None, datetime.datetime(2013, 8, 31, 21, 13, 38), datetime.datetime(2014, 5, 4, 19, 27, 9), 20),
#  ('fd3fda6e-7144-11e5-ba71-058fbc01cf0b', 'Weimaraner', 40, None, datetime.datetime(2013, 2, 17, 3, 2, 3), datetime.datetime(2013, 2, 23, 21, 20, 2), 20),
#  ('fd3fdb54-7144-11e5-ba71-058fbc01cf0b', 'Leonberger', 140, None, datetime.datetime(2013, 2, 17, 2, 23, 44), datetime.datetime(2013, 2, 17, 3, 6, 47), 11),
#  ('fd3fdc3a-7144-11e5-ba71-058fbc01cf0b', 'Poodle', 0, None, datetime.datetime(2013, 2, 17, 14, 16, 20), datetime.datetime(2013, 2, 19, 14, 29, 18), 20),
#  ('fd3fdd20-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 80, 1, datetime.datetime(2013, 2, 17, 22, 32, 10), datetime.datetime(2013, 3, 10, 20, 2, 21), 20),
#  ('fd3fdeec-7144-11e5-ba71-058fbc01cf0b', 'Portuguese Water Dog', 50, None, datetime.datetime(2013, 2, 18, 14, 44, 48), datetime.datetime(2013, 2, 21, 1, 32, 23), 11),
#  ('fd3fdfc8-7144-11e5-ba71-058fbc01cf0b', 'Boykin Spaniel', 20, None, datetime.datetime(2013, 2, 18, 22, 8, 6), datetime.datetime(2014, 5, 25, 1, 38, 48), 11),
#  ('fd3fe18a-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 70, None, datetime.datetime(2013, 2, 17, 20, 27, 6), datetime.datetime(2013, 2, 17, 22, 10, 27), 20),
#  ('fd3fe270-7144-11e5-ba71-058fbc01cf0b', 'Soft Coated Wheaten Terrier', 30, None, datetime.datetime(2013, 2, 17, 23, 26, 8), datetime.datetime(2013, 3, 9, 23, 1, 17), 11),
#  ('fd3fe432-7144-11e5-ba71-058fbc01cf0b', 'Poodle', 80, None, datetime.datetime(2013, 2, 18, 19, 51, 9), datetime.datetime(2013, 3, 3, 18, 8, 18), 8),
#  ('fd3fe842-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 60, None, datetime.datetime(2013, 2, 20, 20, 41, 52), datetime.datetime(2013, 3, 19, 18, 35, 2), 20),
#  ('fd3fe8e2-7144-11e5-ba71-058fbc01cf0b', 'Bulldog', 30, None, datetime.datetime(2013, 2, 18, 18, 58, 22), datetime.datetime(2013, 2, 18, 19, 6, 50), 3),
#  ('fd3fe96e-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 90, None, datetime.datetime(2013, 2, 18, 21, 27, 7), datetime.datetime(2013, 2, 18, 23, 7, 22), 6),
#  ('fd3fea04-7144-11e5-ba71-058fbc01cf0b', 'Boston Terrier', 20, 1, datetime.datetime(2014, 1, 9, 18, 23, 32), datetime.datetime(2014, 1, 12, 20, 35, 53), 21),
#  ('fd3fea9a-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 190, 1, datetime.datetime(2013, 2, 18, 21, 6, 28), datetime.datetime(2014, 4, 19, 4, 58, 51), 35),
#  ('fd3febc6-7144-11e5-ba71-058fbc01cf0b', 'Brittany', 30, None, datetime.datetime(2013, 4, 28, 20, 15, 30), datetime.datetime(2014, 1, 6, 16, 11, 17), 33),
#  ('fd3fec5c-7144-11e5-ba71-058fbc01cf0b', 'Bernese Mountain Dog', 100, None, datetime.datetime(2013, 4, 30, 23, 11, 6), datetime.datetime(2013, 4, 30, 23, 20, 22), 3),
#  ('fd3fefd6-7144-11e5-ba71-058fbc01cf0b', 'Australian Cattle Dog', 40, None, datetime.datetime(2013, 7, 20, 0, 41, 57), datetime.datetime(2013, 7, 20, 18, 29, 27), 5),
#  ('fd3ff102-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 80, None, datetime.datetime(2013, 3, 1, 16, 57, 9), datetime.datetime(2013, 6, 28, 19, 39, 7), 28),
#  ('fd3ff18e-7144-11e5-ba71-058fbc01cf0b', 'Nova Scotia Duck Tolling Retriever', 40, None, datetime.datetime(2013, 2, 25, 2, 37, 30), datetime.datetime(2013, 8, 1, 15, 25, 56), 31),
#  ('fd3ff22e-7144-11e5-ba71-058fbc01cf0b', 'Nova Scotia Duck Tolling Retriever', 30, None, datetime.datetime(2013, 2, 25, 2, 55, 46), datetime.datetime(2013, 7, 11, 14, 53, 36), 31),
#  ('fd3ff512-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 60, 0, datetime.datetime(2013, 2, 21, 1, 15, 4), datetime.datetime(2014, 2, 3, 22, 56, 32), 44),
#  ('fd3ff5a8-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 60, None, datetime.datetime(2013, 2, 21, 0, 45, 47), datetime.datetime(2014, 2, 3, 22, 45), 44),
#  ('fd3ff63e-7144-11e5-ba71-058fbc01cf0b', 'Australian Shepherd', 40, None, datetime.datetime(2013, 2, 23, 22, 58, 53), datetime.datetime(2013, 2, 24, 0, 37, 5), 20),
#  ('fd3ff90e-7144-11e5-ba71-058fbc01cf0b', 'Siberian Husky', 40, None, datetime.datetime(2013, 8, 10, 20, 53, 15), datetime.datetime(2014, 3, 28, 23, 30, 29), 15),
#  ('fd3ffc7e-7144-11e5-ba71-058fbc01cf0b', 'Lhasa Apso', 10, None, datetime.datetime(2013, 2, 23, 14, 20, 20), datetime.datetime(2013, 2, 23, 17, 18, 30), 20),
#  ('fd3ffda0-7144-11e5-ba71-058fbc01cf0b', 'Australian Shepherd', 40, None, datetime.datetime(2013, 3, 27, 17, 44, 16), datetime.datetime(2013, 3, 28, 15, 57, 34), 6),
#  ('fd4003b8-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 70, None, datetime.datetime(2013, 2, 23, 18, 20, 57), datetime.datetime(2013, 3, 9, 17, 52, 10), 20),
#  ('fd400584-7144-11e5-ba71-058fbc01cf0b', 'American Eskimo Dog', 10, None, datetime.datetime(2013, 2, 21, 1, 57, 21), datetime.datetime(2014, 8, 21, 0, 15, 18), 43),
#  ('fd400610-7144-11e5-ba71-058fbc01cf0b', 'Boxer', 50, None, datetime.datetime(2013, 8, 7, 0, 46, 54), datetime.datetime(2013, 8, 10, 16, 7, 16), 20),
#  ('fd4007c8-7144-11e5-ba71-058fbc01cf0b', 'Keeshond', 40, None, datetime.datetime(2013, 2, 20, 15, 10, 50), datetime.datetime(2013, 2, 21, 18, 31, 54), 7),
#  ('fd4008f4-7144-11e5-ba71-058fbc01cf0b', 'Bull Terrier', 60, None, datetime.datetime(2013, 2, 21, 1, 49, 36), datetime.datetime(2013, 2, 21, 2, 23, 33), 5),
#  ('fd40098a-7144-11e5-ba71-058fbc01cf0b', 'Soft Coated Wheaten Terrier', 30, None, datetime.datetime(2013, 3, 20, 17, 56, 29), datetime.datetime(2013, 3, 22, 19, 14, 1), 11),
#  ('fd400a16-7144-11e5-ba71-058fbc01cf0b', 'Boston Terrier', 10, 1, datetime.datetime(2013, 2, 20, 16, 0, 41), datetime.datetime(2013, 2, 20, 16, 5, 2), 4),
#  ('fd400aac-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 70, None, datetime.datetime(2014, 6, 27, 22, 12, 10), datetime.datetime(2014, 6, 27, 22, 16, 13), 2),
#  ('fd400b4c-7144-11e5-ba71-058fbc01cf0b', 'Poodle', 30, None, datetime.datetime(2013, 2, 24, 20, 14, 9), datetime.datetime(2013, 6, 23, 23, 48, 28), 5),
#  ('fd400bec-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 90, None, datetime.datetime(2014, 8, 24, 18, 29, 32), datetime.datetime(2014, 8, 24, 18, 29, 32), 1),
#  ('fd400d04-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 80, None, datetime.datetime(2013, 2, 22, 2, 39, 27), datetime.datetime(2013, 3, 6, 20, 48, 7), 20),
#  ('fd400fca-7144-11e5-ba71-058fbc01cf0b', 'Chesapeake Bay Retriever', 90, None, datetime.datetime(2013, 3, 16, 18, 13, 7), datetime.datetime(2013, 4, 12, 22, 21, 5), 7),
#  ('fd4014a2-7144-11e5-ba71-058fbc01cf0b', 'Mixed', 50, 0, datetime.datetime(2013, 8, 21, 1, 35, 25), datetime.datetime(2013, 9, 11, 2, 13, 5), 20),
#  ('fd401614-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 190, 1, datetime.datetime(2013, 8, 19, 14, 30, 31), datetime.datetime(2014, 9, 15, 7, 29, 31), 36),
#  ('fd4016aa-7144-11e5-ba71-058fbc01cf0b', 'Cocker Spaniel', 20, None, datetime.datetime(2013, 2, 23, 19, 11, 35), datetime.datetime(2014, 7, 14, 1, 3, 59), 45),
#  ('fd401858-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 70, None, datetime.datetime(2013, 2, 22, 16, 56, 41), datetime.datetime(2013, 2, 22, 18, 0, 9), 20),
#  ('fd401d6c-7144-11e5-ba71-058fbc01cf0b', 'Maltese', 10, None, datetime.datetime(2013, 2, 20, 23, 27, 10), datetime.datetime(2013, 2, 20, 23, 38, 25), 4),
#  ('fd402b90-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 50, None, datetime.datetime(2013, 2, 24, 15, 55, 49), datetime.datetime(2013, 2, 24, 16, 23, 33), 6),
#  ('fd4038c4-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 190, 1, datetime.datetime(2013, 2, 21, 16, 24, 56), datetime.datetime(2013, 2, 21, 17, 7, 48), 15),
#  ('fd404634-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 190, 1, datetime.datetime(2013, 2, 21, 16, 41, 41), datetime.datetime(2013, 6, 10, 14, 41, 3), 20),
#  ('fd404760-7144-11e5-ba71-058fbc01cf0b', 'Australian Cattle Dog', 20, None, datetime.datetime(2013, 2, 21, 23, 0, 38), datetime.datetime(2013, 3, 1, 3, 13, 25), 20),
#  ('fd404b02-7144-11e5-ba71-058fbc01cf0b', 'Boxer', 70, 1, datetime.datetime(2013, 2, 28, 1, 44, 54), datetime.datetime(2013, 4, 14, 20, 5, 24), 20),
#  ('fd404ff8-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 40, None, datetime.datetime(2013, 6, 10, 1, 41, 11), datetime.datetime(2015, 1, 19, 22, 53, 19), 37),
#  ('fd40511a-7144-11e5-ba71-058fbc01cf0b', 'Parson Russell Terrier', 0, None, datetime.datetime(2013, 2, 22, 14, 32, 2), datetime.datetime(2013, 2, 22, 15, 58, 25), 20),
#  ('fd4051a6-7144-11e5-ba71-058fbc01cf0b', 'Border Collie', 50, None, datetime.datetime(2013, 2, 25, 18, 19, 30), datetime.datetime(2013, 2, 25, 18, 19, 30), 1),
#  ('fd405232-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 80, None, datetime.datetime(2013, 2, 23, 0, 31, 54), datetime.datetime(2013, 2, 26, 19, 13, 9), 20),
#  ('fd405462-7144-11e5-ba71-058fbc01cf0b', 'Poodle', 30, None, datetime.datetime(2014, 1, 16, 1, 7, 5), datetime.datetime(2014, 1, 16, 1, 12, 13), 2),
#  ('fd4054ee-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 190, 1, datetime.datetime(2013, 6, 6, 13, 35, 50), datetime.datetime(2014, 7, 24, 18, 29, 55), 45),
#  ('fd40557a-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 10, None, datetime.datetime(2013, 5, 28, 1, 20, 51), datetime.datetime(2013, 5, 28, 1, 31, 43), 4),
#  ('fd4058d6-7144-11e5-ba71-058fbc01cf0b', 'Border Collie', 50, None, datetime.datetime(2013, 2, 24, 17, 29, 26), datetime.datetime(2013, 2, 24, 17, 29, 26), 1),
#  ('fd4059e4-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 70, None, datetime.datetime(2013, 3, 10, 17, 0, 48), datetime.datetime(2013, 6, 9, 3, 30, 26), 20),
#  ('fd405c14-7144-11e5-ba71-058fbc01cf0b', 'Chihuahua', 0, None, datetime.datetime(2013, 2, 22, 20, 21, 53), datetime.datetime(2013, 2, 22, 21, 35, 33), 20),
#  ('fd405e30-7144-11e5-ba71-058fbc01cf0b', 'Australian Shepherd', 40, None, datetime.datetime(2013, 3, 18, 15, 30, 54), datetime.datetime(2013, 7, 29, 2, 6, 1), 20),
#  ('fd405f52-7144-11e5-ba71-058fbc01cf0b', 'Poodle', 10, None, datetime.datetime(2013, 2, 22, 23, 35, 49), datetime.datetime(2013, 4, 2, 16, 41, 24), 16),
#  ('fd405fde-7144-11e5-ba71-058fbc01cf0b', 'Affenpinscher', 10, 1, datetime.datetime(2013, 2, 22, 17, 27, 28), datetime.datetime(2013, 2, 22, 19, 16, 51), 18),
#  ('fd40606a-7144-11e5-ba71-058fbc01cf0b', 'Keeshond', 30, None, datetime.datetime(2013, 3, 2, 20, 23, 12), datetime.datetime(2013, 3, 8, 19, 50, 52), 14),
#  ('fd4060f6-7144-11e5-ba71-058fbc01cf0b', 'Chihuahua', 0, None, datetime.datetime(2013, 2, 25, 20, 12, 33), datetime.datetime(2013, 3, 2, 0, 28, 32), 20),
#  ('fd406196-7144-11e5-ba71-058fbc01cf0b', 'English Setter', 40, None, datetime.datetime(2014, 10, 28, 21, 8, 57), datetime.datetime(2015, 1, 29, 21, 21, 14), 5),
#  ('fd406466-7144-11e5-ba71-058fbc01cf0b', 'Miniature Schnauzer-Poodle Mix', 20, 1, datetime.datetime(2013, 6, 9, 15, 51), datetime.datetime(2013, 6, 11, 18, 1, 32), 20),
#  ('fd406704-7144-11e5-ba71-058fbc01cf0b', 'Havanese', 10, None, datetime.datetime(2013, 2, 23, 18, 55, 24), datetime.datetime(2013, 3, 19, 16, 28, 42), 20),
#  ('fd4067d6-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 60, None, datetime.datetime(2013, 2, 24, 2, 35, 47), datetime.datetime(2013, 2, 24, 2, 48, 30), 4),
#  ('fd406a4c-7144-11e5-ba71-058fbc01cf0b', 'Australian Shepherd', 30, None, datetime.datetime(2013, 2, 25, 1, 35, 26), datetime.datetime(2013, 3, 13, 0, 47, 3), 20),
#  ('fd406bf0-7144-11e5-ba71-058fbc01cf0b', 'Border Collie', 30, None, datetime.datetime(2013, 2, 23, 2, 46, 32), datetime.datetime(2013, 3, 3, 2, 26, 2), 7),
#  ('fd406cc2-7144-11e5-ba71-058fbc01cf0b', 'Boxer', 70, None, datetime.datetime(2013, 2, 23, 19, 43, 56), datetime.datetime(2013, 5, 23, 17, 13, 53), 20),
#  ('fd406eb6-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 70, None, datetime.datetime(2013, 2, 23, 16, 31, 18), datetime.datetime(2013, 2, 24, 15, 34, 58), 5),
#  ('fd406f42-7144-11e5-ba71-058fbc01cf0b', 'Miniature Schnauzer', 20, None, datetime.datetime(2013, 6, 8, 14, 48, 42), datetime.datetime(2013, 6, 8, 15, 2, 55), 4),
#  ('fd407168-7144-11e5-ba71-058fbc01cf0b', 'Pug', 20, None, datetime.datetime(2013, 2, 23, 20, 30, 34), datetime.datetime(2013, 9, 4, 20, 37, 8), 31),
#  ('fd407302-7144-11e5-ba71-058fbc01cf0b', 'Poodle', 0, None, datetime.datetime(2013, 2, 23, 23, 31, 33), datetime.datetime(2013, 2, 27, 9, 51, 2), 9),
#  ('fd40738e-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 50, None, datetime.datetime(2013, 3, 23, 20, 22, 36), datetime.datetime(2013, 7, 7, 18, 24, 23), 27),
#  ('fd4074a6-7144-11e5-ba71-058fbc01cf0b', 'Australian Cattle Dog', 40, None, datetime.datetime(2013, 2, 25, 18, 28, 13), datetime.datetime(2013, 3, 25, 18, 0, 6), 14),
#  ('fd407528-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 80, None, datetime.datetime(2013, 2, 24, 0, 0), datetime.datetime(2013, 4, 29, 11, 31), 22),
#  ('fd4078e8-7144-11e5-ba71-058fbc01cf0b', 'Mixed', 40, None, datetime.datetime(2013, 2, 24, 14, 49), datetime.datetime(2013, 3, 24, 19, 53, 7), 23),
#  ('fd407a00-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 20, None, datetime.datetime(2013, 3, 1, 19, 35, 45), datetime.datetime(2013, 12, 7, 17, 47, 54), 31),
#  ('fd407f6e-7144-11e5-ba71-058fbc01cf0b', 'Border Collie', 20, None, datetime.datetime(2013, 2, 27, 0, 28, 23), datetime.datetime(2013, 2, 27, 0, 39, 32), 4),
#  ('fd407ff0-7144-11e5-ba71-058fbc01cf0b', 'Bulldog', 50, None, datetime.datetime(2013, 6, 23, 19, 48, 52), datetime.datetime(2013, 6, 23, 22, 51, 29), 20),
#  ('fd408194-7144-11e5-ba71-058fbc01cf0b', 'Nova Scotia Duck Tolling Retriever', 40, None, datetime.datetime(2013, 2, 27, 19, 0, 8), datetime.datetime(2013, 4, 9, 19, 42, 29), 20),
#  ('fd408446-7144-11e5-ba71-058fbc01cf0b', 'Australian Shepherd', 20, None, datetime.datetime(2013, 3, 6, 2, 4, 34), datetime.datetime(2013, 3, 6, 2, 17, 5), 4),
#  ('fd408662-7144-11e5-ba71-058fbc01cf0b', 'English Cocker Spaniel', 20, None, datetime.datetime(2013, 4, 12, 19, 19, 14), datetime.datetime(2013, 5, 11, 13, 27, 41), 14),
#  ('fd408ed2-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 80, None, datetime.datetime(2013, 2, 25, 1, 56, 44), datetime.datetime(2013, 3, 30, 1, 31, 33), 20),
#  ('fd40945e-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 70, None, datetime.datetime(2013, 3, 1, 0, 33, 46), datetime.datetime(2013, 3, 8, 1, 17, 6), 20),
#  ('fd4094ea-7144-11e5-ba71-058fbc01cf0b', 'Boxer', 50, None, datetime.datetime(2013, 3, 29, 0, 17, 44), datetime.datetime(2013, 3, 29, 0, 17, 44), 1),
#  ('fd4096fc-7144-11e5-ba71-058fbc01cf0b', 'Bernese Mountain Dog', 40, None, datetime.datetime(2013, 2, 26, 11, 45, 41), datetime.datetime(2013, 3, 4, 11, 10, 12), 20),
#  ('fd409e36-7144-11e5-ba71-058fbc01cf0b', 'Havanese', 10, None, datetime.datetime(2013, 3, 1, 0, 55, 2), datetime.datetime(2013, 4, 30, 23, 59, 33), 18),
#  ('fd40aeee-7144-11e5-ba71-058fbc01cf0b', 'Boxer', 60, None, datetime.datetime(2015, 9, 18, 22, 16, 42), datetime.datetime(2015, 9, 18, 22, 21, 40), 2),
#  ('fd40bd62-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 190, 1, datetime.datetime(2013, 3, 3, 22, 10, 22), datetime.datetime(2014, 12, 1, 21, 9, 46), 35),
#  ('fd40cb7c-7144-11e5-ba71-058fbc01cf0b', 'Scottish Terrier', 20, 1, datetime.datetime(2013, 2, 28, 20, 19, 45), datetime.datetime(2013, 3, 2, 19, 58, 43), 20),
#  ('fd40ce38-7144-11e5-ba71-058fbc01cf0b', 'Weimaraner', 60, None, datetime.datetime(2013, 8, 14, 16, 2, 34), datetime.datetime(2013, 8, 14, 16, 18, 26), 4),
#  ('fd40cf5a-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 20, None, datetime.datetime(2013, 3, 3, 21, 37, 18), datetime.datetime(2013, 3, 3, 22, 18, 27), 7),
#  ('fd40d4dc-7144-11e5-ba71-058fbc01cf0b', 'Weimaraner', 80, 1, datetime.datetime(2013, 3, 3, 23, 39, 20), datetime.datetime(2013, 3, 25, 22, 12, 25), 20),
#  ('fd40d5f4-7144-11e5-ba71-058fbc01cf0b', 'West Highland White Terrier', 20, None, datetime.datetime(2013, 3, 31, 13, 31, 42), datetime.datetime(2013, 3, 31, 13, 54, 45), 4),
#  ('fd40d8b0-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 70, None, datetime.datetime(2013, 3, 1, 0, 36, 45), datetime.datetime(2013, 3, 1, 0, 46, 19), 4),
#  ('fd40da54-7144-11e5-ba71-058fbc01cf0b', 'Beagle', 30, None, datetime.datetime(2013, 3, 3, 0, 30, 15), datetime.datetime(2013, 3, 5, 2, 7, 43), 20),
#  ('fd40e206-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 190, 1, datetime.datetime(2013, 7, 26, 2, 9, 20), datetime.datetime(2014, 7, 15, 17, 16, 17), 18),
#  ('fd40e332-7144-11e5-ba71-058fbc01cf0b', 'Australian Shepherd', 40, None, datetime.datetime(2013, 10, 7, 14, 10, 46), datetime.datetime(2013, 10, 7, 14, 10, 46), 1),
#  ('fd40e440-7144-11e5-ba71-058fbc01cf0b', 'Beagle', 30, None, datetime.datetime(2013, 4, 12, 20, 24, 22), datetime.datetime(2013, 9, 21, 2, 42, 36), 28),
#  ('fd40e4cc-7144-11e5-ba71-058fbc01cf0b', 'Beagle', 20, None, datetime.datetime(2013, 4, 11, 16, 47, 44), datetime.datetime(2013, 9, 21, 2, 28, 50), 28),
#  ('fd40e832-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 60, None, datetime.datetime(2013, 8, 2, 0, 40, 5), datetime.datetime(2014, 4, 11, 20, 3, 48), 7),
#  ('fd40eda0-7144-11e5-ba71-058fbc01cf0b', 'Great Dane', 180, None, datetime.datetime(2013, 3, 3, 14, 42, 35), datetime.datetime(2013, 3, 24, 23, 42, 32), 20),
#  ('fd40ee72-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 70, None, datetime.datetime(2013, 3, 1, 2, 4, 35), datetime.datetime(2013, 3, 10, 22, 39, 18), 11),
#  ('fd40f02a-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 60, None, datetime.datetime(2013, 3, 29, 1, 17, 27), datetime.datetime(2014, 9, 9, 15, 41, 37), 16),
#  ('fd40f714-7144-11e5-ba71-058fbc01cf0b', 'Icelandic Sheepdog', 40, None, datetime.datetime(2013, 3, 1, 1, 38, 18), datetime.datetime(2013, 3, 1, 1, 49, 29), 4),
#  ('fd40f822-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 60, None, datetime.datetime(2013, 3, 11, 19, 21, 39), datetime.datetime(2013, 3, 21, 20, 8, 27), 20),
#  ('fd40fa66-7144-11e5-ba71-058fbc01cf0b', 'Dachshund', 0, None, datetime.datetime(2013, 3, 2, 10, 47, 25), datetime.datetime(2013, 3, 2, 15, 55, 29), 20),
#  ('fd40fdc2-7144-11e5-ba71-058fbc01cf0b', 'Miniature Schnauzer', 20, None, datetime.datetime(2013, 3, 1, 0, 21, 26), datetime.datetime(2013, 3, 10, 22, 11, 24), 6),
#  ('fd40feda-7144-11e5-ba71-058fbc01cf0b', 'Miniature Schnauzer', 0, None, datetime.datetime(2013, 3, 1, 0, 38, 51), datetime.datetime(2013, 3, 4, 0, 16, 43), 20),
#  ('fd410376-7144-11e5-ba71-058fbc01cf0b', 'Weimaraner', 80, None, datetime.datetime(2013, 3, 1, 2, 49, 53), datetime.datetime(2013, 3, 5, 3, 2, 31), 13),
#  ('fd410632-7144-11e5-ba71-058fbc01cf0b', 'Border Collie', 30, None, datetime.datetime(2014, 5, 26, 21, 57, 5), datetime.datetime(2014, 5, 26, 22, 6, 1), 4),
#  ('fd4107cc-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 60, None, datetime.datetime(2013, 3, 4, 2, 14, 10), datetime.datetime(2013, 12, 8, 2, 11, 25), 28),
#  ('fd410858-7144-11e5-ba71-058fbc01cf0b', 'Cairn Terrier', 10, None, datetime.datetime(2013, 3, 2, 23, 38, 5), datetime.datetime(2013, 3, 2, 23, 50, 19), 4),
#  ('fd410966-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 80, None, datetime.datetime(2013, 3, 8, 2, 40, 9), datetime.datetime(2013, 4, 28, 15, 27, 33), 18),
#  ('fd410b14-7144-11e5-ba71-058fbc01cf0b', 'Old English Sheepdog', 60, 1, datetime.datetime(2013, 4, 4, 19, 14, 5), datetime.datetime(2015, 1, 30, 19, 47, 12), 15),
#  ('fd410c2c-7144-11e5-ba71-058fbc01cf0b', 'West Highland White Terrier', 10, None, datetime.datetime(2013, 3, 1, 22, 4, 10), datetime.datetime(2013, 3, 2, 1, 6, 23), 20),
#  ('fd410cb8-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 80, None, datetime.datetime(2013, 3, 28, 16, 20), datetime.datetime(2013, 11, 1, 15, 18, 13), 13),
#  ('fd411280-7144-11e5-ba71-058fbc01cf0b', 'Miniature Schnauzer', 10, None, datetime.datetime(2013, 3, 2, 0, 44, 51), datetime.datetime(2013, 3, 2, 1, 12, 18), 6),
#  ('fd411366-7144-11e5-ba71-058fbc01cf0b', 'Boston Terrier', 0, None, datetime.datetime(2013, 3, 2, 14, 33, 40), datetime.datetime(2013, 3, 3, 1, 24, 10), 11),
#  ('fd4113d4-7144-11e5-ba71-058fbc01cf0b', 'Portuguese Water Dog', 30, None, datetime.datetime(2013, 3, 3, 21, 17, 39), datetime.datetime(2014, 3, 9, 2, 29, 3), 18),
#  ('fd4115aa-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 90, None, datetime.datetime(2013, 3, 30, 17, 28, 33), datetime.datetime(2013, 3, 30, 17, 28, 33), 1),
#  ('fd411690-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 70, None, datetime.datetime(2013, 3, 2, 20, 10, 4), datetime.datetime(2013, 3, 17, 19, 51, 50), 16),
#  ('fd4118e8-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 80, None, datetime.datetime(2013, 3, 2, 13, 25, 46), datetime.datetime(2013, 3, 3, 13, 3, 27), 7),
#  ('fd411b0e-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 90, 1, datetime.datetime(2013, 3, 2, 17, 22, 59), datetime.datetime(2013, 10, 26, 13, 47, 8), 20),
#  ('fd411b86-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 90, None, datetime.datetime(2013, 3, 3, 14, 12, 39), datetime.datetime(2013, 3, 17, 12, 33, 43), 9),
#  ('fd411f00-7144-11e5-ba71-058fbc01cf0b', 'Cardigan Welsh Corgi', 30, None, datetime.datetime(2013, 3, 2, 18, 3, 4), datetime.datetime(2013, 3, 2, 18, 59, 10), 6),
#  ('fd412022-7144-11e5-ba71-058fbc01cf0b', 'Bernese Mountain Dog', 110, None, datetime.datetime(2013, 3, 2, 20, 39, 46), datetime.datetime(2013, 3, 2, 20, 52, 32), 4),
#  ('fd412112-7144-11e5-ba71-058fbc01cf0b', 'Boxer', 60, None, datetime.datetime(2013, 7, 26, 15, 52, 9), datetime.datetime(2013, 8, 3, 17, 35, 56), 14),
#  ('fd41218a-7144-11e5-ba71-058fbc01cf0b', 'Boxer', 60, None, datetime.datetime(2013, 3, 5, 22, 45, 50), datetime.datetime(2013, 3, 5, 22, 45, 50), 1),
#  ('fd412aae-7144-11e5-ba71-058fbc01cf0b', 'Poodle', 10, None, datetime.datetime(2013, 4, 23, 2, 59, 36), datetime.datetime(2013, 4, 26, 3, 38, 5), 9),
#  ('fd414674-7144-11e5-ba71-058fbc01cf0b', 'Shetland Sheepdog', 10, 1, datetime.datetime(2013, 3, 2, 21, 10, 9), datetime.datetime(2013, 3, 7, 1, 32, 32), 20),
#  ('fd4146f6-7144-11e5-ba71-058fbc01cf0b', 'Shetland Sheepdog', 10, 1, datetime.datetime(2013, 3, 2, 21, 27, 15), datetime.datetime(2013, 3, 7, 2, 9, 27), 20),
#  ('fd414764-7144-11e5-ba71-058fbc01cf0b', 'Cavalier King Charles Spaniel', 10, None, datetime.datetime(2013, 5, 3, 15, 24, 39), datetime.datetime(2013, 8, 26, 14, 23, 59), 20),
#  ('fd4147e6-7144-11e5-ba71-058fbc01cf0b', 'Beagle', 20, None, datetime.datetime(2013, 3, 2, 21, 37, 42), datetime.datetime(2013, 3, 2, 23, 8, 52), 20),
#  ('fd414b1a-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 50, None, datetime.datetime(2013, 3, 5, 23, 24, 25), datetime.datetime(2013, 3, 5, 23, 39, 53), 4),
#  ('fd414b92-7144-11e5-ba71-058fbc01cf0b', 'French Bulldog', 20, None, datetime.datetime(2013, 3, 2, 22, 16, 24), datetime.datetime(2013, 3, 2, 23, 40, 4), 20),
#  ('fd4151f0-7144-11e5-ba71-058fbc01cf0b', 'Shetland Sheepdog', 20, None, datetime.datetime(2013, 3, 3, 22, 49, 1), datetime.datetime(2013, 8, 1, 21, 3, 2), 7),
#  ('fd4152d6-7144-11e5-ba71-058fbc01cf0b', 'Pomeranian', 0, None, datetime.datetime(2013, 3, 3, 22, 50, 34), datetime.datetime(2013, 3, 5, 1, 59, 36), 20),
#  ('fd41534e-7144-11e5-ba71-058fbc01cf0b', 'Poodle', 40, None, datetime.datetime(2013, 3, 12, 1, 21, 41), datetime.datetime(2013, 4, 14, 18, 37, 50), 7),
#  ('fd41551a-7144-11e5-ba71-058fbc01cf0b', 'Yorkshire Terrier', 0, None, datetime.datetime(2013, 3, 3, 2, 57, 23), datetime.datetime(2013, 3, 13, 1, 53), 7),
#  ('fd415588-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 10, None, datetime.datetime(2013, 3, 3, 18, 22, 12), datetime.datetime(2013, 3, 3, 18, 22, 12), 1),
#  ('fd415754-7144-11e5-ba71-058fbc01cf0b', 'Border Collie', 40, None, datetime.datetime(2013, 3, 4, 9, 56, 51), datetime.datetime(2013, 3, 28, 9, 45, 21), 20),
#  ('fd41583a-7144-11e5-ba71-058fbc01cf0b', 'Dalmatian', 30, None, datetime.datetime(2013, 3, 3, 12, 28, 1), datetime.datetime(2015, 1, 7, 17, 15, 19), 25),
#  ('fd415a7e-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog-Beagle Mix', 50, 1, datetime.datetime(2013, 3, 3, 21, 9, 43), datetime.datetime(2014, 5, 4, 1, 0, 10), 20),
#  ('fd415af6-7144-11e5-ba71-058fbc01cf0b', 'Siberian Husky', 50, None, datetime.datetime(2013, 3, 17, 17, 34, 32), datetime.datetime(2013, 8, 11, 16, 29, 50), 20),
#  ('fd415ea2-7144-11e5-ba71-058fbc01cf0b', 'Yorkshire Terrier', 0, None, datetime.datetime(2013, 3, 3, 18, 52, 5), datetime.datetime(2013, 3, 3, 19, 12, 33), 2),
#  ('fd416050-7144-11e5-ba71-058fbc01cf0b', 'Affenpinscher', 0, None, datetime.datetime(2013, 3, 3, 19, 35, 53), datetime.datetime(2013, 3, 5, 3, 4, 8), 20),
#  ('fd416104-7144-11e5-ba71-058fbc01cf0b', 'Maltese', 0, None, datetime.datetime(2013, 3, 3, 20, 14, 7), datetime.datetime(2013, 3, 5, 0, 5, 12), 20),
#  ('fd416320-7144-11e5-ba71-058fbc01cf0b', 'Scottish Terrier', 30, None, datetime.datetime(2013, 3, 4, 2, 17, 33), datetime.datetime(2015, 3, 27, 2, 10, 15), 22),
#  ('fd4163d4-7144-11e5-ba71-058fbc01cf0b', 'English Setter', 20, None, datetime.datetime(2013, 3, 3, 20, 44, 4), datetime.datetime(2013, 3, 23, 10, 23, 44), 5),
#  ('fd4166a4-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 100, None, datetime.datetime(2013, 3, 3, 21, 18, 50), datetime.datetime(2013, 3, 17, 20, 16, 52), 20),
#  ('fd416d48-7144-11e5-ba71-058fbc01cf0b', 'Havanese', 20, None, datetime.datetime(2013, 3, 4, 4, 6, 16), datetime.datetime(2013, 3, 4, 4, 20, 13), 4),
#  ('fd416dc0-7144-11e5-ba71-058fbc01cf0b', 'Havanese', 10, None, datetime.datetime(2013, 3, 4, 4, 26, 9), datetime.datetime(2013, 3, 4, 4, 37, 9), 4),
#  ('fd416e38-7144-11e5-ba71-058fbc01cf0b', 'Havanese', 10, None, datetime.datetime(2013, 3, 4, 3, 47, 35), datetime.datetime(2013, 3, 4, 3, 58, 21), 4),
#  ('fd416eb0-7144-11e5-ba71-058fbc01cf0b', 'Border Terrier', 10, None, datetime.datetime(2013, 3, 20, 17, 14, 11), datetime.datetime(2013, 7, 14, 20, 42, 12), 20),
#  ('fd416f1e-7144-11e5-ba71-058fbc01cf0b', 'Border Terrier', 10, None, datetime.datetime(2013, 3, 20, 17, 40, 24), datetime.datetime(2013, 7, 14, 20, 17, 11), 20),
#  ('fd416f96-7144-11e5-ba71-058fbc01cf0b', 'Border Terrier', 10, None, datetime.datetime(2013, 3, 20, 17, 57, 4), datetime.datetime(2013, 7, 14, 21, 15, 27), 20),
#  ('fd417072-7144-11e5-ba71-058fbc01cf0b', 'Australian Shepherd', 50, None, datetime.datetime(2013, 3, 5, 2, 27, 4), datetime.datetime(2013, 7, 8, 1, 34, 23), 27),
#  ('fd417158-7144-11e5-ba71-058fbc01cf0b', 'Bulldog', 40, None, datetime.datetime(2013, 3, 5, 0, 45, 29), datetime.datetime(2013, 3, 14, 19, 33, 56), 6),
#  ('fd41739c-7144-11e5-ba71-058fbc01cf0b', 'Cardigan Welsh Corgi', 30, None, datetime.datetime(2013, 3, 4, 16, 5, 46), datetime.datetime(2013, 3, 4, 17, 23, 37), 20),
#  ('fd4176c6-7144-11e5-ba71-058fbc01cf0b', 'Russell Terrier', 20, None, datetime.datetime(2013, 3, 5, 1, 7, 10), datetime.datetime(2013, 3, 10, 18, 9, 39), 16),
#  ('fd4177ac-7144-11e5-ba71-058fbc01cf0b', 'Greyhound', 70, None, datetime.datetime(2013, 3, 5, 0, 39, 24), datetime.datetime(2013, 3, 7, 19, 58, 55), 20),
#  ('fd4179f0-7144-11e5-ba71-058fbc01cf0b', 'American Water Spaniel', 20, None, datetime.datetime(2013, 3, 18, 23, 57, 4), datetime.datetime(2013, 6, 30, 0, 48, 28), 20),
#  ('fd417d1a-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 90, None, datetime.datetime(2013, 3, 5, 3, 33, 29), datetime.datetime(2013, 3, 7, 4, 16, 48), 20),
#  ('fd417e78-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 70, None, datetime.datetime(2013, 3, 5, 20, 58, 30), datetime.datetime(2013, 4, 16, 0, 22, 50), 6),
#  ('fd418044-7144-11e5-ba71-058fbc01cf0b', 'Poodle', 40, None, datetime.datetime(2013, 3, 10, 20, 42, 44), datetime.datetime(2013, 4, 21, 17, 12, 44), 20),
#  ('fd4186d4-7144-11e5-ba71-058fbc01cf0b', 'Cavalier King Charles Spaniel', 10, None, datetime.datetime(2013, 3, 9, 20, 49, 41), datetime.datetime(2013, 6, 1, 14, 50, 34), 26),
#  ('fd418756-7144-11e5-ba71-058fbc01cf0b', 'Mastiff', 130, None, datetime.datetime(2013, 5, 3, 21, 6, 5), datetime.datetime(2013, 5, 28, 19, 17, 52), 20),
# ...
#  ('fd4598d2-7144-11e5-ba71-058fbc01cf0b', 'Great Dane', 100, None, datetime.datetime(2013, 6, 2, 6, 39, 55), datetime.datetime(2013, 10, 7, 0, 35, 10), 11),
#  ('fd45992c-7144-11e5-ba71-058fbc01cf0b', 'Black Russian Terrier', 90, None, datetime.datetime(2014, 7, 17, 4, 31, 13), datetime.datetime(2014, 7, 17, 4, 43, 33), 4),
#  ('fd459990-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 60, None, datetime.datetime(2013, 6, 4, 22, 56), datetime.datetime(2013, 6, 4, 23, 5, 7), 3),
#  ('fd459a58-7144-11e5-ba71-058fbc01cf0b', 'Bulldog', 40, None, datetime.datetime(2013, 6, 2, 23, 51, 51), datetime.datetime(2014, 7, 7, 1, 29, 58), 5),
#  ('fd459b16-7144-11e5-ba71-058fbc01cf0b', 'Chihuahua', 0, None, datetime.datetime(2013, 6, 2, 22, 9, 52), datetime.datetime(2013, 6, 23, 0, 4, 31), 11),
#  ('fd459bf2-7144-11e5-ba71-058fbc01cf0b', 'Border Collie', 40, None, datetime.datetime(2013, 6, 2, 17, 54, 11), datetime.datetime(2013, 6, 3, 21, 18, 40), 20),
#  ('fd459d1e-7144-11e5-ba71-058fbc01cf0b', 'Doberman Pinscher', 70, None, datetime.datetime(2013, 6, 3, 3, 40, 35), datetime.datetime(2013, 6, 3, 4, 32, 36), 7),
#  ('fd459de6-7144-11e5-ba71-058fbc01cf0b', 'French Bulldog', 20, None, datetime.datetime(2013, 6, 9, 19, 6, 41), datetime.datetime(2013, 6, 9, 19, 25, 18), 4),
#  ('fd459f1c-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 50, None, datetime.datetime(2013, 6, 9, 20, 31, 30), datetime.datetime(2013, 6, 9, 20, 56, 54), 6),
#  ('fd45a4ee-7144-11e5-ba71-058fbc01cf0b', 'Papillon', 0, None, datetime.datetime(2013, 6, 3, 19, 47, 13), datetime.datetime(2013, 6, 29, 18, 16, 20), 15),
#  ('fd45a584-7144-11e5-ba71-058fbc01cf0b', 'Australian Shepherd', 40, None, datetime.datetime(2013, 6, 12, 0, 9, 53), datetime.datetime(2014, 4, 1, 1, 20, 15), 14),
#  ('fd45a84a-7144-11e5-ba71-058fbc01cf0b', 'Newfoundland', 140, None, datetime.datetime(2013, 6, 4, 3, 58, 27), datetime.datetime(2013, 6, 4, 4, 21, 18), 7),
#  ('fd45a8e0-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 80, None, datetime.datetime(2013, 6, 12, 20, 13, 10), datetime.datetime(2013, 6, 12, 20, 48, 4), 6),
#  ('fd45aba6-7144-11e5-ba71-058fbc01cf0b', 'Australian Cattle Dog', 40, None, datetime.datetime(2013, 6, 5, 23, 28, 19), datetime.datetime(2013, 6, 19, 11, 44, 58), 20),
#  ('fd45ad36-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 190, 1, datetime.datetime(2013, 6, 4, 18, 7, 7), datetime.datetime(2013, 6, 4, 18, 19, 50), 7),
#  ('fd45ada4-7144-11e5-ba71-058fbc01cf0b', 'BullBoxer', 10, None, datetime.datetime(2013, 6, 4, 18, 30, 13), datetime.datetime(2013, 6, 4, 18, 54, 21), 4),
#  ('fd45ae08-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 180, 1, datetime.datetime(2013, 6, 4, 18, 53, 41), datetime.datetime(2014, 5, 29, 14, 44), 32),
#  ('fd45aeda-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 190, 1, datetime.datetime(2013, 6, 4, 18, 51, 18), datetime.datetime(2013, 6, 20, 20, 15, 40), 21),
#  ('fd45af3e-7144-11e5-ba71-058fbc01cf0b', 'Maltese', 0, None, datetime.datetime(2013, 6, 4, 23, 41, 25), datetime.datetime(2013, 6, 4, 23, 59, 46), 4),
#  ('fd45afac-7144-11e5-ba71-058fbc01cf0b', 'Border Collie', 30, None, datetime.datetime(2013, 6, 4, 19, 56, 24), datetime.datetime(2013, 6, 4, 20, 1, 33), 2),
#  ('fd45b010-7144-11e5-ba71-058fbc01cf0b', 'Australian Shepherd', 40, None, datetime.datetime(2013, 6, 4, 20, 45, 23), datetime.datetime(2014, 4, 30, 22, 20, 14), 4),
#  ('fd45b074-7144-11e5-ba71-058fbc01cf0b', 'Border Collie', 20, None, datetime.datetime(2013, 6, 6, 1, 26, 32), datetime.datetime(2013, 8, 1, 1, 34, 26), 11),
#  ('fd45b1a0-7144-11e5-ba71-058fbc01cf0b', 'Border Collie', 20, None, datetime.datetime(2013, 6, 6, 13, 48, 1), datetime.datetime(2013, 8, 7, 17, 39, 30), 11),
#  ('fd45b330-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 60, None, datetime.datetime(2013, 6, 6, 1, 39, 10), datetime.datetime(2013, 6, 17, 1, 53, 9), 20),
#  ('fd45b394-7144-11e5-ba71-058fbc01cf0b', 'Mixed', 40, None, datetime.datetime(2013, 6, 7, 15, 29, 3), datetime.datetime(2013, 6, 7, 16, 8, 34), 7),
#  ('fd45b4b6-7144-11e5-ba71-058fbc01cf0b', 'Mixed', 40, None, datetime.datetime(2013, 6, 5, 17, 18, 39), datetime.datetime(2013, 6, 5, 17, 27, 59), 4),
#  ('fd45b5d8-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 70, 0, datetime.datetime(2013, 6, 6, 2, 28, 5), datetime.datetime(2013, 8, 21, 2, 11, 22), 20),
#  ('fd45b63c-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 70, None, datetime.datetime(2013, 6, 6, 2, 48, 55), datetime.datetime(2013, 11, 6, 2, 41, 20), 11),
#  ('fd45b6a0-7144-11e5-ba71-058fbc01cf0b', 'Doberman Pinscher', 60, None, datetime.datetime(2013, 6, 6, 16, 16, 27), datetime.datetime(2013, 6, 9, 1, 8, 32), 20),
#  ('fd45b8e4-7144-11e5-ba71-058fbc01cf0b', 'Soft Coated Wheaten Terrier', 30, None, datetime.datetime(2013, 6, 8, 14, 40, 14), datetime.datetime(2013, 6, 8, 14, 43, 36), 2),
#  ('fd45b948-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 70, None, datetime.datetime(2014, 1, 2, 0, 56, 56), datetime.datetime(2014, 1, 2, 0, 56, 56), 1),
#  ('fd45b9a2-7144-11e5-ba71-058fbc01cf0b', 'Glen of Imaal Terrier', 30, None, datetime.datetime(2013, 8, 8, 19, 26, 56), datetime.datetime(2014, 3, 28, 3, 11, 23), 24),
#  ('fd45ba06-7144-11e5-ba71-058fbc01cf0b', 'Russell Terrier', 10, None, datetime.datetime(2013, 8, 13, 22, 26, 14), datetime.datetime(2013, 9, 9, 21, 32, 42), 11),
#  ('fd45ba6a-7144-11e5-ba71-058fbc01cf0b', 'Russell Terrier', 10, None, datetime.datetime(2013, 8, 13, 22, 39, 39), datetime.datetime(2013, 9, 9, 21, 37, 4), 11),
#  ('fd45bf1a-7144-11e5-ba71-058fbc01cf0b', 'Boxer-Ibizan Hound Mix', 50, None, datetime.datetime(2013, 6, 10, 23, 17, 23), datetime.datetime(2013, 6, 10, 23, 20, 46), 2),
#  ('fd45bf7e-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever-Dachshund Mix', 20, None, datetime.datetime(2013, 6, 13, 13, 19, 20), datetime.datetime(2013, 6, 13, 13, 53, 56), 7),
#  ('fd45c03c-7144-11e5-ba71-058fbc01cf0b', 'Japanese Chin', 0, None, datetime.datetime(2013, 6, 18, 19, 46, 18), datetime.datetime(2013, 6, 27, 20, 58, 40), 16),
#  ('fd45c0a0-7144-11e5-ba71-058fbc01cf0b', 'Japanese Chin', 0, None, datetime.datetime(2013, 6, 18, 20, 5, 57), datetime.datetime(2013, 6, 27, 20, 21, 40), 16),
#  ('fd45c104-7144-11e5-ba71-058fbc01cf0b', 'Yorkshire Terrier-Maltese Mix', 0, 1, datetime.datetime(2013, 6, 6, 16, 58, 48), datetime.datetime(2013, 6, 7, 4, 5, 44), 20),
#  ('fd45c4d8-7144-11e5-ba71-058fbc01cf0b', 'Pomeranian', 10, None, datetime.datetime(2013, 6, 10, 19, 53, 47), datetime.datetime(2013, 6, 23, 19, 54, 2), 20),
#  ('fd45c7d0-7144-11e5-ba71-058fbc01cf0b', 'Rhodesian Ridgeback', 70, None, datetime.datetime(2014, 7, 28, 1, 12, 42), datetime.datetime(2014, 7, 29, 2, 8, 25), 7),
#  ('fd45c834-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 50, None, datetime.datetime(2014, 7, 28, 1, 17, 7), datetime.datetime(2014, 7, 28, 1, 43, 50), 7),
#  ('fd45ce2e-7144-11e5-ba71-058fbc01cf0b', 'Pug', 10, None, datetime.datetime(2013, 6, 8, 16, 26, 5), datetime.datetime(2013, 8, 31, 15, 20, 29), 23),
#  ('fd45d2a2-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 60, None, datetime.datetime(2013, 6, 8, 17, 59, 37), datetime.datetime(2013, 8, 31, 15, 2, 33), 23),
#  ('fd45d3ba-7144-11e5-ba71-058fbc01cf0b', 'Mixed', 30, None, datetime.datetime(2013, 6, 9, 18, 20, 20), datetime.datetime(2014, 10, 3, 16, 57, 10), 43),
#  ('fd45d66c-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 50, None, datetime.datetime(2013, 6, 8, 19, 59, 53), datetime.datetime(2013, 7, 7, 18, 36, 12), 14),
#  ('fd45d6ee-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 40, None, datetime.datetime(2013, 6, 8, 20, 15, 21), datetime.datetime(2013, 7, 7, 18, 42, 21), 14),
#  ('fd45da7c-7144-11e5-ba71-058fbc01cf0b', 'German Shorthaired Pointer', 60, None, datetime.datetime(2013, 6, 8, 21, 18, 7), datetime.datetime(2013, 9, 22, 19, 17, 19), 7),
#  ('fd45ddba-7144-11e5-ba71-058fbc01cf0b', 'Mixed', 20, None, datetime.datetime(2013, 6, 8, 19, 14, 32), datetime.datetime(2013, 6, 8, 20, 5, 40), 5),
#  ('fd45ea9e-7144-11e5-ba71-058fbc01cf0b', 'Mixed', 10, None, datetime.datetime(2013, 6, 9, 2, 50, 1), datetime.datetime(2013, 6, 9, 3, 21, 55), 7),
#  ('fd45eb98-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 70, None, datetime.datetime(2013, 6, 9, 4, 26, 2), datetime.datetime(2013, 6, 9, 4, 26, 2), 1),
#  ('fd45ecba-7144-11e5-ba71-058fbc01cf0b', 'Pug', 10, None, datetime.datetime(2013, 6, 14, 14, 23, 14), datetime.datetime(2013, 6, 19, 14, 48, 18), 20),
#  ('fd45ed1e-7144-11e5-ba71-058fbc01cf0b', 'Border Collie', 30, None, datetime.datetime(2013, 6, 9, 12, 47), datetime.datetime(2014, 7, 31, 13, 55, 12), 21),
#  ('fd45ede6-7144-11e5-ba71-058fbc01cf0b', 'Chesapeake Bay Retriever', 60, None, datetime.datetime(2013, 6, 10, 12, 34, 5), datetime.datetime(2013, 6, 10, 13, 17, 42), 7),
#  ('fd45ee4a-7144-11e5-ba71-058fbc01cf0b', 'Dachshund', 10, None, datetime.datetime(2013, 6, 9, 14, 35, 31), datetime.datetime(2013, 6, 9, 18, 5, 23), 20),
#  ('fd45ef08-7144-11e5-ba71-058fbc01cf0b', 'Basset Hound', 50, None, datetime.datetime(2013, 6, 9, 17, 16, 51), datetime.datetime(2013, 6, 9, 17, 28, 43), 4),
#  ('fd45f034-7144-11e5-ba71-058fbc01cf0b', 'Dachshund', 10, None, datetime.datetime(2013, 6, 9, 19, 21, 44), datetime.datetime(2013, 6, 9, 19, 53, 30), 7),
#  ('fd45f08e-7144-11e5-ba71-058fbc01cf0b', 'Mixed', 30, None, datetime.datetime(2013, 6, 10, 8, 33, 8), datetime.datetime(2013, 6, 10, 9, 10, 6), 7),
#  ('fd45f1b0-7144-11e5-ba71-058fbc01cf0b', 'Yorkshire Terrier', 0, None, datetime.datetime(2013, 6, 10, 22, 52, 39), datetime.datetime(2013, 6, 10, 23, 37, 5), 7),
#  ('fd45f214-7144-11e5-ba71-058fbc01cf0b', 'Boxer-Vizsla Mix', 60, None, datetime.datetime(2013, 6, 10, 10, 57, 55), datetime.datetime(2013, 6, 11, 1, 46, 17), 3),
#  ('fd45f462-7144-11e5-ba71-058fbc01cf0b', 'Shih Tzu', 190, 1, datetime.datetime(2013, 6, 10, 15, 21, 50), datetime.datetime(2013, 6, 10, 16, 7, 48), 20),
#  ('fd45f52a-7144-11e5-ba71-058fbc01cf0b', 'Border Collie', 30, None, datetime.datetime(2013, 6, 10, 17, 15, 12), datetime.datetime(2013, 6, 10, 17, 29, 15), 4),
#  ('fd45f58e-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 90, None, datetime.datetime(2013, 6, 16, 18, 52, 5), datetime.datetime(2013, 6, 16, 19, 0, 26), 2),
#  ('fd45f5f2-7144-11e5-ba71-058fbc01cf0b', 'Pembroke Welsh Corgi', 30, 1, datetime.datetime(2013, 6, 11, 3, 12, 36), datetime.datetime(2013, 6, 12, 4, 33, 22), 20),
#  ('fd45f714-7144-11e5-ba71-058fbc01cf0b', "I Don't Know", 60, None, datetime.datetime(2013, 6, 10, 21, 44, 59), datetime.datetime(2013, 6, 10, 21, 59, 20), 4),
#  ('fd45f778-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 70, None, datetime.datetime(2013, 6, 10, 21, 47, 59), datetime.datetime(2013, 6, 17, 22, 57, 50), 14),
#  ('fd45f89a-7144-11e5-ba71-058fbc01cf0b', 'Labradoodle', 80, None, datetime.datetime(2013, 6, 11, 0, 47, 21), datetime.datetime(2013, 6, 11, 1, 33, 44), 5),
#  ('fd45fae8-7144-11e5-ba71-058fbc01cf0b', 'Standard Schnauzer', 30, None, datetime.datetime(2013, 6, 11, 21, 20, 28), datetime.datetime(2013, 6, 22, 2, 10, 10), 7),
#  ('fd45fc14-7144-11e5-ba71-058fbc01cf0b', 'Chihuahua', 0, None, datetime.datetime(2013, 6, 11, 22, 27, 24), datetime.datetime(2013, 6, 11, 22, 27, 24), 1),
#  ('fd45fd72-7144-11e5-ba71-058fbc01cf0b', 'German Shorthaired Pointer', 80, None, datetime.datetime(2013, 6, 11, 23, 6, 21), datetime.datetime(2013, 6, 12, 1, 30, 17), 6),
#  ('fd460010-7144-11e5-ba71-058fbc01cf0b', 'Shiba Inu', 40, None, datetime.datetime(2013, 6, 14, 22, 41, 43), datetime.datetime(2013, 6, 23, 22, 27, 10), 5),
#  ('fd460308-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 50, None, datetime.datetime(2013, 7, 21, 19, 3, 52), datetime.datetime(2013, 7, 21, 19, 18, 46), 4),
#  ('fd46072c-7144-11e5-ba71-058fbc01cf0b', 'West Highland White Terrier', 10, None, datetime.datetime(2013, 6, 13, 3, 25, 7), datetime.datetime(2013, 6, 13, 3, 46, 45), 7),
#  ('fd4607ea-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 60, None, datetime.datetime(2013, 10, 28, 23, 8, 10), datetime.datetime(2013, 10, 28, 23, 8, 10), 1),
#  ('fd46084e-7144-11e5-ba71-058fbc01cf0b', 'Shiba Inu', 20, None, datetime.datetime(2013, 6, 27, 11, 34, 45), datetime.datetime(2013, 7, 12, 23, 5, 9), 10),
#  ('fd4608b2-7144-11e5-ba71-058fbc01cf0b', 'Collie', 40, None, datetime.datetime(2013, 7, 20, 21, 22), datetime.datetime(2015, 1, 29, 1, 11, 48), 20),
#  ('fd460916-7144-11e5-ba71-058fbc01cf0b', 'Collie', 60, None, datetime.datetime(2013, 7, 20, 20, 54, 51), datetime.datetime(2015, 1, 29, 1, 23, 42), 20),
#  ('fd46097a-7144-11e5-ba71-058fbc01cf0b', 'Pembroke Welsh Corgi', 20, None, datetime.datetime(2013, 6, 14, 0, 15, 56), datetime.datetime(2013, 6, 16, 1, 6, 41), 16),
#  ('fd460bd2-7144-11e5-ba71-058fbc01cf0b', 'Dalmatian', 30, None, datetime.datetime(2013, 6, 25, 22, 20, 12), datetime.datetime(2013, 6, 30, 0, 22, 40), 20),
#  ('fd460dbc-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 40, None, datetime.datetime(2013, 9, 24, 1, 9, 4), datetime.datetime(2015, 9, 18, 0, 8, 9), 38),
#  ('fd460e20-7144-11e5-ba71-058fbc01cf0b', 'Cavalier King Charles Spaniel', 20, None, datetime.datetime(2013, 6, 16, 15, 16, 58), datetime.datetime(2013, 9, 7, 17, 16, 19), 14),
#  ('fd460e84-7144-11e5-ba71-058fbc01cf0b', 'Russell Terrier', 10, None, datetime.datetime(2013, 6, 14, 16, 53, 47), datetime.datetime(2013, 6, 14, 17, 5, 59), 4),
#  ('fd460ee8-7144-11e5-ba71-058fbc01cf0b', 'Yorkshire Terrier', 0, None, datetime.datetime(2013, 6, 14, 17, 40, 12), datetime.datetime(2013, 6, 14, 17, 53, 3), 4),
#  ('fd460fa6-7144-11e5-ba71-058fbc01cf0b', 'Mixed', 40, 0, datetime.datetime(2013, 7, 1, 20, 15, 54), datetime.datetime(2014, 10, 7, 19, 12, 37), 26),
#  ('fd461384-7144-11e5-ba71-058fbc01cf0b', 'Miniature Schnauzer', 10, None, datetime.datetime(2013, 6, 23, 19, 54, 50), datetime.datetime(2013, 6, 23, 20, 10, 54), 4),
#  ('fd4613e8-7144-11e5-ba71-058fbc01cf0b', 'Yorkshire Terrier', 10, None, datetime.datetime(2013, 6, 16, 1, 15, 6), datetime.datetime(2013, 6, 16, 19, 37, 20), 4),
#  ('fd4614b0-7144-11e5-ba71-058fbc01cf0b', 'Cavalier King Charles Spaniel', 20, None, datetime.datetime(2013, 6, 21, 1, 34, 54), datetime.datetime(2014, 2, 7, 0, 17, 26), 20),
#  ('fd461514-7144-11e5-ba71-058fbc01cf0b', 'Cavalier King Charles Spaniel', 20, None, datetime.datetime(2014, 2, 12, 23, 51, 41), datetime.datetime(2014, 3, 10, 22, 30, 51), 9),
#  ('fd461578-7144-11e5-ba71-058fbc01cf0b', 'Great Dane', 120, None, datetime.datetime(2014, 6, 24, 2, 6, 53), datetime.datetime(2014, 6, 24, 2, 22, 53), 4),
#  ('fd4615dc-7144-11e5-ba71-058fbc01cf0b', 'Dachshund', 10, 1, datetime.datetime(2013, 6, 15, 17, 22, 11), datetime.datetime(2013, 6, 16, 17, 38, 5), 20),
#  ('fd4616a4-7144-11e5-ba71-058fbc01cf0b', 'Border Collie', 30, None, datetime.datetime(2013, 6, 16, 23, 6, 56), datetime.datetime(2013, 7, 2, 23, 36, 57), 20),
#  ('fd461708-7144-11e5-ba71-058fbc01cf0b', 'Collie', 50, None, datetime.datetime(2013, 6, 15, 20, 38, 38), datetime.datetime(2013, 6, 23, 20, 0, 37), 20),
#  ('fd46176c-7144-11e5-ba71-058fbc01cf0b', 'German Shepherd Dog', 90, 1, datetime.datetime(2013, 6, 30, 21, 25, 1), datetime.datetime(2013, 12, 25, 22, 51, 37), 13),
#  ('fd461b72-7144-11e5-ba71-058fbc01cf0b', 'Golden Retriever', 40, None, datetime.datetime(2013, 9, 21, 16, 28, 26), datetime.datetime(2013, 9, 21, 18, 49, 19), 6),
#  ('fd461c9e-7144-11e5-ba71-058fbc01cf0b', 'Portuguese Water Dog', 40, 0, datetime.datetime(2013, 6, 20, 1, 15, 7), datetime.datetime(2013, 7, 21, 21, 50, 15), 22),
#  ('fd461dca-7144-11e5-ba71-058fbc01cf0b', 'Australian Shepherd', 40, None, datetime.datetime(2013, 6, 22, 20, 51, 10), datetime.datetime(2013, 7, 12, 22, 29, 14), 20),
#  ('fd462086-7144-11e5-ba71-058fbc01cf0b', 'Poodle', 10, 1, datetime.datetime(2013, 6, 30, 14, 17, 38), datetime.datetime(2014, 5, 4, 14, 28, 36), 43),
#  ('fd4621a8-7144-11e5-ba71-058fbc01cf0b', 'Border Collie', 40, 1, datetime.datetime(2013, 7, 18, 16, 20, 54), datetime.datetime(2013, 10, 20, 0, 14, 14), 15),
#  ('fd4622c0-7144-11e5-ba71-058fbc01cf0b', 'Labrador Retriever', 60, None, datetime.datetime(2013, 6, 17, 22, 58, 20), datetime.datetime(2014, 7, 21, 22, 23, 16), 18),
#  ...]

# %% [markdown]
# There are a lot of these entries and there is no obvious feature that is common to all of them, so at present, we do not have a good reason to exclude them from our analysis.  Therefore, let's move on to question 10 now....
#
# **Question 10: Adapt the query in Question 7 to examine the relationship between breed_group and number of tests completed.  Exclude DogIDs with values of "1" in the exclude column. Your results should return 1774 DogIDs in the Herding breed group.**

# %%
# %%sql
#
# select breed_group, avg(total_tests.numtests) as avg_numtests, count(DISTINCT DogID)
# from (  select d.dog_guid as DogID, d.breed_group as breed_group, count(c.created_at) as numtests
#         from dogs d join complete_tests c on d.dog_guid = c.dog_guid
#         where d.exclude=0
#         group by DogID)
#     as total_tests
# group by breed_group
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 8 rows affected.
# [('', Decimal('22.1928'), 83),
#  ('Herding', Decimal('24.6000'), 25),
#  ('Hound', Decimal('26.8571'), 7),
#  ('Non-Sporting', Decimal('21.2500'), 4),
#  ('Sporting', Decimal('25.0476'), 21),
#  ('Terrier', Decimal('23.6000'), 5),
#  ('Toy', Decimal('21.0000'), 2),
#  ('Working', Decimal('28.7000'), 10)]

# %% [markdown]
# The results show there are non-NULL entries of empty strings in breed_group column again.  Ignoring them for now, Herding and Sporting breed_groups complete the most tests, while Toy breed groups complete the least tests.  This suggests that one avenue an analyst might want to explore further is whether it is worth it to target marketing or certain types of Dognition tests to dog owners with dogs in the Herding and Sporting breed_groups.  Later in this lesson we will discuss whether using a median instead of an average to summarize the number of completed tests might affect this potential course of action.
#
# **Question 11: Adapt the query in Question 10 to only report results for Sporting, Hound, Herding, and Working breed_groups using an IN clause.**

# %%
# %%sql
#
# select breed_group, avg(total_tests.numtests) as avg_numtests, count(DISTINCT DogID)
# from (  select d.dog_guid as DogID, d.breed_group as breed_group, count(c.created_at) as numtests
#         from dogs d join complete_tests c on d.dog_guid = c.dog_guid
#         where d.exclude=0
#         group by DogID)
#     as total_tests
# group by breed_group
# having breed_group in ("Sporting", "Hound", "Herding", "Working")
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 4 rows affected.
# [('Herding', Decimal('24.6000'), 25),
#  ('Hound', Decimal('26.8571'), 7),
#  ('Sporting', Decimal('25.0476'), 21),
#  ('Working', Decimal('28.7000'), 10)]

# %% [markdown]
# Next, let's examine the relationship between breed_type and number of completed tests.
#
# **Questions 12: Begin by writing a query that will output all of the distinct values in the breed_type field.**

# %%
# %%sql
#
# select DISTINCT(breed_type)
# from dogs;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 4 rows affected.
# [('Pure Breed',),
#  ("Mixed Breed/ Other/ I Don't Know",),
#  ('Cross Breed',),
#  ('Popular Hybrid',)]

# %% [markdown]
# **Question 13: Adapt the query in Question 7 to examine the relationship between breed_type and number of tests completed. Exclude DogIDs with values of "1" in the exclude column. Your results should return 8865 DogIDs in the Pure Breed group.**

# %%
# %%sql
#
# select breed_type, avg(total_tests.numtests) as avg_numtests, count(DISTINCT DogID)
# from (  select d.dog_guid as DogID, d.breed_type as breed_type, count(c.created_at) as numtests
#         from dogs d join complete_tests c on d.dog_guid = c.dog_guid
#         where d.exclude=0
#         group by DogID)
#     as total_tests
# group by breed_type
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 4 rows affected.
# [('Cross Breed', Decimal('21.0800'), 25),
#  ("Mixed Breed/ Other/ I Don't Know", Decimal('22.3404'), 47),
#  ('Popular Hybrid', Decimal('26.2500'), 8),
#  ('Pure Breed', Decimal('24.8831'), 77)]

# %% [markdown]
# There does not appear to be an appreciable difference between number of tests completed by dogs of different breed types.
#
#
# ## 3. Assess whether dog breeds and neutering are related to the number of tests completed
#
# To explore the results we found above a little further, let's run some queries that relabel the breed_types according to "Pure_Breed" and "Not_Pure_Breed".
#
# **Question 14: For each unique DogID, output its dog_guid, breed_type, number of completed tests, and use a CASE statement to include an extra column with a string that reads "Pure_Breed" whenever breed_type equals 'Pure Breed" and "Not_Pure_Breed" whenever breed_type equals anything else.  LIMIT your output to 50 rows for troubleshooting.**

# %%
# %%sql
#
# select d.dog_guid, d.breed_type, count(c.created_at) as num_tests,case when d.breed_type = 'Pure Breed' then "pure_breed" else "not_pure_breed" end as pure_breed
# from dogs d, complete_tests c
# where d.dog_guid = c.dog_guid
# group by d.dog_guid
# limit 50
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 50 rows affected.
# [('fd27b272-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 21, 'pure_breed'),
#  ('fd27b5ba-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 20, 'pure_breed'),
#  ('fd27b6b4-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 2, 'pure_breed'),
#  ('fd27b79a-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 11, 'pure_breed'),
#  ('fd27b86c-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 31, 'pure_breed'),
#  ('fd27b948-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 20, 'pure_breed'),
#  ('fd27ba1a-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 27, 'pure_breed'),
#  ('fd27bbbe-7144-11e5-ba71-058fbc01cf0b', "Mixed Breed/ Other/ I Don't Know", 20, 'not_pure_breed'),
#  ('fd27c1c2-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 20, 'pure_breed'),
#  ('fd27c5be-7144-11e5-ba71-058fbc01cf0b', 'Cross Breed', 20, 'not_pure_breed'),
#  ('fd27c74e-7144-11e5-ba71-058fbc01cf0b', 'Cross Breed', 14, 'not_pure_breed'),
#  ('fd27c7d0-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 20, 'pure_breed'),
#  ('fd27c852-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 20, 'pure_breed'),
#  ('fd27c8d4-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 20, 'pure_breed'),
#  ('fd27c956-7144-11e5-ba71-058fbc01cf0b', 'Cross Breed', 11, 'not_pure_breed'),
#  ('fd27cb72-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 20, 'pure_breed'),
#  ('fd27cd98-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 20, 'pure_breed'),
#  ('fd27ce1a-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 7, 'pure_breed'),
#  ('fd27cea6-7144-11e5-ba71-058fbc01cf0b', "Mixed Breed/ Other/ I Don't Know", 2, 'not_pure_breed'),
#  ('fd27cf28-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 20, 'pure_breed'),
#  ('fd27cfaa-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 7, 'pure_breed'),
#  ('fd27d02c-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 20, 'pure_breed'),
#  ('fd27d0b8-7144-11e5-ba71-058fbc01cf0b', 'Cross Breed', 21, 'not_pure_breed'),
#  ('fd27d144-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 7, 'pure_breed'),
#  ('fd27d1c6-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 7, 'pure_breed'),
#  ('fd27d248-7144-11e5-ba71-058fbc01cf0b', 'Popular Hybrid', 6, 'not_pure_breed'),
#  ('fd27d2ca-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 4, 'pure_breed'),
#  ('fd27d34c-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 4, 'pure_breed'),
#  ('fd27d3d8-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 4, 'pure_breed'),
#  ('fd27d45a-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 28, 'pure_breed'),
#  ('fd27d4dc-7144-11e5-ba71-058fbc01cf0b', "Mixed Breed/ Other/ I Don't Know", 28, 'not_pure_breed'),
#  ('fd27d770-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 25, 'pure_breed'),
#  ('fd27d9fa-7144-11e5-ba71-058fbc01cf0b', "Mixed Breed/ Other/ I Don't Know", 20, 'not_pure_breed'),
#  ('fd27db08-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 14, 'pure_breed'),
#  ('fd27db8a-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 16, 'pure_breed'),
#  ('fd27dc52-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 2, 'pure_breed'),
#  ('fd27dd38-7144-11e5-ba71-058fbc01cf0b', 'Cross Breed', 4, 'not_pure_breed'),
#  ('fd27e026-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 6, 'pure_breed'),
#  ('fd27e0d0-7144-11e5-ba71-058fbc01cf0b', "Mixed Breed/ Other/ I Don't Know", 6, 'not_pure_breed'),
#  ('fd27e1e8-7144-11e5-ba71-058fbc01cf0b', 'Cross Breed', 20, 'not_pure_breed'),
#  ('fd27e31e-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 23, 'pure_breed'),
#  ('fd27e454-7144-11e5-ba71-058fbc01cf0b', "Mixed Breed/ Other/ I Don't Know", 45, 'not_pure_breed'),
#  ('fd27e580-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 33, 'pure_breed'),
#  ('fd27e9a4-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 22, 'pure_breed'),
#  ('fd27eae4-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 4, 'pure_breed'),
#  ('fd27ed46-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 25, 'pure_breed'),
#  ('fd27efb2-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 20, 'pure_breed'),
#  ('fd27f110-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 7, 'pure_breed'),
#  ('fd27f25a-7144-11e5-ba71-058fbc01cf0b', 'Cross Breed', 6, 'not_pure_breed'),
#  ('fd27f4c6-7144-11e5-ba71-058fbc01cf0b', 'Pure Breed', 4, 'pure_breed')]

# %% [markdown]
# **Question 15: Adapt your queries from Questions 7 and 14 to examine the relationship between breed_type and number of tests completed by Pure_Breed dogs and non_Pure_Breed dogs.  Your results should return 8336 DogIDs in the Not_Pure_Breed group.**

# %%
# %%sql
# select pure_table.pure_breed as pure_breed, AVG(pure_table.num_tests) as avg_numtests, count(DISTINCT DogID)
# from (  select d.dog_guid as DogID, d.breed_type, count(c.created_at) as num_tests,case when d.breed_type = 'Pure Breed' then "pure_breed" else "not_pure_breed" end as pure_breed
#       from dogs d, complete_tests c
#       where d.dog_guid = c.dog_guid
#       group by DogID) as pure_table
#
# group by pure_breed;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 2 rows affected.
# [('not_pure_breed', Decimal('10.6841'), 8640),
#  ('pure_breed', Decimal('10.7819'), 9346)]

# %% [markdown]
# **Question 16: Adapt your query from Question 15 to examine the relationship between breed_type, whether or not a dog was neutered (indicated in the dog_fixed field), and number of tests completed by Pure_Breed dogs and non_Pure_Breed dogs. There are DogIDs with null values in the dog_fixed column, so your results should have 6 rows, and the average number of tests completed by non-pure-breeds who are neutered is 10.5681.**

# %%
# %%sql
# select pure_table.pure_breed as pure_breed, neutered, AVG(pure_table.num_tests) as avg_numtests, count(DISTINCT DogID)
# from (  select d.dog_guid as DogID,d.dog_fixed as neutered, d.breed_group, count(c.created_at) as num_tests,case when d.breed_type = 'Pure Breed' then "pure_breed" else "not_pure_breed" end as pure_breed
#       from dogs d, complete_tests c
#       where d.dog_guid = c.dog_guid
#       group by DogID) as pure_table
#
# group by pure_breed, neutered;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 6 rows affected.
# [('not_pure_breed', None, Decimal('10.0505'), 99),
#  ('not_pure_breed', 0, Decimal('9.1250'), 632),
#  ('not_pure_breed', 1, Decimal('10.8167'), 7909),
#  ('pure_breed', None, Decimal('9.3379'), 145),
#  ('pure_breed', 0, Decimal('9.7763'), 1806),
#  ('pure_breed', 1, Decimal('11.0558'), 7395)]

# %% [markdown]
# These results suggest that although a dog's breed_type doesn't seem to have a strong relationship with how many tests a dog completed, neutered dogs, on average, seem to finish 1-2 more tests than non-neutered dogs.  It may be fruitful to explore further whether this effect is consistent across different segments of dogs broken up according to other variables.  If the effects are consistent, the next step would be to seek evidence that could clarify whether neutered dogs are finishing more tests due to traits that arise when a dog is neutered, or instead, whether owners who are more likely to neuter their dogs have traits that make it more likely they will want to complete more tests.
#
#
# ## 4. Other dog features that might be related to the number of tests completed, and a note about using averages as summary metrics
#
# Two other dog features included in our sPAP were speed of game completion and previous behavioral training.  Examing the relationship between the speed of game completion and number of games completed is best achieved through creating a scatter plot with a best fit line and/or running a statistical regression analysis.  It is possible to achieve the statistical regression analysis through very advanced SQL queries, but the strategy that would be required is outside the scope of this course.  Therefore, I would recommend exporting relevant data to a program like Tableau, R, or Matlab in order to assess the relationship between the speed of game completion and number of games completed.
#
# Unfortunately, there is no field available in the Dognition data that is relevant to a dog's previous behavioral training, so more data would need to be collected to examine whether previous behavioral training is related to the number of Dognition tests completed.
#
# One last issue I would like to address in this lesson is the issue of whether an average is a good summary to use to represent the values of a certain group.  Average calculations are very sensitive to extreme values, or outliers, in the data.  This video provides a nice demonstration of how sensitive averages can be:
#
# http://www.statisticslectures.com/topics/outliereffects/
#
# Ideally, you would summarize the data in a group using a median calculation when you either don't know the distribution of values in your data or you already know that outliers are present (the definition of median is covered in the video above).  Unfortunately, medians are more computationally intensive than averages, and there is no pre-made function that allows you to calculate medians using SQL.  If you wanted to calculate the median, you would need to use an advanced strategy such as the ones described here:
#
# https://www.periscopedata.com/blog/medians-in-sql.html
#
# Despite the fact there is no simple way to calculate medians using SQL, there is a way to get a hint about whether average values are likely to be wildly misleading.  As described in the first video (http://www.statisticslectures.com/topics/outliereffects/), strong outliers lead to large standard deviation values.  Fortunately, we *CAN* calculate standard deviations in SQL easily using the STDDEV function.  Therefore, it is good practice to include standard deviation columns with your outputs so that you have an idea whether the average values outputted by your queries are trustworthy.  Whenever standard deviations are a significant portion of the average values of a field, and certainly when standard deviations are larger than the average values of a field, it's a good idea to export your data to a program that can handle more sophisticated statistical analyses before you interpret any results too strongly.
#
# Let's practice including standard deviations in our queries and interpretting their values.
#
# **Question 17: Adapt your query from Question 7 to include a column with the standard deviation for the number of tests completed by each Dognition personality dimension.**

# %%
# %%sql
#
# select dimension, avg(total_tests.numtests) as avg_numtests, count(DISTINCT DogID), stddev(total_tests.numtests)
# from (  select d.dog_guid as DogID, d.dimension, count(c.created_at) as numtests
#         from dogs d join complete_tests c on d.dog_guid = c.dog_guid
#         where (dimension IS NOT NULL and dimension!='') and (d.exclude=0)
#         group by DogID)
#     as total_tests
# group by dimension
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 9 rows affected.
# [('ace', Decimal('24.6471'), 17, 6.97002976169347),
#  ('charmer', Decimal('24.2308'), 13, 6.588496340111955),
#  ('einstein', Decimal('25.6667'), 15, 7.3181661333667165),
#  ('expert', Decimal('25.6429'), 14, 7.137497989563318),
#  ('maverick', Decimal('23.0588'), 17, 6.475933620951945),
#  ('protodog', Decimal('24.7692'), 13, 7.895021275889354),
#  ('renaissance-dog', Decimal('25.6667'), 21, 8.509565113018315),
#  ('socialite', Decimal('26.0588'), 17, 9.371236268718885),
#  ('stargazer', Decimal('24.0000'), 16, 7.211102550927978)]

# %% [markdown]
# The standard deviations are all around 20-25% of the average values of each personality dimension, and they are not appreciably different across the personality dimensions, so the average values are likely fairly trustworthy.  Let's try calculating the standard deviation of a different measurement.
#
# **Question 18: Write a query that calculates the average amount of time it took each dog breed_type to complete all of the tests in the exam_answers table. Exclude negative durations from the calculation, and include a column that calculates the standard deviation of durations for each breed_type group:**

# %%
# %%sql
# select t.breed_type, count(t.DogID), avg(t.duration), stddev(t.duration)
# from (select d.dog_guid as DogID, d.breed_type, (e.end_time - e.start_time) as duration
# from dogs d, exam_answers e
# where d.dog_guid = e.dog_guid
# group by DogID ) as t
# where t.duration >= 0
# group by t.breed_type
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 4 rows affected.
# [('Cross Breed', 5413, Decimal('50590405.0793'), 765896794.6680926),
#  ("Mixed Breed/ Other/ I Don't Know", 9207, Decimal('43902206.0957'), 656566946.3576828),
#  ('Popular Hybrid', 1122, Decimal('60182851.4171'), 843748947.9661961),
#  ('Pure Breed', 18163, Decimal('47036718.4414'), 711909360.262947)]

# %% [markdown]
# Recommanded Answer

# %%
# %%sql
# SELECT d.breed_type AS breed_type, AVG(TIMESTAMPDIFF(minute,e.start_time,e.end_time)) AS AvgDuration, STDDEV(TIMESTAMPDIFF(minute,e.start_time,e.end_time)) AS StdDevDuration FROM dogs d JOIN exam_answers e
# ON d.dog_guid=e.dog_guid
# WHERE TIMESTAMPDIFF(minute,e.start_time,e.end_time)>0 GROUP BY breed_type;

# %% [markdown]
# This time many of the standard deviations have larger magnitudes than the average duration values.  This suggests  there are outliers in the data that are significantly impacting the reported average values, so the average values are not likely trustworthy. These data should be exported to another program for more sophisticated statistical analysis.
#
# **In the next lesson, we will write queries that assess the relationship between testing circumstances and the number of tests completed.  Until then, feel free to practice any additional queries you would like to below!**
