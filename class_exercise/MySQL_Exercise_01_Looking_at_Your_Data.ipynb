# %% [markdown]
# Copyright Jana Schaich Borg/Attribution-NonCommercial 4.0 International (CC BY-NC 4.0)

# %% [markdown]
# # MySQL Exercise 1: Welcome to your first notebook!
#
# Database interfaces vary greatly across platforms and companies.  The interface you will be using here, called Jupyter, is a web application designed for data science teams who need to create and share documents that share live code.  We will be taking advantage of Jupyter's ability to integrate instructional text with areas that allow you to write and run SQL queries.  In this course, you will practice writing queries about the Dognition data set in these Jupyter notebooks as I give you step-by-step instructions through written text.  Then once you are comfortable with the query syntax, you will practice writing queries about the Dillard's data set in Teradata Viewpoint's more traditional SQL interface, called SQL scratchpad. Your assessments each week will be based on the exercises you complete using the Dillard's dataset.
#
# Jupyter runs in a language called Python, so some of the commands you will run in these MySQL exercises will require incorporating small amounts of Python code, along with the MySQL query itself.  Python is a very popular programming language with many statistical and visualization libraries, so you will likely encounter it in other business analysis settings.  Since many data analysis projects do not use Python, however, I will point out to you what parts of the commands are specific to Python interfaces.
#
# ## The first thing you should do every time you start working with a database: load the SQL library
#
# Since Jupyter is run through Python, the first thing you need to do to start practicing SQL queries is load the SQL library.  To do this, type the following line of code into the empty cell below:
#
# ```python
# %load_ext sql
# ```

# %%
# %load_ext sql

# %% [markdown]
# The "%" in this line of code is syntax for Python, not SQL.  The "cell" I am referring to is the empty box area beside the "In [  ]:" you see on the left side of the screen.
#
# Once you've entered the line of code, press the "run" button on the Jupyter toolbar that looks like an arrow.  It's located under “cell” in the drop-down menu bar, and next to the stop button (the solid square).  The run button is outlined in red in this picture:
#
# ![alt text](https://duke.box.com/shared/static/u9chww13kim30t5p6ndh404d9ap6auwf.jpg)
#
# **TIP: Whenever instructions say “run” or "execute" a command in future exercises, type the appropriate code into the empty cell and execute it by pressing this same button with the arrow.**
#
# When the library has loaded, you will see a number between the brackets that preceed the line of code you executed:
#
# For example, it might look like this:
#
# ```
# In [2]:
# ```
#
#
# ## The second thing you must do every time you want to start working with a database: connect to the database you need to use.
#
# Now that the SQL library is loaded, we need to connect to a database.  The following command will log you into the MySQL server at localhost as the user 'studentuser' and will select the database named 'dognitiondb' :
#
# ```python
# mysql://studentuser:studentpw@localhost/dognitiondb
# ```
#
# However, to execute this command using SQL language instead of Python, you will need to begin the line of code with:
#
# ```python
# %sql
# ```
#
# Thus, the complete line of code is:
#
# ```python
# %sql mysql://studentuser:studentpw@localhost/dognitiondb
# ```
#
# Connect to the database by typing this command into the cell below, and running it (note: you can copy and paste the command from above rather than typing it, if you choose):

# %%
# %sql mysql://studentuser:studentpw@localhost/dognitiondb

# %% [markdown]
# <mark>***Every time you run a line of SQL code in Jupyter, you will need to preface the line with "%sql".  Remember to do this, even though I will not explicitly instruct you to do so for the rest of the exercises in this course.***</mark>
#
# Once you are connected, the output cell (which reads "Out" followed by brackets) will read: "Connected:studentuser@dognitiondb".  To make this the default database for our queries, run this "USE" command:
#
# ```python
# %sql USE dognitiondb
# ```

# %%
# %sql USE dognitiondb
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 0 rows affected.
# []

# %% [markdown]
# You are now ready to run queries in the Dognition database!
#
#
# ## The third thing you should do every time you start working with a new database: get to know your data
#
# The data sets you will be working with in business settings will be big.  REALLY big.  If you just start making queries without knowing what you are pulling out, you could hang up your servers or be staring at your computer for hours before you get an output.  Therefore, even if you are given an ER diagram or relational schema like we learned about in the first week of the course, before you start querying I strongly recommend that you (1) confirm how many tables each database has, and (2) identify the fields contained in each table of the database.  To determine how many tables each database has, use the SHOW command:
#
# ```mySQL
# SHOW tables
# ```
#
# **Try it yourself (TIP: if you get an error message, it's probably because you forgot to start the query with "%sql"):**

# %%
# %sql SHOW tables
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 6 rows affected.
# [('complete_tests',),
#  ('dogs',),
#  ('exam_answers',),
#  ('reviews',),
#  ('site_activities',),
#  ('users',)]

# %% [markdown]
# The output that appears above should show you there are six tables in the Dognition database.  To determine what columns or fields (we will use those terms interchangeably in this course) are in each table, you can use the SHOW command again, but this time (1) you have to clarify that you want to see columns instead of tables, and (2) you have to specify from which table you want to examine the columns.
#
# The syntax, which sounds very similar to what you would actually say in the spoken English language, looks like this:
#
# ```mySQL
# SHOW columns FROM (enter table name here)
# ```
# or if you have multiple databases loaded:
# ```mySQL
# SHOW columns FROM (enter table name here) FROM (enter database name here)
# ```
# or
# ```mySQL
# SHOW columns FROM databasename.tablename
# ```
# <mark> Whenever you have multiple databases loaded, you will need to specify which database a table comes from using one of the syntax options described above.</mark>
#
# As I said in the earlier "Introduction to Query Syntax" video, it makes it easier to read and troubleshoot your queries if you always write SQL keywords in UPPERCASE format and write your table and field names in their native format.  We will only use the most important SQL keywords in this course, but a full list can be found here:
#
# https://dev.mysql.com/doc/refman/5.7/en/keywords.html
#
#
# **Question 1: How many columns does the "dogs" table have?  Enter the appropriate query below to find out:**

# %%
# %sql show columns from dogs
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 21 rows affected.
# [('gender', 'varchar(255)', 'YES', '', None, ''),
#  ('birthday', 'varchar(255)', 'YES', '', None, ''),
#  ('breed', 'varchar(255)', 'YES', '', None, ''),
#  ('weight', 'int(11)', 'YES', '', None, ''),
#  ('dog_fixed', 'tinyint(1)', 'YES', '', None, ''),
#  ('dna_tested', 'tinyint(1)', 'YES', '', None, ''),
#  ('created_at', 'datetime', 'NO', '', None, ''),
#  ('updated_at', 'datetime', 'NO', '', None, ''),
#  ('dimension', 'varchar(255)', 'YES', '', None, ''),
#  ('exclude', 'tinyint(1)', 'YES', '', None, ''),
#  ('breed_type', 'varchar(255)', 'YES', '', None, ''),
#  ('breed_group', 'varchar(255)', 'YES', '', None, ''),
#  ('dog_guid', 'varchar(60)', 'YES', 'MUL', None, ''),
#  ('user_guid', 'varchar(60)', 'YES', 'MUL', None, ''),
#  ('total_tests_completed', 'varchar(255)', 'YES', '', None, ''),
#  ('mean_iti_days', 'varchar(255)', 'YES', '', None, ''),
#  ('mean_iti_minutes', 'varchar(255)', 'YES', '', None, ''),
#  ('median_iti_days', 'varchar(255)', 'YES', '', None, ''),
#  ('median_iti_minutes', 'varchar(255)', 'YES', '', None, ''),
#  ('time_diff_between_first_and_last_game_days', 'varchar(255)', 'YES', '', None, ''),
#  ('time_diff_between_first_and_last_game_minutes', 'varchar(255)', 'YES', '', None, '')]

# %% [markdown]
# You should have determined that the "dogs" table has 21 columns.
#
# An alternate way to learn the same information would be to use the DESCRIBE function.  The syntax is:
#
# ```mySQL
# DESCRIBE tablename
# ```
#
# **Question 2: Try using the DESCRIBE function to learn how many columns are in the "reviews" table:**

# %%
# %sql describe reviews
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 7 rows affected.
# [('rating', 'int(11)', 'YES', '', None, ''),
#  ('created_at', 'datetime', 'NO', '', None, ''),
#  ('updated_at', 'datetime', 'NO', '', None, ''),
#  ('user_guid', 'varchar(60)', 'YES', 'MUL', None, ''),
#  ('dog_guid', 'varchar(60)', 'YES', 'MUL', None, ''),
#  ('subcategory_name', 'varchar(60)', 'YES', '', None, ''),
#  ('test_name', 'varchar(60)', 'YES', '', None, '')]

# %% [markdown]
# You should have determined that there are 7 columns in the "reviews" table.
#
# The SHOW and DESCRIBE functions give a lot more information about the table than just how many columns, or fields, there are.  Indeed, the first column of the output shows the title of each field in the table.  The column next to that describes what type of data are stored in that column.  There are 3 main types of data in MySQL: text, number, and datetime.  There are many subtypes of data within these three general categories, as described here:
#
# https://www.hostgator.com/help/article/mysql-variable-types
#
# The next column in the SHOW/DESCRIBE output indicates whether null values can be stored in the field in the table.  The "Key" column of the output provides the following information about each field of data in the table being described (see https://dev.mysql.com/doc/refman/5.7/en/show-columns.html for more information):
#
# + Empty: the column either is not indexed or is indexed only as a secondary column in a multiple-column, nonunique index.
# + PRI: the column is a PRIMARY KEY or is one of the columns in a multiple-column PRIMARY KEY.
# + UNI: the column is the first column of a UNIQUE index.
# + MUL: the column is the first column of a nonunique index in which multiple occurrences of a given value are permitted within the column.
#
# The "Default" field of the output indicates the default value that is assigned to the field. The "Extra" field contains any additional information that is available about a given field in that table.
#
# **Questions 3-6: In the cells below, examine the fields in the other 4 tables of the Dognition database:**

# %%
# %sql describe complete_tests;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 6 rows affected.
# [('created_at', 'datetime', 'NO', '', None, ''),
#  ('updated_at', 'datetime', 'NO', '', None, ''),
#  ('user_guid', 'varchar(60)', 'YES', 'MUL', None, ''),
#  ('dog_guid', 'varchar(60)', 'YES', 'MUL', None, ''),
#  ('test_name', 'varchar(60)', 'YES', '', None, ''),
#  ('subcategory_name', 'varchar(60)', 'YES', '', None, '')]

# %%
# %sql describe exam_answers;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 8 rows affected.
# [('script_detail_id', 'int(11)', 'YES', '', None, ''),
#  ('subcategory_name', 'varchar(255)', 'YES', '', None, ''),
#  ('test_name', 'varchar(255)', 'YES', '', None, ''),
#  ('step_type', 'varchar(255)', 'YES', '', None, ''),
#  ('start_time', 'datetime', 'YES', '', None, ''),
#  ('end_time', 'datetime', 'YES', '', None, ''),
#  ('loop_number', 'int(11)', 'YES', '', None, ''),
#  ('dog_guid', 'varchar(60)', 'YES', '', None, '')]

# %%
# %sql show columns from site_activities;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 11 rows affected.
# [('activity_type', 'varchar(150)', 'YES', 'MUL', None, ''),
#  ('description', 'text', 'YES', '', None, ''),
#  ('membership_id', 'int(11)', 'YES', '', None, ''),
#  ('category_id', 'int(11)', 'YES', '', None, ''),
#  ('script_id', 'int(11)', 'YES', '', None, ''),
#  ('created_at', 'datetime', 'NO', '', None, ''),
#  ('updated_at', 'datetime', 'NO', '', None, ''),
#  ('user_guid', 'varchar(255)', 'YES', 'MUL', None, ''),
#  ('script_detail_id', 'int(11)', 'YES', '', None, ''),
#  ('test_name', 'varchar(255)', 'YES', '', None, ''),
#  ('dog_guid', 'varchar(255)', 'YES', 'MUL', None, '')]

# %%
# %sql show columns from users;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 16 rows affected.
# [('sign_in_count', 'int(11)', 'YES', '', '0', ''),
#  ('created_at', 'datetime', 'NO', '', None, ''),
#  ('updated_at', 'datetime', 'NO', '', None, ''),
#  ('max_dogs', 'int(11)', 'YES', '', '0', ''),
#  ('membership_id', 'int(11)', 'YES', '', None, ''),
#  ('subscribed', 'tinyint(1)', 'YES', '', '0', ''),
#  ('exclude', 'tinyint(1)', 'YES', '', None, ''),
#  ('free_start_user', 'tinyint(1)', 'YES', '', None, ''),
#  ('last_active_at', 'datetime', 'YES', '', None, ''),
#  ('membership_type', 'int(11)', 'YES', '', None, ''),
#  ('user_guid', 'text', 'YES', 'MUL', None, ''),
#  ('city', 'varchar(255)', 'YES', '', None, ''),
#  ('state', 'varchar(255)', 'YES', '', None, ''),
#  ('zip', 'varchar(255)', 'YES', '', None, ''),
#  ('country', 'varchar(255)', 'YES', '', None, ''),
#  ('utc_correction', 'varchar(255)', 'YES', '', None, '')]

# %% [markdown]
# As you examine the fields in each table, you will notice that none of the Dognition tables have primary keys declared.  However, take note of which fields say "MUL" in the "Key" column of the DESCRIBE output, because these columns can still be used to link tables together.  An important thing to keep in mind, though, is that because these linking columns were not configured as primary keys, it is possible the linking fields contain NULL values or duplicate rows.
#
# If you do not have a ER diagram or relational schema of the Dognition database yet, consider making one at this point, because you will need to refer back to table and column names constantly throughout designing your queries  (if you don't remember what primary keys, secondary keys, ER diagrams, or relational schemas are, review the material discussed in the first week of this course).  Some database interfaces do provide notes or visual representations about the information in each table for easy reference, but since the Jupyter interface does not provide this, take your own notes and make your own diagrams, and keep them handy.  As you will see, these diagrams and notes will save you a lot of time when you design your queries to pull data.
#
#
# ## Using SELECT to look at your raw data
#
# Once you have an idea of what is in your tables look like and how they might interact, it's a good idea to look at some of the raw data itself so that you are aware of any anomalies that could pose problems for your analysis or interpretations.  To do that, we will use arguably the most important SQL statement for analysts: the SELECT statement.
#
# SELECT is used anytime you want to retrieve data from a table.  In order to retrieve that data, you always have to provide at least two pieces of information:
#
#     (1) what you want to select, and
#     (2) from where you want to select it.
#
# I recommend that you always format your SQL code to ensure that these two pieces of information are on separate lines, so they are easy to identify quickly by eye.
#
# The skeleton of a SELECT statement looks like this:
#
# ```mySQL
# SELECT
# FROM
# ```
#
# To fill in the statement, you indicate the column names you are interested in after "SELECT" and the table name (and database name, if you have multiple databases loaded) you are drawing the information from after "FROM."  So in order to look at the breeds in the dogs table, you would execute the following command:
#
# ```mySQL
# SELECT breed
# FROM dogs;
# ```
#
# Remember:
# + SQL syntax and keywords are case insensitive.  I recommend that you always enter SQL keywords in upper case and table or column names in either lower case or their native format to make it easy to read and troubleshoot your code, but it is not a requirement to do so.  Table or column names are often case insensitive as well, but defaults may vary across database platforms so it's always a good idea to check.
# + Table or column names with spaces in them need to be surrounded by quotation marks in SQL.  MySQL accepts both double and single quotation marks, but some database systems only accept single quotation marks.  In all database systems, if a table or column name contains an SQL keyword, the name must be enclosed in backticks instead of quotation marks.
# > ` 'the marks that surrounds this phrase are single quotation marks' `
# > ` "the marks that surrounds this phrase are double quotation marks" `
# > `` `the marks that surround this phrase are backticks` ``
# + The semi-colon at the end of a query is only required when you have multiple separate queries saved in the same text file or editor.  That said, I recommend that you make it a habit to always include a semi-colon at the end of your queries.
#
# <mark>An important note for executing queries in Jupyter: in order to tell Python that you want to execute SQL language on multiple lines, you must include two percent signs in front of the SQL prefix instead of one.</mark>  Therefore, to execute the above query, you should enter:
#
# ```mySQL
# %%sql
# SELECT breed
# FROM dogs;
# ```
#
# When Jupyter is busy executing a query, you will see an asterisk in the brackets next to the output field:
#
# ```
# Out [*]
# ```
#
# When the query is completed, you will see a number in the brackets next to the output field.
#
# ```
# Out [5]
# ```
#
# **Try it yourself:**

# %%
# %%sql
# select breed
# from dogs;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 35050 rows affected.
# [('Labrador Retriever',),
#  ('Shetland Sheepdog',),
#  ('Golden Retriever',),
#  ('Golden Retriever',),
#  ('Shih Tzu',),
#  ('Siberian Husky',),
#  ('Shih Tzu',),
#  ('Mixed',),
#  ('Labrador Retriever',),
#  ('Shih Tzu-Poodle Mix',),
#  ('German Shepherd Dog-Pembroke Welsh Corgi Mix',),
#  ('Vizsla',),
#  ('Pug',),
#  ('Boxer',),
#  ('German Shepherd Dog-Nova Scotia Duck Tolling Retriever Mix',),
#  ('Beagle',),
#  ('Beagle',),
#  ('Beagle',),
#  ('Mixed',),
#  ('Chesapeake Bay Retriever',),
#  ('Border Collie',),
#  ('Belgian Malinois',),
#  ('Australian Shepherd-German Shepherd Dog Mix',),
#  ('Poodle',),
#  ('Poodle',),
#  ('Golden Doodle',),
#  ('Labrador Retriever',),
#  ('German Shepherd Dog',),
#  ('German Shepherd Dog',),
#  ('Weimaraner',),
#  ('Mixed',),
#  ('Bouvier des Flandres',),
#  ('Mixed',),
#  ('German Shepherd Dog',),
#  ('Beagle',),
#  ('Mudi',),
#  ('Parson Russell Terrier-Beagle Mix',),
#  ('Dalmatian',),
#  ("I Don't Know",),
#  ('Border Collie-Labrador Retriever Mix',),
#  ('Belgian Tervuren',),
#  ('Mixed',),
#  ('Labrador Retriever',),
#  ('Shih Tzu',),
#  ('Australian Terrier',),
#  ('Shih Tzu',),
#  ('Golden Retriever',),
#  ('Bernese Mountain Dog',),
#  ('Chihuahua- Mix',),
#  ('Shetland Sheepdog',),
#  ('Shetland Sheepdog',),
#  ('Mixed',),
#  ('Chihuahua-Dachshund Mix',),
#  ('Finnish Spitz',),
#  ('Siberian Husky',),
#  ('Rottweiler',),
#  ('Pembroke Welsh Corgi',),
#  ('Brussels Griffon',),
#  ('Mixed',),
#  ('French Bulldog',),
#  ('French Bulldog',),
#  ('Shih Tzu',),
#  ('Doberman Pinscher',),
#  ('German Shepherd Dog',),
#  ('Pembroke Welsh Corgi',),
#  ('English Cocker Spaniel-Cocker Spaniel Mix',),
#  ('Rottweiler',),
#  ('German Shepherd Dog',),
#  ('Cavalier King Charles Spaniel-Bichon Frise Mix',),
#  ('Shih Tzu',),
#  ('Bedlington Terrier',),
#  ('Labrador Retriever',),
#  ('Russell Terrier',),
#  ('Poodle',),
#  ('Irish Setter',),
#  ('German Shepherd Dog',),
#  ('Irish Setter',),
#  ('Poodle',),
#  ('Irish Red and White Setter',),
#  ('Poodle-Cocker Spaniel Mix',),
#  ('American Pit Bull Terrier',),
#  ('Golden Retriever',),
#  ('Beagle-Schipperke Mix',),
#  ('Greyhound',),
#  ('Labrador Retriever-Golden Retriever Mix',),
#  ('Labrador Retriever-Golden Retriever Mix',),
#  ('Labrador Retriever',),
#  ('Boston Terrier-Chihuahua Mix',),
#  ('American Pit Bull Terrier',),
#  ('Mixed',),
#  ('Beagle-Cavalier King Charles Spaniel Mix',),
#  ('Boxer',),
#  ('Pug',),
#  ('French Bulldog',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Labradoodle',),
#  ('Mixed',),
#  ('Pembroke Welsh Corgi',),
#  ('Golden Retriever',),
#  ('Cocker Spaniel',),
#  ('Mixed',),
#  ('Rottweiler',),
#  ('Labrador Retriever-Border Collie Mix',),
#  ('Lhasa Apso-Poodle Mix',),
#  ('Labradoodle',),
#  ('English Springer Spaniel',),
#  ('English Springer Spaniel',),
#  ('Mixed',),
#  ('Shih Tzu',),
#  ('Neapolitan Mastiff',),
#  ('Rat Terrier',),
#  ('Border Terrier',),
#  ('Collie-Shetland Sheepdog Mix',),
#  ('German Shepherd Dog',),
#  ('Dachshund',),
#  ('Dachshund',),
#  ('Golden Retriever-Collie Mix',),
#  ('Beagle',),
#  ('Labrador Retriever',),
#  ('American Eskimo Dog-Papillon Mix',),
#  ('Papillon',),
#  ('Pomeranian',),
#  ('German Shepherd Dog-Belgian Tervuren Mix',),
#  ('German Shepherd Dog',),
#  ('Maltese-Yorkshire Terrier Mix',),
#  ('Australian Shepherd',),
#  ('Shiba Inu',),
#  ('Rat Terrier',),
#  ('Poodle',),
#  ('Border Collie-Greyhound Mix',),
#  ('Poodle',),
#  ('Labradoodle',),
#  ('Mixed',),
#  ('Maltese-Poodle Mix',),
#  ('Siberian Husky-German Shepherd Dog Mix',),
#  ('Chihuahua',),
#  ('Golden Retriever-German Shepherd Dog Mix',),
#  ('Parson Russell Terrier',),
#  ('Rhodesian Ridgeback',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Chihuahua',),
#  ('West Highland White Terrier',),
#  ('Poodle-Miniature Schnauzer Mix',),
#  ('Maltese-Poodle Mix',),
#  ('Yorkshire Terrier-Poodle Mix',),
#  ('Vizsla',),
#  ('Golden Retriever',),
#  ('Labradoodle',),
#  ('Silky Terrier-Poodle Mix',),
#  ('Mixed',),
#  ('Russell Terrier-Miniature Pinscher Mix',),
#  ('Mixed',),
#  ('Bernese Mountain Dog',),
#  ('Bernese Mountain Dog',),
#  ('Bernese Mountain Dog',),
#  ('Yorkshire Terrier',),
#  ('Australian Cattle Dog- Mix',),
#  ('Mixed',),
#  ('Flat-Coated Retriever',),
#  ('Staffordshire Bull Terrier-Bulldog Mix',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Kooikerhondje',),
#  ('German Shepherd Dog',),
#  ('Labrador Retriever-Golden Retriever Mix',),
#  ('German Shepherd Dog-Border Collie Mix',),
#  ('Mixed',),
#  ('Golden Retriever',),
#  ('Mixed',),
#  ('German Shepherd Dog',),
#  ('Mixed',),
#  ('Labradoodle',),
#  ('Shih Tzu',),
#  ('American Staffordshire Terrier',),
#  ('Bulldog',),
#  ('Mixed',),
#  ('Labrador Retriever',),
#  ('Beagle',),
#  ('Beagle',),
#  ('Cardigan Welsh Corgi-German Shepherd Dog Mix',),
#  ('German Shepherd Dog',),
#  ('Doberman Pinscher',),
#  ('Doberman Pinscher-German Shepherd Dog Mix',),
#  ('Mixed',),
#  ('Shetland Sheepdog',),
#  ('Canaan Dog- Mix',),
#  ('Beagle',),
#  ('Rhodesian Ridgeback',),
#  ('Miniature Schnauzer',),
#  ('Russell Terrier-Pug Mix',),
#  ('Mixed',),
#  ('Australian Cattle Dog-Border Collie Mix',),
#  ('Mixed',),
#  ('Shih Tzu',),
#  ('Shih Tzu',),
#  ('English Cocker Spaniel',),
#  ('Australian Shepherd',),
#  ('Parson Russell Terrier',),
#  ('Boxer',),
#  ('German Shepherd Dog',),
#  ('Chihuahua-Dachshund Mix',),
#  ('Australian Cattle Dog',),
#  ('Border Collie-Australian Shepherd Mix',),
#  ('Shih Tzu',),
#  ('Miniature Schnauzer',),
#  ('Australian Shepherd-Border Collie Mix',),
#  ('Mixed',),
#  ('Poodle',),
#  ('Labrador Retriever',),
#  ('Mixed',),
#  ('French Spaniel',),
#  ('Mixed',),
#  ('Italian Greyhound',),
#  ('Weimaraner',),
#  ('Leonberger',),
#  ('Poodle',),
#  ('German Shepherd Dog',),
#  ('Mixed',),
#  ('Portuguese Water Dog',),
#  ('Boykin Spaniel',),
#  ('Mixed',),
#  ('Labrador Retriever',),
#  ('Soft Coated Wheaten Terrier',),
#  ('Poodle',),
#  ('Mixed',),
#  ('Mixed',),
#  ('German Shepherd Dog',),
#  ('Bulldog',),
#  ('Golden Retriever',),
#  ('Boston Terrier',),
#  ('Shih Tzu',),
#  ('Brittany',),
#  ('Bernese Mountain Dog',),
#  ('Golden Retriever-Labrador Retriever Mix',),
#  ('Mixed',),
#  ('Golden Retriever-Labrador Retriever Mix',),
#  ('Mixed',),
#  ('Australian Cattle Dog',),
#  ('Labrador Retriever-Chinese Shar-Pei Mix',),
#  ('Labrador Retriever',),
#  ('Nova Scotia Duck Tolling Retriever',),
#  ('Nova Scotia Duck Tolling Retriever',),
#  ('Mixed',),
#  ('Labrador Retriever',),
#  ('Labrador Retriever',),
#  ('Australian Shepherd',),
#  ('Mixed',),
#  ('Siberian Husky',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Lhasa Apso',),
#  ('Australian Shepherd',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Labrador Retriever',),
#  ('Mixed',),
#  ('American Eskimo Dog',),
#  ('Boxer',),
#  ('Keeshond',),
#  ('Bull Terrier',),
#  ('Soft Coated Wheaten Terrier',),
#  ('Boston Terrier',),
#  ('German Shepherd Dog',),
#  ('Poodle',),
#  ('German Shepherd Dog',),
#  ('Shih Tzu-Maltese Mix',),
#  ('Labrador Retriever',),
#  ('Chesapeake Bay Retriever',),
#  ('Mixed',),
#  ('Shih Tzu',),
#  ('Cocker Spaniel',),
#  ('Labrador Retriever',),
#  ('Maltese',),
#  ('Mixed',),
#  ('Cockapoo',),
#  ('Chihuahua-Miniature Pinscher Mix',),
#  ('German Shepherd Dog',),
#  ('Mixed',),
#  ('Shih Tzu',),
#  ('Shih Tzu',),
#  ('Australian Cattle Dog',),
#  ('Maltese-Poodle Mix',),
#  ('Maltese-Shih Tzu Mix',),
#  ('Mixed',),
#  ('Boxer',),
#  ('Dachshund-Miniature Pinscher Mix',),
#  ('Mixed',),
#  ('Miniature American Shepherd',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Golden Retriever',),
#  ('Parson Russell Terrier',),
#  ('Border Collie',),
#  ('German Shepherd Dog',),
#  ('Labrador Retriever-Australian Cattle Dog Mix',),
#  ('Poodle',),
#  ('Shih Tzu',),
#  ('Shih Tzu',),
#  ('Mixed',),
#  ('Mixed',),
#  ("I Don't Know",),
#  ('Border Collie',),
#  ('Golden Retriever',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Chihuahua',),
#  ('Australian Shepherd',),
#  ('Poodle',),
#  ('Affenpinscher',),
#  ('Keeshond',),
#  ('Chihuahua',),
#  ('English Setter',),
#  ('Miniature Schnauzer-Poodle Mix',),
#  ('Mixed',),
#  ('Havanese',),
#  ('German Shepherd Dog',),
#  ('Australian Shepherd',),
#  ('Mixed',),
#  ('Border Collie',),
#  ('Boxer',),
#  ('Labrador Retriever-Cane Corso Mix',),
#  ('Labrador Retriever',),
#  ('Miniature Schnauzer',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Bichon Frise-Shih Tzu Mix',),
#  ('Pug',),
#  ('Pointer-Labrador Retriever Mix',),
#  ('Labrador Retriever-Basenji Mix',),
#  ('Poodle',),
#  ('Golden Retriever',),
#  ('Australian Cattle Dog',),
#  ('German Shepherd Dog',),
#  ('Mixed',),
#  ('Golden Doodle',),
#  ('Pembroke Welsh Corgi-Russell Terrier Mix',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Labrador Retriever',),
#  ('Border Collie-Labrador Retriever Mix',),
#  ('Mixed',),
#  ('Bulldog-Beagle Mix',),
#  ('Border Collie',),
#  ('Bulldog',),
#  ('Mixed',),
#  ('Nova Scotia Duck Tolling Retriever',),
#  ('Mixed',),
#  ('Australian Shepherd',),
#  ('English Cocker Spaniel',),
#  ('Golden Retriever',),
#  ('Poodle-Maltese Mix',),
#  ('Great Dane-Labrador Retriever Mix',),
#  ('Mixed',),
#  ('Golden Retriever',),
#  ('Boxer',),
#  ('Bernese Mountain Dog',),
#  ('Havanese',),
#  ('Mixed',),
#  ('Boxer',),
#  ('Mixed',),
#  ('Brittany-Poodle Mix',),
#  ('Shih Tzu',),
#  ('Mixed',),
#  ('Scottish Terrier',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Weimaraner',),
#  ('Shih Tzu',),
#  ('Weimaraner',),
#  ('Mixed',),
#  ('West Highland White Terrier',),
#  ('Labradoodle',),
#  ('Labrador Retriever',),
#  ('Mixed',),
#  ('Beagle',),
#  ('Labrador Retriever-Cardigan Welsh Corgi Mix',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Bearded Collie-Tibetan Terrier Mix',),
#  ('Shih Tzu',),
#  ('Australian Shepherd',),
#  ('Beagle',),
#  ('Beagle',),
#  ('German Shepherd Dog',),
#  ("I Don't Know",),
#  ('Mixed',),
#  ('Miniature American Shepherd',),
#  ('Great Dane',),
#  ('Golden Retriever',),
#  ('Golden Retriever-Labrador Retriever Mix',),
#  ('Labrador Retriever',),
#  ('Mixed',),
#  ('Icelandic Sheepdog',),
#  ('Golden Retriever',),
#  ('Dachshund',),
#  ('German Shorthaired Pointer-Labrador Retriever Mix',),
#  ('Miniature Schnauzer',),
#  ('Miniature Schnauzer',),
#  ('Pug-Chihuahua Mix',),
#  ('Cockapoo',),
#  ('Mixed',),
#  ('Weimaraner',),
#  ('Yorkshire Terrier-Bichon Frise Mix',),
#  ('Cockapoo',),
#  ('Border Collie',),
#  ('Golden Retriever',),
#  ('Cairn Terrier',),
#  ('Yorkshire Terrier- Mix',),
#  ('German Shepherd Dog',),
#  ('Belgian Sheepdog- Mix',),
#  ('Australian Cattle Dog-Border Collie Mix',),
#  ('Old English Sheepdog',),
#  ('West Highland White Terrier',),
#  ('Golden Retriever',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Miniature Schnauzer',),
#  ('Mixed',),
#  ('Boston Terrier',),
#  ('Portuguese Water Dog',),
#  ('American Pit Bull Terrier-American Staffordshire Terrier Mix',),
#  ('American Pit Bull Terrier-American Staffordshire Terrier Mix',),
#  ('Labrador Retriever',),
#  ('Golden Retriever',),
#  ('Golden Retriever',),
#  ('Danish-Swedish Farmdog',),
#  ('Golden Retriever',),
#  ('Labrador Retriever',),
#  ('Mixed',),
#  ('Cardigan Welsh Corgi',),
#  ('Bernese Mountain Dog',),
#  ('Boxer',),
#  ('Boxer',),
#  ('Poodle',),
#  ('Mixed',),
#  ('Labradoodle',),
#  ('Mixed',),
#  ('Labradoodle',),
#  ('Mixed',),
#  ('Shetland Sheepdog',),
#  ('Shetland Sheepdog',),
#  ('Cavalier King Charles Spaniel',),
#  ('Beagle',),
#  ('Bichon Frise-Cavalier King Charles Spaniel Mix',),
#  ('Golden Doodle',),
#  ('Labrador Retriever',),
#  ('French Bulldog',),
#  ('Cockapoo',),
#  ('Rhodesian Ridgeback-Boxer Mix',),
#  ('Mixed',),
#  ('Poodle-Cavalier King Charles Spaniel Mix',),
#  ('Poodle-Cavalier King Charles Spaniel Mix',),
#  ('Mixed',),
#  ('Beagle-Australian Cattle Dog Mix',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Shetland Sheepdog',),
#  ('Labrador Retriever-Rottweiler Mix',),
#  ('Pomeranian',),
#  ('Poodle',),
#  ('Mixed',),
#  ('Yorkshire Terrier',),
#  ('Shih Tzu',),
#  ('Mixed',),
#  ('Border Collie',),
#  ('Mixed',),
#  ('Dalmatian',),
#  ('Chow Chow-Golden Retriever Mix',),
#  ('German Shepherd Dog-Beagle Mix',),
#  ('Siberian Husky',),
#  ('Other',),
#  ('American Staffordshire Terrier-Labrador Retriever Mix',),
#  ('Yorkshire Terrier',),
#  ('Cockapoo',),
#  ('Affenpinscher',),
#  ('Maltese',),
#  ('Mixed',),
#  ('Border Terrier- Mix',),
#  ('Scottish Terrier',),
#  ('English Setter',),
#  ('Labrador Retriever',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Other',),
#  ('Havanese',),
#  ('Havanese',),
#  ('Havanese',),
#  ('Border Terrier',),
#  ('Border Terrier',),
#  ('Border Terrier',),
#  ('Australian Shepherd',),
#  ('Bulldog',),
#  ('Coton de Tulear',),
#  ('Cardigan Welsh Corgi',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Russell Terrier',),
#  ('Greyhound',),
#  ('American Water Spaniel',),
#  ('Mixed',),
#  ('German Shepherd Dog',),
#  ('Russell Terrier-Chihuahua Mix',),
#  ('Labrador Retriever',),
#  ('Poodle',),
#  ('Cavalier King Charles Spaniel',),
#  ('Mastiff',),
#  ('Cavalier King Charles Spaniel',),
#  ('Mixed',),
#  ("I Don't Know",),
#  ('Shiba Inu',),
#  ('Golden Retriever',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Border Collie',),
#  ('Beagle',),
#  ('Mixed',),
#  ('German Shepherd Dog',),
#  ('Miniature Schnauzer',),
#  ('Labradoodle',),
#  ('Australian Shepherd-Golden Retriever Mix',),
#  ('German Shorthaired Pointer',),
#  ('German Shorthaired Pointer',),
#  ('German Shorthaired Pointer',),
#  ('German Shorthaired Pointer',),
#  ('Border Collie-Belgian Tervuren Mix',),
#  ('American Staffordshire Terrier-Australian Shepherd Mix',),
#  ('Pekingese-Dachshund Mix',),
#  ('German Shepherd Dog-Siberian Husky Mix',),
#  ('Golden Doodle',),
#  ('Rat Terrier',),
#  ('Chihuahua',),
#  ('Portuguese Water Dog',),
#  ('Rottweiler- Mix',),
#  ('Mixed',),
#  ('Labrador Retriever',),
#  ('Labrador Retriever',),
#  ('Labrador Retriever',),
#  ('Pug-Maltese Mix',),
#  ('Boston Terrier',),
#  ('Boston Terrier',),
#  ('Labradoodle',),
#  ('Border Collie',),
#  ('Cairn Terrier',),
#  ('Mixed',),
#  ('Shih Tzu',),
#  ('English Springer Spaniel',),
#  ('Mixed',),
#  ('Maltese',),
#  ('Golden Retriever',),
#  ('Mixed',),
#  ('Golden Retriever',),
#  ('Siberian Husky-Australian Shepherd Mix',),
#  ('Australian Cattle Dog',),
#  ('Chihuahua',),
#  ('Whippet',),
#  ('West Highland White Terrier',),
#  ('Boston Terrier-Bulldog Mix',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Portuguese Water Dog',),
#  ('Border Collie-Dalmatian Mix',),
#  ('Other',),
#  ('Cocker Spaniel',),
#  ('Welsh Springer Spaniel',),
#  ('Poodle-Old English Sheepdog Mix',),
#  ('Mixed',),
#  ('Golden Retriever',),
#  ('Mixed',),
#  ('Mixed',),
#  ('German Shepherd Dog',),
#  ('Mixed',),
#  ('Labrador Retriever',),
#  ('Labrador Retriever',),
#  ('German Shepherd Dog',),
#  ('Labradoodle',),
#  ('Labrador Retriever',),
#  ('Mixed',),
#  ('Border Terrier',),
#  ('Golden Retriever',),
#  ('Golden Retriever',),
#  ('Staffordshire Bull Terrier',),
#  ('Australian Shepherd',),
#  ('Havanese',),
#  ('Labrador Retriever',),
#  ('Soft Coated Wheaten Terrier',),
#  ('Mixed',),
#  ('Golden Retriever',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Poodle',),
#  ('Poodle',),
#  ('Shih Tzu',),
#  ('Border Collie',),
#  ('Border Collie-Staffordshire Bull Terrier Mix',),
#  ('Siberian Husky',),
#  ('German Shepherd Dog',),
#  ('Shih Tzu',),
#  ('Mixed',),
#  ('English Springer Spaniel',),
#  ('Australian Cattle Dog- Mix',),
#  ('Boxer',),
#  ('Other',),
#  ("I Don't Know",),
#  ('Golden Doodle',),
#  ('Bichon Frise-Poodle Mix',),
#  ('Mixed',),
#  ('Shetland Sheepdog',),
#  ('Shetland Sheepdog',),
#  ('Golden Retriever',),
#  ('Mixed',),
#  ('Labrador Retriever',),
#  ('German Shorthaired Pointer-Catahoula Leopard Dog Mix',),
#  ('Mixed',),
#  ('Alaskan Malamute-Collie Mix',),
#  ('Mixed',),
#  ('Doberman Pinscher',),
#  ('Collie',),
#  ('Boxer',),
#  ('Weimaraner',),
#  ('Boxer',),
#  ('Labrador Retriever',),
#  ('Poodle',),
#  ('Mixed',),
#  ('Coton de Tulear',),
#  ('Shih Tzu',),
#  ('Shih Tzu',),
#  ('Golden Retriever-Newfoundland Mix',),
#  ('Shih Tzu',),
#  ('Shetland Sheepdog',),
#  ('Mixed',),
#  ('Border Collie',),
#  ('Mixed',),
#  ('Border Collie',),
#  ('Shih Tzu',),
#  ('American Staffordshire Terrier',),
#  ('Shih Tzu',),
#  ('Mixed',),
#  ('Other',),
#  ('Greyhound',),
#  ('Cavalier King Charles Spaniel',),
#  ('Border Collie',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Boxer-American Staffordshire Terrier Mix',),
#  ('Miniature Schnauzer',),
#  ('Cavalier King Charles Spaniel-Poodle Mix',),
#  ('Other',),
#  ('Shih Tzu',),
#  ('Boston Terrier',),
#  ('Poodle',),
#  ('German Shepherd Dog',),
#  ('Norfolk Terrier',),
#  ('Norfolk Terrier',),
#  ('Labrador Retriever',),
#  ('Labrador Retriever-Rottweiler Mix',),
#  ('Mixed',),
#  ('Nova Scotia Duck Tolling Retriever',),
#  ('German Shepherd Dog',),
#  ('Australian Shepherd',),
#  ('Greyhound',),
#  ('Staffordshire Bull Terrier-Great Dane Mix',),
#  ('Mixed',),
#  ('Wire Fox Terrier',),
#  ('Golden Retriever',),
#  ('French Spaniel',),
#  ('Samoyed',),
#  ('Coton de Tulear',),
#  ('Mixed',),
#  ('Labrador Retriever',),
#  ('Poodle-Maltese Mix',),
#  ('German Shepherd Dog',),
#  ('Golden Retriever',),
#  ('Border Collie',),
#  ('Maltese-Yorkshire Terrier Mix',),
#  ('Cockapoo',),
#  ('Collie',),
#  ('Labrador Retriever-German Shepherd Dog Mix',),
#  ("I Don't Know",),
#  ('Border Collie',),
#  ('Mixed',),
#  ('Pekingese-Shih Tzu Mix',),
#  ('Mixed',),
#  ('Siberian Husky',),
#  ('Shih Tzu',),
#  ('Rhodesian Ridgeback',),
#  ('Mixed',),
#  ('Dalmatian',),
#  ('Dalmatian',),
#  ('Labrador Retriever',),
#  ('Staffordshire Bull Terrier-Miniature Schnauzer Mix',),
#  ('Cocker Spaniel',),
#  ('Mixed',),
#  ('Greyhound',),
#  ('Shetland Sheepdog',),
#  ('Poodle',),
#  ('Puggle',),
#  ('Mixed',),
#  ('Cockapoo',),
#  ('Beagle- Mix',),
#  ('Rhodesian Ridgeback',),
#  ('Havanese',),
#  ('Golden Retriever',),
#  ('Mixed',),
#  ('Shih Tzu',),
#  ('Shih Tzu',),
#  ('Mixed',),
#  ('Shih Tzu',),
#  ('Havanese',),
#  ('Yorkshire Terrier',),
#  ('Dalmatian',),
#  ('Dalmatian',),
#  ('Belgian Malinois',),
#  ('Mixed',),
#  ('Rhodesian Ridgeback',),
#  ('Labradoodle',),
#  ('Australian Shepherd',),
#  ('Australian Shepherd',),
#  ('Dalmatian',),
#  ('Portuguese Water Dog',),
#  ('Australian Shepherd-Australian Cattle Dog Mix',),
#  ("I Don't Know",),
#  ('French Bulldog',),
#  ('Boston Terrier',),
#  ('Labrador Retriever',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Pomeranian',),
#  ('Whippet',),
#  ('Golden Doodle',),
#  ('Border Collie',),
#  ('Border Collie',),
#  ('Border Collie',),
#  ('Poodle-Labrador Retriever Mix',),
#  ('Pug-Wire Fox Terrier Mix',),
#  ('Greyhound',),
#  ('Pug-Wire Fox Terrier Mix',),
#  ('Pug-Smooth Fox Terrier Mix',),
#  ('Pembroke Welsh Corgi',),
#  ('Australian Shepherd',),
#  ('German Shepherd Dog',),
#  ('Mixed',),
#  ('Shih Tzu',),
#  ('Wire Fox Terrier',),
#  ('Mixed',),
#  ('Labrador Retriever',),
#  ('Bearded Collie-Beagle Mix',),
#  ('Golden Retriever',),
#  ('Border Collie-Australian Cattle Dog Mix',),
#  ('Mixed',),
#  ('Great Dane',),
#  ('Brussels Griffon',),
#  ('Poodle',),
#  ('Irish Setter',),
#  ('Poodle',),
#  ('Labrador Retriever',),
#  ('Mixed',),
#  ('Puggle',),
#  ('Shih Tzu',),
#  ('Nova Scotia Duck Tolling Retriever',),
#  ('Poodle-Dachshund Mix',),
#  ('German Shepherd Dog',),
#  ('Golden Retriever',),
#  ('Mixed',),
#  ('Golden Retriever',),
#  ('Cocker Spaniel',),
#  ('Miniature Schnauzer',),
#  ('Shetland Sheepdog',),
#  ('Shetland Sheepdog',),
#  ('Mixed',),
#  ('Pug-Chihuahua Mix',),
#  ('Mixed',),
#  ('Coton de Tulear',),
#  ('Golden Retriever',),
#  ('Golden Retriever',),
#  ('Papillon',),
#  ('Mastiff',),
#  ('Shih Tzu',),
#  ('Polish Lowland Sheepdog',),
#  ('Miniature Pinscher',),
#  ('English Springer Spaniel',),
#  ("I Don't Know",),
#  ('American Eskimo Dog',),
#  ('German Shepherd Dog',),
#  ('Soft Coated Wheaten Terrier',),
#  ('Mixed',),
#  ('Chinese Crested-Poodle Mix',),
#  ('Labrador Retriever',),
#  ('Golden Retriever',),
#  ('American Pit Bull Terrier-Australian Cattle Dog Mix',),
#  ('Shih Tzu',),
#  ('Catahoula Leopard Dog-Rottweiler Mix',),
#  ('Shih Tzu',),
#  ('Belgian Tervuren',),
#  ('Belgian Tervuren',),
#  ('Greyhound',),
#  ('Nova Scotia Duck Tolling Retriever',),
#  ('Mixed',),
#  ('Australian Shepherd-Border Collie Mix',),
#  ('Bernese Mountain Dog',),
#  ('West Highland White Terrier',),
#  ('Poodle-Shih Tzu Mix',),
#  ('Boxer-Border Collie Mix',),
#  ('Shih Tzu',),
#  ('Other',),
#  ('Cavalier King Charles Spaniel',),
#  ('Mixed',),
#  ('Border Collie',),
#  ("I Don't Know",),
#  ('Golden Retriever',),
#  ('Great Dane-Irish Wolfhound Mix',),
#  ('Pyrenean Shepherd',),
#  ('Pyrenean Shepherd',),
#  ('Labrador Retriever',),
#  ('Golden Retriever',),
#  ('German Shepherd Dog',),
#  ('Other',),
#  ('Chinese Shar-Pei',),
#  ('Mastiff',),
#  ('French Bulldog',),
#  ('Australian Shepherd',),
#  ('Australian Shepherd',),
#  ('Australian Shepherd',),
#  ('Dachshund',),
#  ("I Don't Know",),
#  ('Golden Retriever',),
#  ('Maltese',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Cavalier King Charles Spaniel',),
#  ('Labradoodle',),
#  ('Labradoodle',),
#  ('Border Collie',),
#  ('Lhasa Apso',),
#  ('Greyhound',),
#  ('Mixed',),
#  ('Shih Tzu',),
#  ('Dogue de Bordeaux-Boxer Mix',),
#  ('Golden Doodle',),
#  ('Belgian Malinois',),
#  ('Greyhound',),
#  ('Belgian Malinois',),
#  ('Akita',),
#  ('Golden Retriever',),
#  ('Mixed',),
#  ('Labrador Retriever',),
#  ('Golden Retriever',),
#  ('Golden Retriever',),
#  ('Australian Shepherd',),
#  ('Bulldog',),
#  ('Golden Doodle',),
#  ('American Staffordshire Terrier-Catahoula Leopard Dog Mix',),
#  ('Mixed',),
#  ('Golden Retriever',),
#  ('German Shepherd Dog',),
#  ('Scottish Terrier',),
#  ('Bulldog',),
#  ('Shih Tzu-Pekingese Mix',),
#  ('Labrador Retriever',),
#  ('Rat Terrier',),
#  ('Border Terrier',),
#  ('Poodle',),
#  ('Labrador Retriever',),
#  ('Boxer',),
#  ('Beagle-Labrador Retriever Mix',),
#  ('Australian Shepherd',),
#  ('Golden Retriever',),
#  ('Dachshund-Beagle Mix',),
#  ('Silky Terrier',),
#  ('Shetland Sheepdog',),
#  ('Mixed',),
#  ('Golden Doodle',),
#  ('Scottish Terrier',),
#  ('-German Shepherd Dog Mix',),
#  ('Boxer',),
#  ('Labrador Retriever',),
#  ('Keeshond',),
#  ('Mixed',),
#  ('Mixed',),
#  ('German Shorthaired Pointer',),
#  ('Coton de Tulear',),
#  ('Golden Retriever',),
#  ('Mixed',),
#  ('Belgian Malinois',),
#  ('Chihuahua',),
#  ('Poodle',),
#  ('American Pit Bull Terrier',),
#  ('Bernese Mountain Dog',),
#  ('Golden Retriever',),
#  ('Mixed',),
#  ('Mixed',),
#  ('German Shepherd Dog-Chow Chow Mix',),
#  ('Labrador Retriever-Golden Retriever Mix',),
#  ('Weimaraner',),
#  ('Mixed',),
#  ('German Shepherd Dog',),
#  ('Border Collie-Australian Shepherd Mix',),
#  ('Labrador Retriever- Mix',),
#  ('Border Collie',),
#  ('Labrador Retriever',),
#  ('Mixed',),
#  ('Beagle-Australian Cattle Dog Mix',),
#  ('Mixed',),
#  ('Pembroke Welsh Corgi-Great Pyrenees Mix',),
#  ('Mixed',),
#  ('Golden Retriever',),
#  ('Golden Retriever',),
#  ('Mixed',),
#  ('German Shepherd Dog',),
#  ('Australian Shepherd-Pembroke Welsh Corgi Mix',),
#  ('Mixed',),
#  ('German Shepherd Dog',),
#  ('Labrador Retriever',),
#  ('Cavalier King Charles Spaniel',),
#  ('Australian Shepherd',),
#  ('French Bulldog',),
#  ('Labrador Retriever',),
#  ('Golden Doodle',),
#  ('Chesapeake Bay Retriever',),
#  ('Poodle',),
#  ('Golden Doodle',),
#  ('Labrador Retriever',),
#  ('Maltese-Poodle Mix',),
#  ('Labrador Retriever',),
#  ('Labradoodle',),
#  ('Cavalier King Charles Spaniel',),
#  ('Mixed',),
#  ('Mixed',),
#  ('Dachshund',),
#  ('Havanese',),
#  ('Mixed',),
#  ('Labrador Retriever',),
#  ('Boxer',),
#  ('Mixed',),
#  ('Boxer',),
#  ('German Shepherd Dog',),
#  ('Border Collie',),
#  ('Mixed',),
#  ('Australian Shepherd',),
#  ('Afghan Hound-Golden Retriever Mix',),
#  ('Mixed',),
#  ('Dachshund',),
#  ('Shorkie',),
#  ('Field Spaniel',),
#  ('Mixed',),
#  ('Cavalier King Charles Spaniel',),
#  ('Poodle',),
#  ('Chihuahua-American Staffordshire Terrier Mix',),
#  ('Newfoundland',),
#  ('Mixed',),
#  ('Yorkshire Terrier',),
#  ('Australian Cattle Dog',),
#  ('Other',),
#  ('English Cocker Spaniel',),
#  ('Boxer',),
#  ('Portuguese Water Dog',),
#  ('Labradoodle',),
#  ('Mixed',),
#  ('Pug',),
#  ('Bluetick Coonhound',),
#  ('Pug-Miniature Pinscher Mix',),
#  ('Shetland Sheepdog',),
#  ('Whippet-Chinese Shar-Pei Mix',),
#  ('German Shepherd Dog',),
#  ('German Shepherd Dog',),
#  ('Boxer-Bulldog Mix',),
#  ('Portuguese Water Dog',),
#  ('Other',),
#  ('Portuguese Water Dog',),
#  ('Portuguese Water Dog',),
#  ('Portuguese Water Dog',),
#  ('Golden Retriever',),
#  ('Labrador Retriever',),
#  ('Labradoodle',),
#  ('Papillon',),
#  ('Poodle',),
#  ('Mixed',),
#  ('Poodle',),
#  ('Portuguese Water Dog',),
#  ('Vizsla- Mix',),
#  ('Boxer',),
#  ('Chow Chow-Labrador Retriever Mix',),
#  ('Rat Terrier',),
#  ('Rhodesian Ridgeback-Boxer Mix',),
#  ('Labrador Retriever',),
#  ('Mixed',),
#  ('Border Collie-Whippet Mix',),
#  ('Mixed',),
#  ('Russell Terrier',),
#  ('Other',),
#  ('Belgian Malinois',),
#  ('German Shepherd Dog',),
#  ('Border Collie-Pembroke Welsh Corgi Mix',),
#  ('Mixed',),
#  ('Pug',),
#  ...]

# %% [markdown]
# When you do so, you will see a line at the top of the output panel that says "35050 rows affected".  This means that there are 35050 rows of data in the dogs table.  Each row of the output lists the name of the breed of the dog represented by that entry.  Notice that some breed names are listed multiple times, because several dogs of that breed have participated in the Dognition tests.
#
# If you scroll all the way down to the bottom of the output, you will see a notification that says "35050 rows, truncated to displaylimit of 1000."  We have set up a display limit of 1000 rows in these notebooks to ensure that our database servers are not overloaded, and to reduce the amount of time you have to wait for the query output. However, in a actual scenario these limits would not necessarily be in place for you.  Therefore, before we go any further, I want to show you how you could restrict the number of rows outputted by a query.
#
# ![Alt text](https://duke.box.com/shared/static/dm85qcbpdsza8tc7be8x7tc6x6tr2xjq.jpg)
#
#
#
# ## Using LIMIT to restrict the number of rows in your output (and prevent system crashes)
#
# The MySQL clause you should use is called LIMIT, and it is always placed at the very end of your query.  The simplest version of a limit statement looks like this:
#
# ```mySQL
# SELECT breed
# FROM dogs LIMIT 5;
# ```
#
# The "5" in this case indicates that you will only see the first 5 rows of data you select.
#
# **Question 7: In the next cell, try entering a query that will let you see the first 10 rows of the breed column in the dogs table.**

# %%
# %%sql
# SELECT breed
# FROM dogs
# LIMIT 10;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 10 rows affected.
# [('Labrador Retriever',),
#  ('Shetland Sheepdog',),
#  ('Golden Retriever',),
#  ('Golden Retriever',),
#  ('Shih Tzu',),
#  ('Siberian Husky',),
#  ('Shih Tzu',),
#  ('Mixed',),
#  ('Labrador Retriever',),
#  ('Shih Tzu-Poodle Mix',)]

# %% [markdown]
# You can also select rows of data from different parts of the output table, rather than always just starting at the beginning.  To do this, use the OFFSET clause after LIMIT. The number after the OFFSET clause indicates from which row the output will begin querying.  Note that the offset of Row 1 of a table is actually 0.  Therefore, in the following query:
#
# ```mySQL
# SELECT breed
# FROM dogs LIMIT 10 OFFSET 5;
# ```
#
# 10 rows of data will be returned, starting at Row 6.
#
# An alternative way to write the OFFSET clause in the query is:
#
# ```mySQL
# SELECT breed
# FROM dogs LIMIT 5, 10;
# ```
#
# In this notation, the offset is the number before the comma, and the number of rows returned is the number after the comma.
#
# **Try it yourself:**

# %%
# %%sql
# select breed
# from dogs
# limit 10 offset 5;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 10 rows affected.
# [('Siberian Husky',),
#  ('Shih Tzu',),
#  ('Mixed',),
#  ('Labrador Retriever',),
#  ('Shih Tzu-Poodle Mix',),
#  ('German Shepherd Dog-Pembroke Welsh Corgi Mix',),
#  ('Vizsla',),
#  ('Pug',),
#  ('Boxer',),
#  ('German Shepherd Dog-Nova Scotia Duck Tolling Retriever Mix',)]

# %% [markdown]
# The LIMIT command is one of the pieces of syntax that can vary across database platforms.  MySQL uses LIMIT to restrict the output, but other databases including Teradata use a statement called "TOP" instead.  Oracle has yet another syntax:
#
# http://www.tutorialspoint.com/sql/sql-top-clause.htm
#
# Make sure to look up the correct syntax for the database type you are using.
#
#
# ## Using SELECT to query multiple columns
#
# Now that we know how to limit our output, we are ready to make our SELECT statement work a little harder.  The SELECT statement can be used to select multiple columns as well as a single column.  The output of the query will depend on the order of the columns you enter after the SELECT statement in your query.  <mark> When you enter column names, separate each name with a comma, but do NOT include a comma after the last column name. </mark>
#
# **Try the following query with different orders of the column names to observe the differences in output (I will include a LIMIT statement in many of the examples I use in the rest of the course, but feel free to change or remove them to explore different aspects of the data):**
#
# ```mySQL
# SELECT breed, breed_type, breed_group
# FROM dogs LIMIT 5, 10;
# ```

# %%
# %sql select breed, breed_type, breed_group from dogs limit 5, 10;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 10 rows affected.
# [('Siberian Husky', 'Pure Breed', 'Working'),
#  ('Shih Tzu', 'Pure Breed', 'Toy'),
#  ('Mixed', "Mixed Breed/ Other/ I Don't Know", None),
#  ('Labrador Retriever', 'Pure Breed', 'Sporting'),
#  ('Shih Tzu-Poodle Mix', 'Cross Breed', None),
#  ('German Shepherd Dog-Pembroke Welsh Corgi Mix', 'Cross Breed', None),
#  ('Vizsla', 'Pure Breed', 'Sporting'),
#  ('Pug', 'Pure Breed', 'Toy'),
#  ('Boxer', 'Pure Breed', 'Working'),
#  ('German Shepherd Dog-Nova Scotia Duck Tolling Retriever Mix', 'Cross Breed', None)]

# %% [markdown]
# Another trick to know about when using SELECT is that <mark> you can use an asterisk as a "wild card" to return all the data in a table.</mark>  (A wild card is defined as a character that will represent or match any character or sequence of characters in a query.) <mark> Take note, this is very risky to do if you do not limit your output or if you don't know how many data are in your database, so use the wild card with caution.</mark>  However, it is a handy tool to use when you don't have all the column names easily available or when you know you want to query an entire table.
#
# The syntax is as follows:
#
# ```mySQL
# SELECT *
# FROM dogs LIMIT 5, 10;
# ```
#
# **Question 8: Try using the wild card to query the reviews table:**

# %%
# %%sql
# SELECT *
# FROM dogs
# LIMIT 5, 10;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 10 rows affected.
# [('male', '2011', 'Siberian Husky', 60, 1, 0, datetime.datetime(2013, 2, 5, 18, 14, 14), datetime.datetime(2013, 7, 25, 19, 41, 49), 'stargazer', None, 'Pure Breed', 'Working', 'fd27b948-7144-11e5-ba71-058fbc01cf0b', 'ce13615c-7144-11e5-ba71-058fbc01cf0b', '20', '0.1785873538', '257.16578947', '0.0035648148035', '5.1333333171', '3.3931597222', '4886.15'),
#  ('male', '1982', 'Shih Tzu', 190, 1, 0, datetime.datetime(2013, 2, 5, 18, 16, 24), datetime.datetime(2014, 5, 30, 15, 52, 54), 'maverick', 1, 'Pure Breed', 'Toy', 'fd27ba1a-7144-11e5-ba71-058fbc01cf0b', 'ce135e14-7144-11e5-ba71-058fbc01cf0b', '27', '6.1905898326', '8914.449359', '0.00033564807185', '0.48333322347', '160.95533565', '231775.68333'),
#  ('male', '2012', 'Mixed', 50, 1, 0, datetime.datetime(2013, 2, 5, 18, 44, 2), datetime.datetime(2013, 7, 25, 19, 41, 49), 'protodog', None, "Mixed Breed/ Other/ I Don't Know", None, 'fd27bbbe-7144-11e5-ba71-058fbc01cf0b', 'ce135f2c-7144-11e5-ba71-058fbc01cf0b', '20', '0.0080750487303', '11.628070172', '0.0046412037941', '6.6833334635', '0.15342592588', '220.93333326'),
#  ('male', '2008', 'Labrador Retriever', 70, 1, 0, datetime.datetime(2013, 2, 5, 20, 59, 42), datetime.datetime(2013, 7, 25, 19, 41, 49), 'einstein', None, 'Pure Breed', 'Sporting', 'fd27c1c2-7144-11e5-ba71-058fbc01cf0b', 'ce136a1c-7144-11e5-ba71-058fbc01cf0b', '20', '0.68410453216', '985.11052631', '0.0033796295731', '4.8666665853', '12.997986111', '18717.1'),
#  ('male', '2008', 'Shih Tzu-Poodle Mix', 0, 1, 0, datetime.datetime(2013, 2, 5, 21, 30, 14), datetime.datetime(2013, 7, 25, 19, 41, 49), 'socialite', None, 'Cross Breed', None, 'fd27c5be-7144-11e5-ba71-058fbc01cf0b', 'ce136ac6-7144-11e5-ba71-058fbc01cf0b', '20', '0.22328155458', '321.5254386', '0.0038888889878', '5.6000001424', '4.2423495371', '6108.9833334'),
#  ('female', '2011', 'German Shepherd Dog-Pembroke Welsh Corgi Mix', 40, 1, 0, datetime.datetime(2013, 2, 5, 22, 29, 24), datetime.datetime(2013, 7, 25, 19, 41, 49), None, None, 'Cross Breed', None, 'fd27c74e-7144-11e5-ba71-058fbc01cf0b', 'ce136c24-7144-11e5-ba71-058fbc01cf0b', '14', '25.69619391', '37002.519231', '0.0058449073678', '8.4166666097', '334.05052083', '481032.75'),
#  ('male', '2011', 'Vizsla', 60, 1, 0, datetime.datetime(2013, 2, 5, 23, 9, 37), datetime.datetime(2013, 7, 25, 19, 41, 49), 'socialite', None, 'Pure Breed', 'Sporting', 'fd27c7d0-7144-11e5-ba71-058fbc01cf0b', 'ce136e36-7144-11e5-ba71-058fbc01cf0b', '20', '0.0053776803082', '7.7438596438', '0.0044791667034', '6.4500000529', '0.10217592586', '147.13333323'),
#  ('female', '2007', 'Pug', 20, 1, 0, datetime.datetime(2013, 2, 5, 23, 10, 40), datetime.datetime(2013, 7, 31, 21, 57, 21), 'stargazer', None, 'Pure Breed', 'Toy', 'fd27c852-7144-11e5-ba71-058fbc01cf0b', 'ce136ee0-7144-11e5-ba71-058fbc01cf0b', '20', '0.051511939572', '74.177192984', '0.0039930555499', '5.7499999919', '0.97872685187', '1409.3666667'),
#  ('female', '2010', 'Boxer', 50, 1, 0, datetime.datetime(2013, 2, 5, 23, 27, 59), datetime.datetime(2013, 7, 25, 19, 41, 49), 'ace', None, 'Pure Breed', 'Working', 'fd27c8d4-7144-11e5-ba71-058fbc01cf0b', 'ce136f94-7144-11e5-ba71-058fbc01cf0b', '20', '0.15856725147', '228.33684211', '0.0039351851456', '5.6666666097', '3.0127777779', '4338.4000001'),
#  ('male', '2010', 'German Shepherd Dog-Nova Scotia Duck Tolling Retriever Mix', 30, 1, 0, datetime.datetime(2013, 2, 6, 0, 9, 33), datetime.datetime(2014, 5, 30, 15, 52, 56), None, None, 'Cross Breed', None, 'fd27c956-7144-11e5-ba71-058fbc01cf0b', 'ce134be0-7144-11e5-ba71-058fbc01cf0b', '11', '2.8247997685', '4067.7116667', '0.0037731481142', '5.4333332845', '28.247997685', '40677.116667')]

# %% [markdown]
# NOTE: if you do this for the dogs table, your output will be too wide to see at one time in the dialog box.  Use the scroll bars at bottom and to the right of the dialog box to see the entire output table.
#
#
# SELECT statements can also be used to make new derivations of individual columns using "+" for addition, "-" for subtraction, "\*" for multiplication, or "/" for division.  For example, if you wanted the median inter-test intervals in hours instead of minutes or days, you could query:
#
# ```mySQL
# SELECT median_iti_minutes / 60
# FROM dogs LIMIT 5, 10;
# ```
#
# **Question 9: Go ahead and try it, adding in a column to your output that shows you the original median_iti in minutes.**

# %%
# %sql select median_iti_minutes / 60 from dogs limit 5, 10;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 10 rows affected.
# [(0.085555555285,),
#  (0.0080555537245,),
#  (0.11138889105833334,),
#  (0.081111109755,),
#  (0.09333333570666666,),
#  (0.14027777682833334,),
#  (0.10750000088166667,),
#  (0.09583333319833334,),
#  (0.094444443495,),
#  (0.09055555474166667,)]

# %% [markdown]
# ## Now it's time to practice writing your own SELECT statements.
#
# **Question 10: How would you retrieve the first 15 rows of data from the dog_guid, subcategory_name, and test_name fields of the Reviews table, in that order?**

# %%
# %sql select dog_guid, subcategory_name, test_name from reviews limit 15;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 15 rows affected.
# [('ce3ac77e-7144-11e5-ba71-058fbc01cf0b', 'Empathy', 'Yawn Warm-up'),
#  ('ce2aedcc-7144-11e5-ba71-058fbc01cf0b', 'Empathy', 'Eye Contact Warm-up'),
#  ('ce2aedcc-7144-11e5-ba71-058fbc01cf0b', 'Empathy', 'Eye Contact Game'),
#  ('ce2aedcc-7144-11e5-ba71-058fbc01cf0b', 'Communication', 'Treat Warm-up'),
#  ('ce405c52-7144-11e5-ba71-058fbc01cf0b', 'Empathy', 'Yawn Warm-up'),
#  ('ce405c52-7144-11e5-ba71-058fbc01cf0b', 'Empathy', 'Yawn Game'),
#  ('ce405c52-7144-11e5-ba71-058fbc01cf0b', 'Empathy', 'Eye Contact Game'),
#  ('ce405e28-7144-11e5-ba71-058fbc01cf0b', 'Communication', 'Treat Warm-up'),
#  ('ce405e28-7144-11e5-ba71-058fbc01cf0b', 'Cunning', 'Turn Your Back'),
#  ('ce2609c4-7144-11e5-ba71-058fbc01cf0b', 'Communication', 'Treat Warm-up'),
#  ('ce2609c4-7144-11e5-ba71-058fbc01cf0b', 'Communication', 'Arm Pointing'),
#  ('ce2609c4-7144-11e5-ba71-058fbc01cf0b', 'Communication', 'Foot Pointing'),
#  ('ce260c1c-7144-11e5-ba71-058fbc01cf0b', 'Shaker Game', 'Shaker Warm-Up'),
#  ('ce3fd48a-7144-11e5-ba71-058fbc01cf0b', 'Empathy', 'Yawn Game'),
#  ('ce3fd48a-7144-11e5-ba71-058fbc01cf0b', 'Empathy', 'Eye Contact Warm-up')]

# %% [markdown]
# **Question 11: How would you retrieve 10 rows of data from the activity_type, created_at, and updated_at fields of the site_activities table, starting at row 50?  What do you notice about the created_at and updated_at fields?**

# %%
# %sql select activity_type, created_at, updated_at from site_activities limit 50, 10;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 10 rows affected.
# [('point_in_cat', datetime.datetime(2013, 7, 25, 20, 55, 7), datetime.datetime(2013, 7, 25, 20, 55, 7)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 55, 50), datetime.datetime(2013, 7, 25, 20, 55, 50)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 56, 9), datetime.datetime(2013, 7, 25, 20, 56, 9)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 20, 56, 21), datetime.datetime(2013, 7, 25, 20, 56, 21)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 21, 0, 31), datetime.datetime(2013, 7, 25, 21, 0, 31)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 21, 2, 29), datetime.datetime(2013, 7, 25, 21, 2, 29)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 21, 2, 31), datetime.datetime(2013, 7, 25, 21, 2, 31)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 21, 2, 45), datetime.datetime(2013, 7, 25, 21, 2, 45)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 21, 5, 41), datetime.datetime(2013, 7, 25, 21, 5, 41)),
#  ('point_in_cat', datetime.datetime(2013, 7, 25, 21, 7, 40), datetime.datetime(2013, 7, 25, 21, 7, 40))]

# %% [markdown]
# **Question 12: How would you retrieve 20 rows of data from all the columns in the users table, starting from row 2000?  What do you notice about the free_start_user field?**

# %%
# %sql select * from users limit 20 offset 2000;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 20 rows affected.
# [(3, datetime.datetime(2013, 2, 21, 23, 25, 3), datetime.datetime(2015, 1, 28, 20, 51, 53), 1, 2, 1, None, None, None, 2, 'ce24589a-7144-11e5-ba71-058fbc01cf0b', None, None, None, None, None),
#  (1, datetime.datetime(2013, 2, 22, 1, 21, 20), datetime.datetime(2015, 1, 28, 20, 51, 53), 1, 1, 1, None, None, None, 1, 'ce245a3e-7144-11e5-ba71-058fbc01cf0b', None, None, None, None, None),
#  (1, datetime.datetime(2013, 2, 22, 3, 5, 42), datetime.datetime(2015, 1, 28, 20, 51, 53), 1, 2, 1, None, None, None, 2, 'ce245c50-7144-11e5-ba71-058fbc01cf0b', None, None, None, None, None),
#  (5, datetime.datetime(2013, 2, 22, 3, 29, 6), datetime.datetime(2015, 1, 28, 20, 51, 53), 1, 1, 1, None, None, datetime.datetime(2014, 6, 23, 23, 31, 28), 1, 'ce245d7c-7144-11e5-ba71-058fbc01cf0b', None, None, None, None, None),
#  (1, datetime.datetime(2013, 2, 22, 15, 5, 13), datetime.datetime(2015, 1, 28, 20, 51, 53), 1, 1, 1, None, None, None, 1, 'ce245eda-7144-11e5-ba71-058fbc01cf0b', None, None, None, None, None),
#  (1, datetime.datetime(2013, 2, 22, 16, 30, 17), datetime.datetime(2015, 1, 28, 20, 51, 53), 1, 2, 1, None, None, None, 2, 'ce245f98-7144-11e5-ba71-058fbc01cf0b', None, None, None, None, None),
#  (1, datetime.datetime(2013, 2, 22, 18, 16, 5), datetime.datetime(2015, 1, 28, 20, 51, 53), 1, 1, 0, None, None, None, 1, 'ce24611e-7144-11e5-ba71-058fbc01cf0b', None, None, None, None, None),
#  (3, datetime.datetime(2013, 2, 22, 20, 26, 53), datetime.datetime(2015, 1, 28, 20, 51, 53), 1, 1, 1, None, None, None, 1, 'ce24629a-7144-11e5-ba71-058fbc01cf0b', None, None, None, None, None),
#  (1, datetime.datetime(2013, 2, 22, 23, 14, 40), datetime.datetime(2015, 1, 28, 20, 51, 54), 2, 2, 1, None, None, None, 2, 'ce2465ec-7144-11e5-ba71-058fbc01cf0b', None, None, None, None, None),
#  (1, datetime.datetime(2013, 2, 23, 13, 5, 38), datetime.datetime(2015, 1, 28, 20, 51, 54), 1, 1, 1, None, None, None, 1, 'ce246772-7144-11e5-ba71-058fbc01cf0b', None, None, None, None, None),
#  (3, datetime.datetime(2013, 2, 23, 16, 56, 55), datetime.datetime(2015, 1, 28, 20, 51, 54), 2, 2, 1, None, None, None, 2, 'ce24688a-7144-11e5-ba71-058fbc01cf0b', None, None, None, None, None),
#  (3, datetime.datetime(2013, 2, 23, 21, 7, 41), datetime.datetime(2015, 1, 28, 20, 51, 54), 1, 2, 1, None, None, None, 2, 'ce246b28-7144-11e5-ba71-058fbc01cf0b', None, None, None, None, None),
#  (1, datetime.datetime(2013, 2, 23, 21, 22, 9), datetime.datetime(2015, 1, 28, 20, 51, 54), 1, 1, 1, None, None, None, 1, 'ce246b82-7144-11e5-ba71-058fbc01cf0b', None, None, None, None, None),
#  (4, datetime.datetime(2013, 2, 23, 22, 48, 15), datetime.datetime(2015, 1, 28, 20, 51, 54), 1, 2, 1, None, None, datetime.datetime(2014, 8, 4, 14, 16, 34), 2, 'ce246c40-7144-11e5-ba71-058fbc01cf0b', None, None, None, None, None),
#  (4, datetime.datetime(2013, 2, 24, 0, 14, 21), datetime.datetime(2015, 1, 28, 20, 51, 54), 2, 2, 0, None, None, None, 2, 'ce246dbc-7144-11e5-ba71-058fbc01cf0b', None, None, None, None, None),
#  (1, datetime.datetime(2013, 2, 24, 7, 34, 32), datetime.datetime(2015, 1, 28, 20, 51, 54), 1, 1, 0, None, None, None, 1, 'ce246e84-7144-11e5-ba71-058fbc01cf0b', None, None, None, None, None),
#  (1, datetime.datetime(2013, 2, 24, 14, 48, 43), datetime.datetime(2015, 1, 28, 20, 51, 54), 1, 1, 1, None, None, None, 1, 'ce246ff6-7144-11e5-ba71-058fbc01cf0b', None, None, None, None, None),
#  (1, datetime.datetime(2013, 2, 24, 15, 34, 10), datetime.datetime(2015, 1, 28, 20, 51, 54), 1, 1, 1, None, None, None, 1, 'ce247050-7144-11e5-ba71-058fbc01cf0b', None, None, None, None, None),
#  (1, datetime.datetime(2013, 2, 24, 15, 36, 19), datetime.datetime(2015, 1, 28, 20, 51, 54), 1, 1, 0, None, None, None, 1, 'ce2470aa-7144-11e5-ba71-058fbc01cf0b', None, None, None, None, None),
#  (2, datetime.datetime(2013, 2, 24, 16, 29, 34), datetime.datetime(2015, 1, 28, 20, 51, 54), 1, 1, 1, None, None, datetime.datetime(2014, 7, 5, 19, 59, 14), 1, 'ce2470fa-7144-11e5-ba71-058fbc01cf0b', None, None, None, None, None)]

# %% [markdown]
# ## You have already learned how to see all the data in your database!  Congratulations!
#
# Feel free to practice any other queries you are interested in below:

# %%
# %sql show columns from dogs;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 21 rows affected.
# [('gender', 'varchar(255)', 'YES', '', None, ''),
#  ('birthday', 'varchar(255)', 'YES', '', None, ''),
#  ('breed', 'varchar(255)', 'YES', '', None, ''),
#  ('weight', 'int(11)', 'YES', '', None, ''),
#  ('dog_fixed', 'tinyint(1)', 'YES', '', None, ''),
#  ('dna_tested', 'tinyint(1)', 'YES', '', None, ''),
#  ('created_at', 'datetime', 'NO', '', None, ''),
#  ('updated_at', 'datetime', 'NO', '', None, ''),
#  ('dimension', 'varchar(255)', 'YES', '', None, ''),
#  ('exclude', 'tinyint(1)', 'YES', '', None, ''),
#  ('breed_type', 'varchar(255)', 'YES', '', None, ''),
#  ('breed_group', 'varchar(255)', 'YES', '', None, ''),
#  ('dog_guid', 'varchar(60)', 'YES', 'MUL', None, ''),
#  ('user_guid', 'varchar(60)', 'YES', 'MUL', None, ''),
#  ('total_tests_completed', 'varchar(255)', 'YES', '', None, ''),
#  ('mean_iti_days', 'varchar(255)', 'YES', '', None, ''),
#  ('mean_iti_minutes', 'varchar(255)', 'YES', '', None, ''),
#  ('median_iti_days', 'varchar(255)', 'YES', '', None, ''),
#  ('median_iti_minutes', 'varchar(255)', 'YES', '', None, ''),
#  ('time_diff_between_first_and_last_game_days', 'varchar(255)', 'YES', '', None, ''),
#  ('time_diff_between_first_and_last_game_minutes', 'varchar(255)', 'YES', '', None, '')]

# %% [markdown]
# ## the numbers of male dogs order by breed

# %%
# %%sql
# select gender, breed, count(dog_guid) as number
# from dogs
# group by gender, breed
# having gender ='male'
# order by number desc ;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 1376 rows affected.
# [('male', 'Mixed', 3923),
#  ('male', 'Labrador Retriever', 1139),
#  ('male', 'Golden Retriever', 715),
#  ('male', 'German Shepherd Dog', 533),
#  ('male', "I Don't Know", 492),
#  ('male', 'Poodle', 378),
#  ('male', 'Shih Tzu', 328),
#  ('male', 'Border Collie', 316),
#  ('male', 'Australian Shepherd', 314),
#  ('male', 'Other', 260),
#  ('male', 'Boxer', 237),
#  ('male', 'Dachshund', 237),
#  ('male', 'Golden Doodle', 237),
#  ('male', 'Miniature Schnauzer', 189),
#  ('male', 'Chihuahua', 185),
#  ('male', 'Yorkshire Terrier', 180),
#  ('male', 'Labradoodle', 178),
#  ('male', 'Beagle', 161),
#  ('male', 'American Pit Bull Terrier', 158),
#  ('male', 'Pug', 144),
#  ('male', 'Shetland Sheepdog', 143),
#  ('male', 'Doberman Pinscher', 135),
#  ('male', 'Cocker Spaniel', 124),
#  ('male', 'Boston Terrier', 124),
#  ('male', 'Labrador Retriever-Golden Retriever Mix', 119),
#  ('male', 'English Springer Spaniel', 116),
#  ('male', 'Siberian Husky', 114),
#  ('male', 'French Bulldog', 107),
#  ('male', 'Bulldog', 106),
#  ('male', 'Maltese', 105),
#  ('male', 'Cavalier King Charles Spaniel', 104),
#  ('male', 'Cockapoo', 103),
#  ('male', 'Havanese', 101),
#  ('male', 'Rottweiler', 98),
#  ('male', 'West Highland White Terrier', 94),
#  ('male', 'Pomeranian', 92),
#  ('male', 'Golden Retriever-Labrador Retriever Mix', 90),
#  ('male', 'Bichon Frise', 89),
#  ('male', 'Australian Cattle Dog', 87),
#  ('male', 'Pembroke Welsh Corgi', 87),
#  ('male', 'Jack Russell Terrier', 79),
#  ('male', 'Parson Russell Terrier', 79),
#  ('male', 'Vizsla', 71),
#  ('male', 'Weimaraner', 70),
#  ('male', 'Rhodesian Ridgeback', 67),
#  ('male', 'Great Dane', 65),
#  ('male', 'Portuguese Water Dog', 63),
#  ('male', 'Greyhound', 59),
#  ('male', 'Russell Terrier', 58),
#  ('male', 'Standard Poodle', 58),
#  ('male', 'American Staffordshire Terrier', 58),
#  ('male', 'German Shorthaired Pointer', 56),
#  ('male', 'Shiba Inu', 56),
#  ('male', 'Basset Hound', 55),
#  ('male', 'Papillon', 54),
#  ('male', 'Soft Coated Wheaten Terrier', 54),
#  ('male', 'Miniature Pinscher', 51),
#  ('male', 'Collie', 50),
#  ('male', 'Brittany', 49),
#  ('male', 'Rat Terrier', 49),
#  ('male', 'Bernese Mountain Dog', 48),
#  ('male', 'Border Terrier', 47),
#  ('male', 'Cairn Terrier', 47),
#  ('male', 'Belgian Malinois', 45),
#  ('male', 'Puggle', 43),
#  ('male', 'Maltese-Poodle Mix', 43),
#  ('male', 'Whippet', 42),
#  ('male', 'Flat-Coated Retriever', 41),
#  ('male', 'Staffordshire Bull Terrier', 39),
#  ('male', 'Newfoundland', 35),
#  ('male', 'English Cocker Spaniel', 35),
#  ('male', 'Coton de Tulear', 34),
#  ('male', 'Standard Schnauzer', 32),
#  ('male', 'Great Pyrenees', 32),
#  ('male', 'Shih Tzu-Poodle Mix', 31),
#  ('male', 'American Eskimo Dog', 31),
#  ('male', 'Dalmatian', 31),
#  ('male', 'Labrador Retriever-German Shepherd Dog Mix', 31),
#  ('male', 'Cocker Spaniel-Poodle Mix', 30),
#  ('male', 'Alaskan Malamute', 30),
#  ('male', 'Yorkshire Terrier-Poodle Mix', 30),
#  ('male', 'Nova Scotia Duck Tolling Retriever', 29),
#  ('male', 'Miniature Schnauzer-Poodle Mix', 29),
#  ('male', 'Australian Labradoodle', 29),
#  ('male', 'Akita', 28),
#  ('male', 'Airedale Terrier', 27),
#  ('male', 'Scottish Terrier', 27),
#  ('male', 'Golden Retriever-Poodle Mix', 26),
#  ('male', 'Border Collie-Australian Shepherd Mix', 26),
#  ('male', 'Samoyed', 26),
#  ('male', 'Lhasa Apso', 25),
#  ('male', 'Labrador Retriever-American Pit Bull Terrier Mix', 25),
#  ('male', 'Chihuahua-Dachshund Mix', 25),
#  ('male', 'Border Collie-Labrador Retriever Mix', 24),
#  ('male', 'Brussels Griffon', 23),
#  ('male', 'Labrador Retriever-Border Collie Mix', 23),
#  ('male', 'Maltese-Yorkshire Terrier Mix', 23),
#  ('male', 'Mastiff', 22),
#  ('male', 'Australian Shepherd-Border Collie Mix', 22),
#  ('male', 'Italian Greyhound', 22),
#  ('male', 'Bichon Frise-Poodle Mix', 22),
#  ('male', 'Bull Terrier', 21),
#  ('male', 'St. Bernard', 21),
#  ('male', 'Miniature American Shepherd', 21),
#  ('male', 'German Shepherd Dog-Labrador Retriever Mix', 20),
#  ('male', 'Silky Terrier', 19),
#  ('male', 'English Setter', 19),
#  ('male', 'Cardigan Welsh Corgi', 19),
#  ('male', 'Old English Sheepdog', 19),
#  ('male', 'Labrador Retriever-Poodle Mix', 18),
#  ('male', 'Chinese Crested', 18),
#  ('male', 'Catahoula Leopard Dog', 18),
#  ('male', 'Cane Corso', 17),
#  ('male', 'Chinese Shar-Pei', 17),
#  ('male', 'Basenji', 17),
#  ('male', 'Shorkie', 17),
#  ('male', 'Bouvier des Flandres', 17),
#  ('male', 'Tibetan Terrier', 16),
#  ('male', 'Labrador Retriever-Rottweiler Mix', 16),
#  ('male', 'Poodle-Miniature Schnauzer Mix', 16),
#  ('male', 'Boxer-Labrador Retriever Mix', 16),
#  ('male', 'American Pit Bull Terrier-Boxer Mix', 16),
#  ('male', 'Border Collie-Australian Cattle Dog Mix', 16),
#  ('male', 'Bichon Frise-Shih Tzu Mix', 16),
#  ('male', 'Cavalier King Charles Spaniel-Poodle Mix', 15),
#  ('male', 'Miniature Australian Shepherd', 15),
#  ('male', 'Poodle-Shih Tzu Mix', 15),
#  ('male', 'American Pit Bull Terrier-Labrador Retriever Mix', 15),
#  ('male', 'German Wirehaired Pointer', 15),
#  ('male', 'Chesapeake Bay Retriever', 15),
#  ('male', 'Chihuahua-Miniature Pinscher Mix', 15),
#  ('male', 'Yorkshire Terrier-Maltese Mix', 15),
#  ('male', 'German Shepherd Dog-Siberian Husky Mix', 14),
#  ('male', 'Chow Chow', 14),
#  ('male', 'Poodle-Yorkshire Terrier Mix', 14),
#  ('male', 'Keeshond', 14),
#  ('male', 'Labrador Retriever-Weimaraner Mix', 14),
#  ('male', 'Wire Fox Terrier', 14),
#  ('male', 'Australian Terrier', 14),
#  ('male', 'Pekingese', 14),
#  ('male', 'Siberian Husky-German Shepherd Dog Mix', 13),
#  ('male', 'Chihuahua-Rat Terrier Mix', 13),
#  ('male', 'Australian Shepherd-Poodle Mix', 13),
#  ('male', 'Bullmastiff', 13),
#  ('male', 'Irish Setter', 13),
#  ('male', 'Maltese-Shih Tzu Mix', 13),
#  ('male', 'Dutch Shepherd', 13),
#  ('male', 'Chihuahua-Yorkshire Terrier Mix', 12),
#  ('male', 'Leonberger', 12),
#  ('male', 'Poodle-Maltese Mix', 12),
#  ('male', 'Bugg', 11),
#  ('male', 'Bearded Collie', 11),
#  ('male', 'German Shepherd Dog-Golden Retriever Mix', 11),
#  ('male', 'Beaglier', 11),
#  ('male', 'Australian Shepherd-Labrador Retriever Mix', 11),
#  ('male', 'Schipperke', 11),
#  ('male', 'Beagle-Labrador Retriever Mix', 10),
#  ('male', 'Treeing Walker Coonhound', 10),
#  ('male', 'Lagotto Romagnolo', 10),
#  ('male', 'Welsh Terrier', 10),
#  ('male', 'Belgian Sheepdog', 10),
#  ('male', 'Welsh Springer Spaniel', 10),
#  ('male', 'Poodle-Bichon Frise Mix', 10),
#  ('male', 'BullBoxer', 10),
#  ('male', 'Labrador Retriever- Mix', 10),
#  ('male', 'American Pit Bull Terrier-American Staffordshire Terrier Mix', 10),
#  ('male', 'American Staffordshire Terrier-American Pit Bull Terrier Mix', 10),
#  ('male', 'Greater Swiss Mountain Dog', 10),
#  ('male', 'Norwich Terrier', 10),
#  ('male', 'Australian Cattle Dog-Border Collie Mix', 10),
#  ('male', 'Pomapoo', 10),
#  ('male', 'Anatolian Shepherd Dog', 9),
#  ('male', 'Pointer', 9),
#  ('male', 'Giant Schnauzer', 9),
#  ('male', 'Tibetan Spaniel', 9),
#  ('male', 'Chihuahua-Pomeranian Mix', 9),
#  ('male', 'Australian Cattle Dog-Australian Shepherd Mix', 9),
#  ('male', 'Rottweiler-Labrador Retriever Mix', 9),
#  ('male', 'Yorkshire Terrier-Miniature Schnauzer Mix', 9),
#  ('male', 'Affenpinscher', 9),
#  ('male', 'Cavalier King Charles Spaniel-Bichon Frise Mix', 9),
#  ('male', 'Belgian Tervuren', 9),
#  ('male', 'Shih Tzu-Bichon Frise Mix', 9),
#  ('male', 'Icelandic Sheepdog', 9),
#  ('male', 'Chihuahua-Jack Russell Terrier Mix', 9),
#  ('male', 'Labrador Retriever-Siberian Husky Mix', 9),
#  ('male', 'Spinone Italiano', 8),
#  ('male', 'Bluetick Coonhound', 8),
#  ('male', 'Norfolk Terrier', 8),
#  ('male', 'Dogo Argentino', 8),
#  ('male', 'German Shepherd Dog-Border Collie Mix', 8),
#  ('male', 'Irish Wolfhound', 8),
#  ('male', 'Pomeranian-Chihuahua Mix', 8),
#  ('male', 'Wirehaired Pointing Griffon', 8),
#  ('male', 'Briard', 8),
#  ('male', 'Border Collie-German Shepherd Dog Mix', 8),
#  ('male', 'Irish Terrier', 8),
#  ('male', 'Poodle-Cocker Spaniel Mix', 8),
#  ('male', 'German Shepherd Dog-Rottweiler Mix', 8),
#  ('male', 'Hovawart', 8),
#  ('male', 'Lhasa Apso-Shih Tzu Mix', 8),
#  ('male', 'Toy Fox Terrier', 8),
#  ('male', 'Alaskan Malamute-Siberian Husky Mix', 8),
#  ('male', 'Chihuahua-Pug Mix', 8),
#  ('male', 'Afghan Hound', 8),
#  ('male', 'Manchester Terrier', 7),
#  ('male', 'Rottweiler-German Shepherd Dog Mix', 7),
#  ('male', 'Kerry Blue Terrier', 7),
#  ('male', 'Field Spaniel', 7),
#  ('male', 'Golden Retriever-German Shepherd Dog Mix', 7),
#  ('male', 'Australian Shepherd-Australian Cattle Dog Mix', 7),
#  ('male', 'Labrador Retriever-Great Dane Mix', 7),
#  ('male', 'Norwegian Elkhound', 7),
#  ('male', 'Shih Tzu-Maltese Mix', 7),
#  ('male', 'Beagle-Russell Terrier Mix', 7),
#  ('male', 'Siberian Husky-Labrador Retriever Mix', 7),
#  ('male', 'Gordon Setter', 7),
#  ('male', 'Alaskan Malamute-German Shepherd Dog Mix', 7),
#  ('male', 'Poodle-Golden Retriever Mix', 7),
#  ('male', 'Beauceron', 7),
#  ('male', 'Labrador Retriever-Australian Shepherd Mix', 7),
#  ('male', 'Bichon Frise-Cavalier King Charles Spaniel Mix', 7),
#  ('male', 'Boxer-American Pit Bull Terrier Mix', 7),
#  ('male', 'Bloodhound', 7),
#  ('male', 'Poodle-Labrador Retriever Mix', 7),
#  ('male', 'Boxer-American Staffordshire Terrier Mix', 6),
#  ('male', 'Labrador Retriever-Chow Chow Mix', 6),
#  ('male', '-Labrador Retriever Mix', 6),
#  ('male', 'Chihuahua-Russell Terrier Mix', 6),
#  ('male', 'German Spitz', 6),
#  ('male', 'Chihuahua-Italian Greyhound Mix', 6),
#  ('male', 'Border Collie-Siberian Husky Mix', 6),
#  ('male', 'American Staffordshire Terrier-Labrador Retriever Mix', 6),
#  ('male', 'Labrador Retriever-Australian Cattle Dog Mix', 6),
#  ('male', 'German Shepherd Dog- Mix', 6),
#  ('male', 'German Shepherd Dog-Chow Chow Mix', 6),
#  ('male', 'Labrador Retriever-German Shorthaired Pointer Mix', 6),
#  ('male', 'Xoloitzcuintli', 6),
#  ('male', 'Redbone Coonhound', 6),
#  ('male', 'Australian Cattle Dog-German Shepherd Dog Mix', 6),
#  ('male', 'Finnish Lapphund', 6),
#  ('male', 'Jack-A-Poo', 6),
#  ('male', 'Dachshund-Chihuahua Mix', 6),
#  ('male', 'Czechoslovakian Vlcak', 6),
#  ('male', 'Border Collie-Golden Retriever Mix', 6),
#  ('male', 'Australian Kelpie', 6),
#  ('male', 'American Pit Bull Terrier-Bulldog Mix', 6),
#  ('male', 'Border Collie-Greyhound Mix', 6),
#  ('male', 'Neapolitan Mastiff', 6),
#  ('male', 'Poodle-Cavalier King Charles Spaniel Mix', 6),
#  ('male', 'Smooth Fox Terrier', 5),
#  ('male', 'Labrador Retriever-Chesapeake Bay Retriever Mix', 5),
#  ('male', 'Dachshund-Labrador Retriever Mix', 5),
#  ('male', 'German Shorthaired Pointer-Labrador Retriever Mix', 5),
#  ('male', 'Bedlington Terrier', 5),
#  ('male', 'Lakeland Terrier', 5),
#  ('male', 'Saluki', 5),
#  ('male', 'Boerboel', 5),
#  ('male', 'Boston Terrier-French Bulldog Mix', 5),
#  ('male', 'Pug-Shih Tzu Mix', 5),
#  ('male', 'Yorkshire Terrier-Chihuahua Mix', 5),
#  ('male', 'German Pinscher', 5),
#  ('male', 'Boykin Spaniel', 5),
#  ('male', 'Japanese Chin', 5),
#  ('male', 'Labrador Retriever-Greyhound Mix', 5),
#  ('male', 'Beagle-Pug Mix', 5),
#  ('male', 'Poodle-Soft Coated Wheaten Terrier Mix', 5),
#  ('male', 'Dogue de Bordeaux', 5),
#  ('male', 'Labrador Retriever-Pointer Mix', 5),
#  ('male', 'Pekingese-Poodle Mix', 5),
#  ('male', 'Lhasa Apso-Poodle Mix', 5),
#  ('male', 'Border Collie-English Springer Spaniel Mix', 5),
#  ('male', 'Rat Terrier-Chihuahua Mix', 5),
#  ('male', 'Poodle-Standard Schnauzer Mix', 5),
#  ('male', 'German Shepherd Dog-Australian Shepherd Mix', 5),
#  ('male', 'German Shepherd Dog-Alaskan Malamute Mix', 5),
#  ('male', 'Borzoi', 5),
#  ('male', 'Wirehaired Vizsla', 5),
#  ('male', 'Clumber Spaniel', 5),
#  ('male', 'Chihuahua-Papillon Mix', 5),
#  ('male', 'Pug-Chihuahua Mix', 5),
#  ('male', 'Australian Shepherd-Golden Retriever Mix', 5),
#  ('male', 'German Shepherd Dog-Belgian Malinois Mix', 5),
#  ('male', 'Dachshund-Miniature Pinscher Mix', 4),
#  ('male', 'Spanish Water Dog', 4),
#  ('male', 'Chinook', 4),
#  ('male', 'Yorkshire Terrier- Mix', 4),
#  ('male', 'German Shepherd Dog-American Pit Bull Terrier Mix', 4),
#  ('male', 'Dachshund-Beagle Mix', 4),
#  ('male', 'German Shepherd Dog-Poodle Mix', 4),
#  ('male', 'Poodle-English Springer Spaniel Mix', 4),
#  ('male', 'Glen of Imaal Terrier', 4),
#  ('male', 'Border Collie-Flat-Coated Retriever Mix', 4),
#  ('male', 'Catahoula Leopard Dog-Australian Cattle Dog Mix', 4),
#  ('male', 'Havanese-Poodle Mix', 4),
#  ('male', 'Bichon Frise-Maltese Mix', 4),
#  ('male', 'Pug-French Bulldog Mix', 4),
#  ('male', 'Jack Russell Terrier-Rat Terrier Mix', 4),
#  ('male', 'Plott', 4),
#  ('male', 'Australian Shepherd- Mix', 4),
#  ('male', 'Golden Retriever-Chow Chow Mix', 4),
#  ('male', 'Irish Water Spaniel', 4),
#  ('male', 'American Staffordshire Terrier-Border Collie Mix', 4),
#  ('male', 'Catahoula Leopard Dog-Labrador Retriever Mix', 4),
#  ('male', 'Yorkshire Terrier-Shih Tzu Mix', 4),
#  ('male', 'American Staffordshire Terrier- Mix', 4),
#  ('male', 'Pharaoh Hound', 4),
#  ('male', 'Berger Picard', 4),
#  ('male', 'American Pit Bull Terrier-Great Dane Mix', 4),
#  ('male', 'American Water Spaniel', 4),
#  ('male', 'Pyrenean Shepherd', 4),
#  ('male', 'Chesapeake Bay Retriever-Labrador Retriever Mix', 4),
#  ('male', 'Poodle-Pekingese Mix', 4),
#  ('male', 'Chow Chow-Labrador Retriever Mix', 4),
#  ('male', 'Great Dane-Labrador Retriever Mix', 4),
#  ('male', 'Black Russian Terrier', 4),
#  ('male', 'Puli', 4),
#  ('male', 'Labrador Retriever-Mastiff Mix', 4),
#  ('male', 'Bullmastiff-Staffordshire Bull Terrier Mix', 4),
#  ('male', '-Australian Cattle Dog Mix', 4),
#  ('male', 'Irish Red and White Setter', 4),
#  ('male', 'Labrador Retriever-Beagle Mix', 4),
#  ('male', 'Dachshund-Yorkshire Terrier Mix', 4),
#  ('male', 'Chihuahua- Mix', 4),
#  ('male', 'Golden Retriever-Great Pyrenees Mix', 4),
#  ('male', 'Entlebucher Mountain Dog', 4),
#  ('male', 'Pug-Beagle Mix', 4),
#  ('male', 'Siberian Husky-Australian Shepherd Mix', 4),
#  ('male', 'Swedish Vallhund', 4),
#  ('male', 'Border Collie-Australian Kelpie Mix', 4),
#  ('male', 'Black and Tan Coonhound', 3),
#  ('male', 'Great Pyrenees-Golden Retriever Mix', 3),
#  ('male', 'Collie-German Shepherd Dog Mix', 3),
#  ('male', 'Labrador Retriever-Boxer Mix', 3),
#  ('male', 'Staffordshire Bull Terrier-Australian Kelpie Mix', 3),
#  ('male', 'Shih Tzu-Pekingese Mix', 3),
#  ('male', 'Russell Terrier-Chihuahua Mix', 3),
#  ('male', 'Border Collie-Newfoundland Mix', 3),
#  ('male', 'Pomeranian-Yorkshire Terrier Mix', 3),
#  ('male', 'Staffordshire Bull Terrier-Labrador Retriever Mix', 3),
#  ('male', 'Lowchen', 3),
#  ('male', 'Eurasier', 3),
#  ('male', 'Collie-Labrador Retriever Mix', 3),
#  ('male', 'Siberian Husky-American Pit Bull Terrier Mix', 3),
#  ('male', 'Yorkshire Terrier-Silky Terrier Mix', 3),
#  ('male', 'Border Collie-Shetland Sheepdog Mix', 3),
#  ('male', 'Labrador Retriever-American Staffordshire Terrier Mix', 3),
#  ('male', 'Pug-Miniature Pinscher Mix', 3),
#  ('male', 'Yorkshire Terrier-Bichon Frise Mix', 3),
#  ('male', 'American Pit Bull Terrier-Rhodesian Ridgeback Mix', 3),
#  ('male', 'American Eskimo Dog-Pomeranian Mix', 3),
#  ('male', '-American Pit Bull Terrier Mix', 3),
#  ('male', 'Labrador Retriever-Chinese Shar-Pei Mix', 3),
#  ('male', 'Parson Russell Terrier-Poodle Mix', 3),
#  ('male', 'Jindo', 3),
#  ('male', 'Australian Shepherd-Siberian Husky Mix', 3),
#  ('male', '-German Shepherd Dog Mix', 3),
#  ('male', '-Border Collie Mix', 3),
#  ('male', 'Dachshund-Poodle Mix', 3),
#  ('male', 'French Bulldog-Boston Terrier Mix', 3),
#  ('male', 'Golden Retriever-St. Bernard Mix', 3),
#  ('male', 'Rhodesian Ridgeback-Labrador Retriever Mix', 3),
#  ('male', 'Australian Shepherd-German Shepherd Dog Mix', 3),
#  ('male', 'Chihuahua-Pekingese Mix', 3),
#  ('male', 'American Staffordshire Terrier-Boxer Mix', 3),
#  ('male', 'Basset Hound-Beagle Mix', 3),
#  ('male', 'Doberman Pinscher-Labrador Retriever Mix', 3),
#  ('male', 'American Pit Bull Terrier-Pointer Mix', 3),
#  ('male', 'Poodle-Chihuahua Mix', 3),
#  ('male', 'Labrador Retriever-English Springer Spaniel Mix', 3),
#  ('male', 'French Spaniel', 3),
#  ('male', 'German Shepherd Dog-Doberman Pinscher Mix', 3),
#  ('male', 'Labrador Retriever-St. Bernard Mix', 3),
#  ('male', 'Akita-German Shepherd Dog Mix', 3),
#  ('male', 'Russian Toy', 3),
#  ('male', 'Brittany-German Shorthaired Pointer Mix', 3),
#  ('male', 'Australian Shepherd-Pembroke Welsh Corgi Mix', 3),
#  ('male', 'Airedale Terrier-Labrador Retriever Mix', 3),
#  ('male', 'Dachshund-Pug Mix', 3),
#  ('male', 'Border Collie-Pembroke Welsh Corgi Mix', 3),
#  ('male', 'Shih Tzu-Yorkshire Terrier Mix', 3),
#  ('male', 'Jack Russell Terrier-Beagle Mix', 3),
#  ('male', 'Greyhound-Labrador Retriever Mix', 3),
#  ('male', 'Staffordshire Bull Terrier-Australian Cattle Dog Mix', 3),
#  ('male', 'Kooikerhondje', 3),
#  ('male', 'Miniature Bull Terrier', 3),
#  ('male', 'Bichon Frise-Lhasa Apso Mix', 3),
#  ('male', 'Stabyhoun', 3),
#  ('male', 'Shetland Sheepdog-Border Collie Mix', 3),
#  ('male', 'Australian Shepherd-Chow Chow Mix', 3),
#  ('male', 'Polish Lowland Sheepdog', 3),
#  ('male', 'Bernese Mountain Dog-Poodle Mix', 3),
#  ('male', 'Greyhound-Border Collie Mix', 3),
#  ('male', 'Tibetan Mastiff', 3),
#  ('male', 'West Highland White Terrier-Bichon Frise Mix', 3),
#  ('male', 'Bull Terrier-Labrador Retriever Mix', 3),
#  ('male', 'Australian Cattle Dog-Beagle Mix', 3),
#  ('male', 'American Staffordshire Terrier-Bullmastiff Mix', 3),
#  ('male', 'Chihuahua-Pembroke Welsh Corgi Mix', 3),
#  ('male', 'American Pit Bull Terrier-Bullmastiff Mix', 3),
#  ('male', 'Chinese Shar-Pei- Mix', 3),
#  ('male', 'German Shepherd Dog-Rhodesian Ridgeback Mix', 3),
#  ('male', 'Border Terrier-Lakeland Terrier Mix', 3),
#  ('male', 'Beagle-Border Collie Mix', 3),
#  ('male', 'Pumi', 3),
#  ('male', 'Chihuahua-Australian Terrier Mix', 2),
#  ('male', 'Border Collie-Irish Setter Mix', 2),
#  ('male', 'Chihuahua-Shiba Inu Mix', 2),
#  ('male', 'Akita-Afghan Hound Mix', 2),
#  ('male', 'Labrador Retriever-Staffordshire Bull Terrier Mix', 2),
#  ('male', 'Border Collie-Whippet Mix', 2),
#  ('male', 'Parson Russell Terrier-Russell Terrier Mix', 2),
#  ('male', 'American Staffordshire Terrier-Bull Terrier Mix', 2),
#  ('male', 'Soft Coated Wheaten Terrier-Poodle Mix', 2),
#  ('male', 'Siberian Husky-Standard Schnauzer Mix', 2),
#  ('male', 'Jack Russell Terrier-American Pit Bull Terrier Mix', 2),
#  ('male', 'Boston Terrier-Bulldog Mix', 2),
#  ('male', 'Chihuahua-Toy Fox Terrier Mix', 2),
#  ('male', 'Labrador Retriever-Bloodhound Mix', 2),
#  ('male', 'Russell Terrier-Shih Tzu Mix', 2),
#  ('male', 'Cavalier King Charles Spaniel-Cocker Spaniel Mix', 2),
#  ('male', 'Poodle-Rat Terrier Mix', 2),
#  ('male', 'Bulldog-Bullmastiff Mix', 2),
#  ('male', 'Small Munsterlander Pointer', 2),
#  ('male', 'Cocker Spaniel-Cavalier King Charles Spaniel Mix', 2),
#  ('male', 'Dachshund-Rat Terrier Mix', 2),
#  ('male', 'Poodle-Dachshund Mix', 2),
#  ('male', 'Papillon-Pomeranian Mix', 2),
#  ('male', 'Chihuahua-Cairn Terrier Mix', 2),
#  ('male', 'Caucasian Ovcharka', 2),
#  ('male', 'Miniature Pinscher-Chihuahua Mix', 2),
#  ('male', 'Poodle-German Shepherd Dog Mix', 2),
#  ('male', 'Miniature Pinscher- Mix', 2),
#  ('male', 'Beagle-Pekingese Mix', 2),
#  ('male', 'Bulldog-Beagle Mix', 2),
#  ('male', 'Italian Greyhound-Miniature Pinscher Mix', 2),
#  ('male', 'Great Dane-American Staffordshire Terrier Mix', 2),
#  ('male', 'Boxer-Boston Terrier Mix', 2),
#  ('male', 'Siberian Husky-Greyhound Mix', 2),
#  ('male', 'Greyhound-Saluki Mix', 2),
#  ('male', 'Papillon-Japanese Chin Mix', 2),
#  ('male', 'English Springer Spaniel-Labrador Retriever Mix', 2),
#  ('male', 'Shih Tzu-Russell Terrier Mix', 2),
#  ('male', 'Standard Poodle-Soft Coated Wheaten Terrier Mix', 2),
#  ('male', 'Dandie Dinmont Terrier', 2),
#  ('male', 'Mastiff-Great Dane Mix', 2),
#  ('male', 'Chow Chow-Golden Retriever Mix', 2),
#  ('male', 'Poodle-Australian Cattle Dog Mix', 2),
#  ('male', 'Labrador Retriever-Flat-Coated Retriever Mix', 2),
#  ('male', 'Miniature Schnauzer-Wire Fox Terrier Mix', 2),
#  ('male', 'Rat Terrier-Basenji Mix', 2),
#  ('male', 'Dalmatian-Labrador Retriever Mix', 2),
#  ('male', 'Bernese Mountain Dog-Border Collie Mix', 2),
#  ('male', 'Mastiff-Labrador Retriever Mix', 2),
#  ('male', 'Brittany-English Springer Spaniel Mix', 2),
#  ('male', 'German Shepherd Dog-Redbone Coonhound Mix', 2),
#  ('male', 'Yorkshire Terrier-Cairn Terrier Mix', 2),
#  ('male', 'Pug-American Pit Bull Terrier Mix', 2),
#  ('male', 'German Shepherd Dog-Beagle Mix', 2),
#  ('male', 'Border Collie- Mix', 2),
#  ('male', 'Cirneco dell"Etna', 2),
#  ('male', 'Beagle-Pointer Mix', 2),
#  ('male', 'Greyhound-Staffordshire Bull Terrier Mix', 2),
#  ('male', 'Australian Labradoodle-Poodle Mix', 2),
#  ('male', 'German Longhaired Pointer', 2),
#  ('male', 'Beagle-Golden Retriever Mix', 2),
#  ('male', 'Danish-Swedish Farmdog', 2),
#  ('male', 'Pembroke Welsh Corgi-Chihuahua Mix', 2),
#  ('male', 'Jack Russell Terrier-Chihuahua Mix', 2),
#  ('male', 'Anatolian Shepherd Dog-Great Pyrenees Mix', 2),
#  ('male', 'American Staffordshire Terrier-Chinese Shar-Pei Mix', 2),
#  ('male', 'Bulldog-Boxer Mix', 2),
#  ('male', 'Appenzeller Sennenhunde', 2),
#  ('male', 'Beagle-Parson Russell Terrier Mix', 2),
#  ('male', 'Komondor', 2),
#  ('male', 'Cavalier King Charles Spaniel-Coton de Tulear Mix', 2),
#  ('male', 'Pug- Mix', 2),
#  ('male', 'Border Collie-Saluki Mix', 2),
#  ('male', 'Cardigan Welsh Corgi-American Pit Bull Terrier Mix', 2),
#  ('male', 'Bloodhound-Labrador Retriever Mix', 2),
#  ('male', 'Pug-Lhasa Apso Mix', 2),
#  ('male', 'Poodle-Havanese Mix', 2),
#  ('male', 'Great Pyrenees-Labrador Retriever Mix', 2),
#  ('male', 'Pomeranian-Maltese Mix', 2),
#  ('male', 'Boxer-Bullmastiff Mix', 2),
#  ('male', 'Basset Hound-Labrador Retriever Mix', 2),
#  ('male', 'French Bulldog-Pug Mix', 2),
#  ('male', 'Pug-Wire Fox Terrier Mix', 2),
#  ('male', 'Siberian Husky-Border Collie Mix', 2),
#  ('male', 'Dachshund-Cocker Spaniel Mix', 2),
#  ('male', 'Havanese-Maltese Mix', 2),
#  ('male', 'Boxer-Vizsla Mix', 2),
#  ('male', 'Pug-Russell Terrier Mix', 2),
#  ('male', 'Miniature Pinscher-Rat Terrier Mix', 2),
#  ('male', 'Dachshund-Parson Russell Terrier Mix', 2),
#  ('male', 'Catahoula Leopard Dog-Bluetick Coonhound Mix', 2),
#  ('male', 'Chihuahua-Maltese Mix', 2),
#  ('male', 'Pointer-Labrador Retriever Mix', 2),
#  ('male', 'Beagle-Chihuahua Mix', 2),
#  ('male', 'Siberian Husky-Staffordshire Bull Terrier Mix', 2),
#  ('male', 'Chihuahua-Poodle Mix', 2),
#  ('male', 'Pug-Boston Terrier Mix', 2),
#  ('male', 'Belgian Malinois-Labrador Retriever Mix', 2),
#  ('male', 'Papillon-Poodle Mix', 2),
#  ('male', 'Australian Cattle Dog-Siberian Husky Mix', 2),
#  ('male', 'Labrador Retriever-Bull Terrier Mix', 2),
#  ('male', 'Beagle-Treeing Walker Coonhound Mix', 2),
#  ('male', 'English Springer Spaniel-Cocker Spaniel Mix', 2),
#  ('male', 'Belgian Malinois-German Shepherd Dog Mix', 2),
#  ('male', 'Miniature Schnauzer-Yorkshire Terrier Mix', 2),
#  ('male', 'Border Collie-American Eskimo Dog Mix', 2),
#  ('male', 'Maltese-Chihuahua Mix', 2),
#  ('male', 'Australian Shepherd-Standard Poodle Mix', 2),
#  ('male', 'Poodle-Japanese Chin Mix', 2),
#  ('male', '-Boxer Mix', 2),
#  ('male', 'Beagle-Bulldog Mix', 2),
#  ('male', 'Maltese-Silky Terrier Mix', 2),
#  ('male', 'Russell Terrier-Beagle Mix', 2),
#  ('male', 'Beagle-Rat Terrier Mix', 2),
#  ('male', 'Poodle-Pomeranian Mix', 2),
#  ('male', 'American Pit Bull Terrier- Mix', 2),
#  ('male', 'Jack Russell Terrier-Welsh Terrier Mix', 2),
#  ('male', 'Border Collie-Dalmatian Mix', 2),
#  ('male', 'American Staffordshire Terrier-Staffordshire Bull Terrier Mix', 2),
#  ('male', 'Scottish Deerhound', 2),
#  ('male', 'Beagle-Basset Hound Mix', 2),
#  ('male', 'Labrador Retriever-Rhodesian Ridgeback Mix', 2),
#  ('male', 'German Shepherd Dog-Staffordshire Bull Terrier Mix', 2),
#  ('male', 'American Staffordshire Terrier-Dogo Argentino Mix', 2),
#  ('male', 'West Highland White Terrier-Poodle Mix', 2),
#  ('male', 'Golden Retriever-Australian Shepherd Mix', 2),
#  ('male', 'American Pit Bull Terrier-Mastiff Mix', 2),
#  ('male', 'Yorkshire Terrier-Pekingese Mix', 2),
#  ('male', 'Australian Cattle Dog-Labrador Retriever Mix', 2),
#  ('male', 'Australian Cattle Dog- Mix', 2),
#  ('male', 'Boxer-Rhodesian Ridgeback Mix', 2),
#  ('male', 'Labrador Retriever-Basset Hound Mix', 2),
#  ('male', 'English Setter-Labrador Retriever Mix', 2),
#  ('male', 'Italian Greyhound-Russell Terrier Mix', 2),
#  ('male', 'German Shepherd Dog-Shetland Sheepdog Mix', 2),
#  ('male', 'German Shorthaired Pointer-Pointer Mix', 2),
#  ('male', 'Petit Basset Griffon Vendeen', 2),
#  ('male', 'Pomeranian-Pekingese Mix', 2),
#  ('male', 'Maltese-Pomeranian Mix', 2),
#  ('male', 'Border Collie-Rottweiler Mix', 2),
#  ('male', 'Dalmatian-American Pit Bull Terrier Mix', 2),
#  ('male', 'Chinese Shar-Pei-German Shepherd Dog Mix', 2),
#  ('male', 'Sealyham Terrier', 2),
#  ('male', 'Thai Ridgeback', 2),
#  ('male', 'Bulldog-American Pit Bull Terrier Mix', 2),
#  ('male', 'Siberian Husky-Shiba Inu Mix', 2),
#  ('male', 'Boxer-German Shepherd Dog Mix', 2),
#  ('male', 'Poodle- Mix', 2),
#  ('male', 'Chihuahua-Boston Terrier Mix', 2),
#  ('male', 'Curly-Coated Retriever', 2),
#  ('male', 'Pug-Brussels Griffon Mix', 2),
#  ('male', 'Shetland Sheepdog-Collie Mix', 2),
#  ('male', 'Border Collie-Great Pyrenees Mix', 2),
#  ('male', 'Russell Terrier- Mix', 2),
#  ('male', 'Russell Terrier-Toy Fox Terrier Mix', 2),
#  ('male', 'Border Collie-Bearded Collie Mix', 2),
#  ('male', 'Labrador Retriever-Vizsla Mix', 2),
#  ('male', 'Staffordshire Bull Terrier-Beagle Mix', 2),
#  ('male', 'Brittany-Labrador Retriever Mix', 2),
#  ('male', 'Rat Terrier-Dachshund Mix', 2),
#  ('male', 'Mastiff-American Pit Bull Terrier Mix', 2),
#  ('male', 'Old English Sheepdog-Poodle Mix', 2),
#  ('male', 'Parson Russell Terrier- Mix', 2),
#  ('male', 'Bolognese', 2),
#  ('male', 'Collie- Mix', 2),
#  ('male', 'Flat-Coated Retriever- Mix', 2),
#  ('male', 'American Foxhound-Labrador Retriever Mix', 2),
#  ('male', '-Anatolian Shepherd Dog Mix', 2),
#  ('male', 'German Shepherd Dog-Australian Cattle Dog Mix', 2),
#  ('male', 'Miniature Schnauzer-Chihuahua Mix', 2),
#  ('male', 'American Pit Bull Terrier-Plott Mix', 2),
#  ('male', 'Pembroke Welsh Corgi-Russell Terrier Mix', 2),
#  ('male', 'Pomeranian-Papillon Mix', 2),
#  ('male', 'Rottweiler-American Pit Bull Terrier Mix', 2),
#  ('male', 'Bernese Mountain Dog-Golden Retriever Mix', 2),
#  ('male', 'English Springer Spaniel-Border Collie Mix', 2),
#  ('male', 'Whippet-Border Collie Mix', 2),
#  ('male', 'English Springer Spaniel-Dalmatian Mix', 2),
#  ('male', 'Poodle-Lhasa Apso Mix', 2),
#  ('male', 'Chihuahua-Beagle Mix', 2),
#  ('male', 'Labrador Retriever-Dachshund Mix', 2),
#  ('male', 'Brussels Griffon-Pug Mix', 2),
#  ('male', 'Ibizan Hound', 2),
#  ('male', 'Otterhound', 2),
#  ('male', 'Chesapeake Bay Retriever-Siberian Husky Mix', 2),
#  ('male', 'Bichon Frise-West Highland White Terrier Mix', 2),
#  ('male', 'Border Collie-Great Dane Mix', 2),
#  ('male', 'Golden Retriever-Collie Mix', 2),
#  ('male', 'Havanese-Shih Tzu Mix', 2),
#  ('male', 'Italian Greyhound-Dachshund Mix', 1),
#  ('male', 'Pyrenean Shepherd-Collie Mix', 1),
#  ('male', 'Papillon-Pug Mix', 1),
#  ('male', 'Standard Poodle-Dachshund Mix', 1),
#  ('male', 'German Shepherd Dog-Gordon Setter Mix', 1),
#  ('male', 'Manchester Terrier-Chihuahua Mix', 1),
#  ('male', 'Akita-Labrador Retriever Mix', 1),
#  ('male', 'Treeing Walker Coonhound-Great Dane Mix', 1),
#  ('male', 'Cavalier King Charles Spaniel-Papillon Mix', 1),
#  ('male', 'Miniature Pinscher-Border Collie Mix', 1),
#  ('male', 'German Shepherd Dog-Mastiff Mix', 1),
#  ('male', 'Great Pyrenees-Bernese Mountain Dog Mix', 1),
#  ('male', 'Jack Russell Terrier-Staffordshire Bull Terrier Mix', 1),
#  ('male', 'Siberian Husky-Rottweiler Mix', 1),
#  ('male', 'Clumber Spaniel-English Springer Spaniel Mix', 1),
#  ('male', 'Jack Russell Terrier-Smooth Fox Terrier Mix', 1),
#  ('male', 'Poodle-Bernese Mountain Dog Mix', 1),
#  ('male', 'Catahoula Leopard Dog-Boxer Mix', 1),
#  ('male', 'Alaskan Malamute- Mix', 1),
#  ('male', 'Newfoundland-St. Bernard Mix', 1),
#  ('male', 'Catahoula Leopard Dog-American Pit Bull Terrier Mix', 1),
#  ('male', 'Russell Terrier-Manchester Terrier Mix', 1),
#  ('male', 'Bloodhound-Beagle Mix', 1),
#  ('male', 'Beagle-Cocker Spaniel Mix', 1),
#  ('male', 'Border Terrier-Bernese Mountain Dog Mix', 1),
#  ('male', 'Boxer-Poodle Mix', 1),
#  ('male', 'Rottweiler-Komondor Mix', 1),
#  ('male', 'Bullmastiff-Chinese Shar-Pei Mix', 1),
#  ('male', 'American Eskimo Dog-Australian Shepherd Mix', 1),
#  ('male', 'Pembroke Welsh Corgi-Dachshund Mix', 1),
#  ('male', 'Yorkshire Terrier-Dogue de Bordeaux Mix', 1),
#  ('male', 'Shih Tzu-Coton de Tulear Mix', 1),
#  ('male', 'Boston Terrier-Pug Mix', 1),
#  ('male', 'Siberian Husky-Australian Cattle Dog Mix', 1),
#  ('male', 'Maltese-Tibetan Spaniel Mix', 1),
#  ('male', 'Standard Schnauzer-Yorkshire Terrier Mix', 1),
#  ('male', 'Icelandic Sheepdog-Papillon Mix', 1),
#  ('male', 'Golden Retriever-Chinese Shar-Pei Mix', 1),
#  ('male', 'Chinese Shar-Pei-Boerboel Mix', 1),
#  ('male', 'Australian Shepherd-Cocker Spaniel Mix', 1),
#  ('male', 'Dachshund-Glen of Imaal Terrier Mix', 1),
#  ('male', 'Shih Tzu-West Highland White Terrier Mix', 1),
#  ('male', 'American Pit Bull Terrier-Australian Shepherd Mix', 1),
#  ('male', 'Border Collie-Beauceron Mix', 1),
#  ('male', 'Miniature Schnauzer-Scottish Terrier Mix', 1),
#  ('male', 'Australian Shepherd-Beagle Mix', 1),
#  ('male', 'Australian Terrier-Rottweiler Mix', 1),
#  ('male', 'Cavalier King Charles Spaniel-Maltese Mix', 1),
#  ('male', 'Vizsla- Mix', 1),
#  ('male', 'Wire Fox Terrier-Australian Cattle Dog Mix', 1),
#  ('male', 'Cairn Terrier-Yorkshire Terrier Mix', 1),
#  ('male', 'Newfoundland-Weimaraner Mix', 1),
#  ('male', 'Bernese Mountain Dog-Labrador Retriever Mix', 1),
#  ('male', 'Whippet-Pointer Mix', 1),
#  ('male', 'Staffordshire Bull Terrier-American Staffordshire Terrier Mix', 1),
#  ('male', 'Pekingese-Lhasa Apso Mix', 1),
#  ('male', '-Shih Tzu Mix', 1),
#  ('male', 'Basenji-Whippet Mix', 1),
#  ('male', 'Bulldog-French Bulldog Mix', 1),
#  ('male', 'Golden Retriever-Polish Lowland Sheepdog Mix', 1),
#  ('male', 'Brittany-Golden Retriever Mix', 1),
#  ('male', 'Boykin Spaniel- Mix', 1),
#  ('male', 'Chihuahua-Parson Russell Terrier Mix', 1),
#  ('male', 'American Pit Bull Terrier-Greyhound Mix', 1),
#  ('male', 'Pekingese-Pomeranian Mix', 1),
#  ('male', 'Cairn Terrier-Poodle Mix', 1),
#  ('male', 'Beagle- Mix', 1),
#  ('male', 'Wire Fox Terrier-Chihuahua Mix', 1),
#  ('male', 'Pointer-Australian Shepherd Mix', 1),
#  ('male', 'Anatolian Shepherd Dog-Labrador Retriever Mix', 1),
#  ('male', 'Greyhound-American Pit Bull Terrier Mix', 1),
#  ('male', 'Jack Russell Terrier-Poodle Mix', 1),
#  ('male', 'Deutscher Wachtelhund- Mix', 1),
#  ('male', 'Boxer-Redbone Coonhound Mix', 1),
#  ('male', 'Irish Wolfhound-Bouvier des Flandres Mix', 1),
#  ('male', '-Bluetick Coonhound Mix', 1),
#  ('male', 'Chesapeake Bay Retriever-Beagle Mix', 1),
#  ('male', 'Akita-Affenpinscher Mix', 1),
#  ('male', 'Poodle-Tibetan Terrier Mix', 1),
#  ('male', 'Mastador', 1),
#  ('male', 'Affenpinscher-Afghan Hound Mix', 1),
#  ('male', 'Cavalier King Charles Spaniel-Standard Poodle Mix', 1),
#  ('male', 'Border Collie-Borzoi Mix', 1),
#  ('male', 'Yorkshire Terrier-Soft Coated Wheaten Terrier Mix', 1),
#  ('male', 'Siberian Husky- Mix', 1),
#  ('male', 'Border Collie-Standard Poodle Mix', 1),
#  ('male', 'Golden Retriever-Siberian Husky Mix', 1),
#  ('male', 'Jack Russell Terrier-Doberman Pinscher Mix', 1),
#  ('male', 'Newfoundland-Rottweiler Mix', 1),
#  ('male', 'American Pit Bull Terrier-Parson Russell Terrier Mix', 1),
#  ('male', 'German Shepherd Dog-English Setter Mix', 1),
#  ('male', '-Otterhound Mix', 1),
#  ('male', 'American Hairless Terrier', 1),
#  ('male', 'Chesapeake Bay Retriever-American Staffordshire Terrier Mix', 1),
#  ('male', 'Australian Shepherd-Shiba Inu Mix', 1),
#  ('male', 'Flat-Coated Retriever-Labrador Retriever Mix', 1),
#  ('male', 'Boykin Spaniel-Deutscher Wachtelhund Mix', 1),
#  ('male', 'Plott-Boxer Mix', 1),
#  ('male', 'Pekingese-Pug Mix', 1),
#  ('male', '-Pug Mix', 1),
#  ('male', 'Bullmastiff-Border Collie Mix', 1),
#  ('male', 'Harrier-Shiba Inu Mix', 1),
#  ('male', 'American English Coonhound', 1),
#  ('male', 'West Highland White Terrier-Dachshund Mix', 1),
#  ('male', 'Mastiff-Great Pyrenees Mix', 1),
#  ('male', 'Cairn Terrier-Smooth Fox Terrier Mix', 1),
#  ('male', 'Shih Tzu-Dachshund Mix', 1),
#  ('male', 'Bernese Mountain Dog-Chow Chow Mix', 1),
#  ('male', '-Chesapeake Bay Retriever Mix', 1),
#  ('male', 'Toy Fox Terrier-German Shepherd Dog Mix', 1),
#  ('male', 'Belgian Tervuren-Basenji Mix', 1),
#  ('male', 'Dalmatian-Beagle Mix', 1),
#  ('male', 'Labrador Retriever-Whippet Mix', 1),
#  ('male', 'Drentsche Patrijshond', 1),
#  ('male', 'Australian Shepherd-Collie Mix', 1),
#  ('male', 'Bulldog-American Staffordshire Terrier Mix', 1),
#  ('male', 'Treeing Walker Coonhound- Mix', 1),
#  ('male', 'Belgian Tervuren-Whippet Mix', 1),
#  ('male', 'German Longhaired Pointer-Pointer Mix', 1),
#  ('male', 'Maltese-Japanese Chin Mix', 1),
#  ('male', 'Keeshond-American Eskimo Dog Mix', 1),
#  ('male', 'Basset Hound-Cocker Spaniel Mix', 1),
#  ('male', 'Dogue de Bordeaux-American Pit Bull Terrier Mix', 1),
#  ('male', 'Belgian Malinois- Mix', 1),
#  ('male', 'Boxer-Golden Retriever Mix', 1),
#  ('male', 'American Eskimo Dog-Pembroke Welsh Corgi Mix', 1),
#  ('male', 'English Springer Spaniel-Poodle Mix', 1),
#  ('male', 'Whippet-Italian Greyhound Mix', 1),
#  ('male', 'Russell Terrier-Australian Cattle Dog Mix', 1),
#  ('male', 'Airedale Terrier-Golden Retriever Mix', 1),
#  ('male', 'Alaskan Malamute-American Pit Bull Terrier Mix', 1),
#  ('male', 'Toy Fox Terrier-Chihuahua Mix', 1),
#  ('male', 'Australian Shepherd-Rottweiler Mix', 1),
#  ('male', 'Collie-Shetland Sheepdog Mix', 1),
#  ('male', 'Bullmastiff-Dogue de Bordeaux Mix', 1),
#  ('male', 'Staffordshire Bull Terrier-Border Collie Mix', 1),
#  ('male', 'Miniature Schnauzer-Havanese Mix', 1),
#  ('male', 'Staffordshire Bull Terrier-Bulldog Mix', 1),
#  ('male', 'Australian Shepherd-Doberman Pinscher Mix', 1),
#  ('male', 'Poodle-Lowchen Mix', 1),
#  ('male', 'Standard Poodle-Standard Schnauzer Mix', 1),
#  ('male', 'Boston Terrier-Danish-Swedish Farmdog Mix', 1),
#  ('male', 'Pug-Jack Russell Terrier Mix', 1),
#  ('male', 'Golden Retriever-Standard Schnauzer Mix', 1),
#  ('male', 'American Pit Bull Terrier-Whippet Mix', 1),
#  ('male', 'Norwegian Buhund', 1),
#  ('male', 'Pomeranian-Rat Terrier Mix', 1),
#  ('male', 'Samoyed-Shetland Sheepdog Mix', 1),
#  ('male', 'Shih Tzu-Wire Fox Terrier Mix', 1),
#  ('male', 'American English Coonhound-Redbone Coonhound Mix', 1),
#  ('male', 'Russell Terrier-Miniature Pinscher Mix', 1),
#  ('male', 'American Foxhound- Mix', 1),
#  ('male', 'Staffordshire Bull Terrier-Bernese Mountain Dog Mix', 1),
#  ('male', 'Staffordshire Bull Terrier-Great Dane Mix', 1),
#  ('male', 'Boxer-Staffordshire Bull Terrier Mix', 1),
#  ('male', 'Pekingese-Tibetan Spaniel Mix', 1),
#  ('male', 'Chinese Shar-Pei-American Pit Bull Terrier Mix', 1),
#  ('male', 'Keeshond-Chinese Shar-Pei Mix', 1),
#  ('male', 'Basset Hound-Rottweiler Mix', 1),
#  ('male', 'Smooth Fox Terrier-Chihuahua Mix', 1),
#  ('male', 'Affenpinscher-Airedale Terrier Mix', 1),
#  ('male', 'Great Dane-Bulldog Mix', 1),
#  ('male', 'American Pit Bull Terrier-Cane Corso Mix', 1),
#  ('male', 'Labrador Retriever-Catahoula Leopard Dog Mix', 1),
#  ('male', 'Australian Cattle Dog-Doberman Pinscher Mix', 1),
#  ('male', 'Border Collie-Affenpinscher Mix', 1),
#  ('male', 'Boston Terrier-American Staffordshire Terrier Mix', 1),
#  ('male', 'Basset Hound-Russell Terrier Mix', 1),
#  ('male', 'Maltese-American Foxhound Mix', 1),
#  ('male', 'Russell Terrier-Wire Fox Terrier Mix', 1),
#  ('male', 'German Shorthaired Pointer-Whippet Mix', 1),
#  ('male', 'Treeing Tennessee Brindle-Plott Mix', 1),
#  ('male', 'Redbone Coonhound-Basset Hound Mix', 1),
#  ('male', 'Labrador Retriever-Cocker Spaniel Mix', 1),
#  ('male', 'Wire Fox Terrier-Bulldog Mix', 1),
#  ('male', 'Beagle-Poodle Mix', 1),
#  ('male', 'Poodle-Australian Shepherd Mix', 1),
#  ('male', '-Toy Fox Terrier Mix', 1),
#  ('male', 'Rottweiler-Siberian Husky Mix', 1),
#  ('male', 'Whippet-Chinese Shar-Pei Mix', 1),
#  ('male', 'Cocker Spaniel-Maltese Mix', 1),
#  ('male', '-Whippet Mix', 1),
#  ('male', 'Boston Terrier-Pomeranian Mix', 1),
#  ('male', 'Lhasa Apso-Dandie Dinmont Terrier Mix', 1),
#  ('male', 'Coton de Tulear-Poodle Mix', 1),
#  ('male', 'Basenji-Manchester Terrier Mix', 1),
#  ('male', 'Border Terrier-Shih Tzu Mix', 1),
#  ('male', 'Poodle-Old English Sheepdog Mix', 1),
#  ('male', 'Cairn Terrier-Russell Terrier Mix', 1),
#  ('male', 'American Leopard Hound', 1),
#  ('male', 'Collie-Golden Retriever Mix', 1),
#  ('male', 'Miniature Pinscher-German Shepherd Dog Mix', 1),
#  ('male', 'Labrador Retriever-Pomeranian Mix', 1),
#  ('male', 'Rottweiler-Redbone Coonhound Mix', 1),
#  ('male', 'Greyhound-Irish Wolfhound Mix', 1),
#  ('male', 'Miniature Schnauzer-Airedale Terrier Mix', 1),
#  ('male', 'Affenpinscher-Spanish Water Dog Mix', 1),
#  ('male', 'Lhasa Apso-Maltese Mix', 1),
#  ('male', 'Jack Russell Terrier-Manchester Terrier Mix', 1),
#  ('male', 'Mastiff-Bulldog Mix', 1),
#  ('male', 'Newfoundland-Great Pyrenees Mix', 1),
#  ('male', 'Pomeranian-Tibetan Spaniel Mix', 1),
#  ('male', 'English Setter-English Springer Spaniel Mix', 1),
#  ('male', 'English Springer Spaniel- Mix', 1),
#  ('male', 'Jack Russell Terrier-Dachshund Mix', 1),
#  ('male', 'American Foxhound-Anatolian Shepherd Dog Mix', 1),
#  ('male', 'Jack Russell Terrier-Pug Mix', 1),
#  ('male', 'Standard Schnauzer-Russell Terrier Mix', 1),
#  ('male', '-Rhodesian Ridgeback Mix', 1),
#  ('male', 'Yorkshire Terrier-German Wirehaired Pointer Mix', 1),
#  ('male', 'German Shepherd Dog-Basset Hound Mix', 1),
#  ('male', 'Russell Terrier-Yorkshire Terrier Mix', 1),
#  ('male', 'Borzoi-Whippet Mix', 1),
#  ('male', 'Basenji-Cardigan Welsh Corgi Mix', 1),
#  ('male', 'Cardigan Welsh Corgi-Australian Shepherd Mix', 1),
#  ('male', 'Chinese Crested-Papillon Mix', 1),
#  ('male', 'Pug-Pomeranian Mix', 1),
#  ('male', 'Beagle-Australian Cattle Dog Mix', 1),
#  ('male', 'Greyhound-Whippet Mix', 1),
#  ('male', 'Boxer-Weimaraner Mix', 1),
#  ('male', 'Dogue de Bordeaux-Labrador Retriever Mix', 1),
#  ('male', 'Karelian Bear Dog', 1),
#  ('male', 'Weimaraner-American Pit Bull Terrier Mix', 1),
#  ('male', 'Mudi', 1),
#  ('male', 'Chow Chow-Poodle Mix', 1),
#  ('male', 'Labrador Retriever-Newfoundland Mix', 1),
#  ('male', 'Schapendoes', 1),
#  ('male', 'Redbone Coonhound-German Shepherd Dog Mix', 1),
#  ('male', 'English Toy Spaniel', 1),
#  ('male', 'Chihuahua-Golden Retriever Mix', 1),
#  ('male', 'American Pit Bull Terrier-German Shepherd Dog Mix', 1),
#  ('male', 'Shetland Sheepdog-Norwich Terrier Mix', 1),
#  ('male', 'Boxer-Cocker Spaniel Mix', 1),
#  ('male', 'Greater Swiss Mountain Dog-Border Collie Mix', 1),
#  ('male', 'Bulldog-Labrador Retriever Mix', 1),
#  ('male', 'Russell Terrier-Rat Terrier Mix', 1),
#  ('male', 'Perro de Presa Canario', 1),
#  ('male', 'Rhodesian Ridgeback-American Staffordshire Terrier Mix', 1),
#  ('male', 'Chow Chow-Catahoula Leopard Dog Mix', 1),
#  ('male', 'Catahoula Leopard Dog-Rottweiler Mix', 1),
#  ('male', 'Australian Shepherd-Weimaraner Mix', 1),
#  ('male', 'Australian Cattle Dog-Greyhound Mix', 1),
#  ('male', 'Border Collie-Kooikerhondje Mix', 1),
#  ('male', 'French Bulldog-Havanese Mix', 1),
#  ('male', 'Bichon Frise-Golden Retriever Mix', 1),
#  ('male', 'Cocker Spaniel-Dachshund Mix', 1),
#  ('male', 'Siberian Husky-Jack Russell Terrier Mix', 1),
#  ('male', 'German Shepherd Dog-Greyhound Mix', 1),
#  ('male', 'Dachshund-Staffordshire Bull Terrier Mix', 1),
#  ('male', 'German Shepherd Dog-Ibizan Hound Mix', 1),
#  ('male', 'Great Dane-Boxer Mix', 1),
#  ('male', 'Bedlington Terrier-Whippet Mix', 1),
#  ('male', 'Bull Terrier-American Foxhound Mix', 1),
#  ('male', 'Labrador Retriever-Neapolitan Mastiff Mix', 1),
#  ('male', 'Appenzeller Sennenhunde-Border Collie Mix', 1),
#  ('male', 'Chihuahua-Lhasa Apso Mix', 1),
#  ('male', 'Dachshund-Miniature Schnauzer Mix', 1),
#  ('male', 'Boxer-Mastiff Mix', 1),
#  ('male', 'Rottweiler-Collie Mix', 1),
#  ('male', 'Great Dane-Mastiff Mix', 1),
#  ('male', 'Basenji-German Shepherd Dog Mix', 1),
#  ('male', 'Silky Terrier-Basset Hound Mix', 1),
#  ('male', 'Border Collie-Bluetick Coonhound Mix', 1),
#  ('male', 'Great Pyrenees-Australian Cattle Dog Mix', 1),
#  ('male', 'Boxer-Bloodhound Mix', 1),
#  ('male', 'Cocker Spaniel-Labrador Retriever Mix', 1),
#  ('male', 'Australian Cattle Dog-Rottweiler Mix', 1),
#  ('male', 'Flat-Coated Retriever-Border Collie Mix', 1),
#  ('male', 'Coton de Tulear-Chow Chow Mix', 1),
#  ('male', 'Parson Russell Terrier-Beagle Mix', 1),
#  ('male', 'Bichon Frise-Pomeranian Mix', 1),
#  ('male', 'German Shorthaired Pointer- Mix', 1),
#  ('male', 'Poodle-English Cocker Spaniel Mix', 1),
#  ('male', 'Chow Chow-German Shepherd Dog Mix', 1),
#  ('male', 'Catahoula Leopard Dog-German Shepherd Dog Mix', 1),
#  ('male', 'Maltese- Mix', 1),
#  ('male', 'Keeshond-German Shepherd Dog Mix', 1),
#  ('male', 'Deutscher Wachtelhund', 1),
#  ('male', 'Rottweiler-St. Bernard Mix', 1),
#  ('male', 'Border Collie-American Foxhound Mix', 1),
#  ('male', 'Golden Retriever-Brittany Mix', 1),
#  ('male', 'Papillon-Cavalier King Charles Spaniel Mix', 1),
#  ('male', 'Norfolk Terrier-Norwich Terrier Mix', 1),
#  ('male', 'American Eskimo Dog-Border Collie Mix', 1),
#  ('male', 'Maltese-Lhasa Apso Mix', 1),
#  ('male', 'Boxer-St. Bernard Mix', 1),
#  ('male', 'Dachshund-Maltese Mix', 1),
#  ('male', 'Irish Wolfhound-Mastiff Mix', 1),
#  ('male', 'Bichon Frise-Jack Russell Terrier Mix', 1),
#  ('male', 'Afghan Hound-Airedale Terrier Mix', 1),
#  ('male', 'Dachshund-Flat-Coated Retriever Mix', 1),
#  ('male', 'German Shepherd Dog-Bearded Collie Mix', 1),
#  ('male', 'St. Bernard-Labrador Retriever Mix', 1),
#  ('male', 'German Shorthaired Pointer-American Pit Bull Terrier Mix', 1),
#  ('male', 'Siberian Husky-Alaskan Malamute Mix', 1),
#  ('male', 'Bouvier des Flandres-Standard Poodle Mix', 1),
#  ('male', 'Dachshund- Mix', 1),
#  ('male', 'Bulldog-Great Dane Mix', 1),
#  ('male', 'Plott-American Pit Bull Terrier Mix', 1),
#  ('male', 'Beagle-Dachshund Mix', 1),
#  ('male', 'Maltese-Miniature Schnauzer Mix', 1),
#  ('male', 'Labrador Retriever-Afghan Hound Mix', 1),
#  ('male', 'Bloodhound-Irish Setter Mix', 1),
#  ('male', 'Yorkshire Terrier-Pomeranian Mix', 1),
#  ('male', 'Chihuahua-American Pit Bull Terrier Mix', 1),
#  ('male', 'German Shepherd Dog-Nova Scotia Duck Tolling Retriever Mix', 1),
#  ('male', 'Lhasa Apso-Tibetan Spaniel Mix', 1),
#  ('male', 'Golden Retriever-Cardigan Welsh Corgi Mix', 1),
#  ('male', 'American Pit Bull Terrier-Beagle Mix', 1),
#  ('male', 'Airedale Terrier-Catahoula Leopard Dog Mix', 1),
#  ('male', 'American Eskimo Dog-Cocker Spaniel Mix', 1),
#  ('male', 'Akita-Siberian Husky Mix', 1),
#  ('male', 'American Pit Bull Terrier-Australian Cattle Dog Mix', 1),
#  ('male', 'Afghan Hound-Border Collie Mix', 1),
#  ('male', 'Siberian Husky-Beagle Mix', 1),
#  ('male', 'Peruvian Inca Orchid', 1),
#  ('male', 'Cairn Terrier-German Shepherd Dog Mix', 1),
#  ('male', 'Canaan Dog', 1),
#  ('male', '-Great Pyrenees Mix', 1),
#  ('male', 'Siberian Husky-American English Coonhound Mix', 1),
#  ('male', 'Pug-Smooth Fox Terrier Mix', 1),
#  ('male', 'Miniature Schnauzer- Mix', 1),
#  ('male', 'Vizsla-Rhodesian Ridgeback Mix', 1),
#  ('male', 'Collie-Anatolian Shepherd Dog Mix', 1),
#  ('male', 'Australian Cattle Dog-American Pit Bull Terrier Mix', 1),
#  ('male', '-Bichon Frise Mix', 1),
#  ('male', 'Bullmastiff-American Pit Bull Terrier Mix', 1),
#  ('male', 'Havanese-Lhasa Apso Mix', 1),
#  ('male', 'German Shepherd Dog-American Staffordshire Terrier Mix', 1),
#  ('male', 'St. Bernard-Border Collie Mix', 1),
#  ('male', 'Vizsla-Dachshund Mix', 1),
#  ('male', 'Pomeranian-Shih Tzu Mix', 1),
#  ('male', 'Labrador Retriever-Airedale Terrier Mix', 1),
#  ('male', 'Great Pyrenees-Chow Chow Mix', 1),
#  ('male', 'Australian Cattle Dog-Staffordshire Bull Terrier Mix', 1),
#  ('male', 'Labrador Retriever-Collie Mix', 1),
#  ('male', 'Golden Retriever-Portuguese Podengo Mix', 1),
#  ('male', 'German Shepherd Dog-Dachshund Mix', 1),
#  ('male', 'German Shepherd Dog-Central Asian Shepherd Dog Mix', 1),
#  ('male', 'Staffordshire Bull Terrier-Bull Terrier Mix', 1),
#  ('male', 'Boxer-Dalmatian Mix', 1),
#  ('male', 'Basset Hound-Pointer Mix', 1),
#  ('male', 'Australian Kelpie-Basenji Mix', 1),
#  ('male', 'Bulldog-Rhodesian Ridgeback Mix', 1),
#  ('male', 'Maltese-Bichon Frise Mix', 1),
#  ('male', 'Tibetan Terrier-Border Collie Mix', 1),
#  ('male', 'Rottweiler-Australian Cattle Dog Mix', 1),
#  ('male', 'Bulldog-Pug Mix', 1),
#  ('male', 'Maltese-Pekingese Mix', 1),
#  ('male', 'Havanese- Mix', 1),
#  ('male', 'Belgian Sheepdog-Border Collie Mix', 1),
#  ('male', 'Pomeranian-Anatolian Shepherd Dog Mix', 1),
#  ('male', 'Staffordshire Bull Terrier-Boston Terrier Mix', 1),
#  ('male', 'Rat Terrier-Russell Terrier Mix', 1),
#  ('male', 'Border Collie-Cavalier King Charles Spaniel Mix', 1),
#  ('male', 'Poodle-Standard Poodle Mix', 1),
#  ('male', 'Cairn Terrier-Shih Tzu Mix', 1),
#  ('male', 'German Shepherd Dog-Collie Mix', 1),
#  ('male', 'Bouvier des Flandres-Airedale Terrier Mix', 1),
#  ('male', 'Doberman Pinscher-Catahoula Leopard Dog Mix', 1),
#  ('male', 'Border Collie-Belgian Tervuren Mix', 1),
#  ('male', 'Border Collie-Jack Russell Terrier Mix', 1),
#  ('male', 'Boxer- Mix', 1),
#  ('male', 'Jack Russell Terrier-Miniature Schnauzer Mix', 1),
#  ('male', 'Boxer-Great Dane Mix', 1),
#  ('male', 'Basenji-English Springer Spaniel Mix', 1),
#  ('male', 'Australian Cattle Dog-Australian Kelpie Mix', 1),
#  ('male', 'Dachshund-Pomeranian Mix', 1),
#  ('male', 'Irish Wolfhound-Great Dane Mix', 1),
#  ('male', 'Chihuahua-Xoloitzcuintli Mix', 1),
#  ('male', 'Rat Terrier-Papillon Mix', 1),
#  ('male', 'Rottweiler-Chow Chow Mix', 1),
#  ('male', 'American Pit Bull Terrier-Border Collie Mix', 1),
#  ('male', 'Tosa- Mix', 1),
#  ('male', 'American Pit Bull Terrier-Brittany Mix', 1),
#  ('male', 'Alaskan Malamute-Bernese Mountain Dog Mix', 1),
#  ('male', 'Pomeranian-Poodle Mix', 1),
#  ('male', 'Maltese-Standard Poodle Mix', 1),
#  ('male', 'Redbone Coonhound-Rhodesian Ridgeback Mix', 1),
#  ('male', 'Russell Terrier-Japanese Chin Mix', 1),
#  ('male', 'Italian Greyhound-Pug Mix', 1),
#  ('male', 'Cocker Spaniel-English Springer Spaniel Mix', 1),
#  ('male', 'Golden Retriever-Bullmastiff Mix', 1),
#  ('male', '-American Eskimo Dog Mix', 1),
#  ('male', 'Chihuahua-Norwich Terrier Mix', 1),
#  ('male', 'Boxer-Border Collie Mix', 1),
#  ('male', 'Chihuahua-Smooth Fox Terrier Mix', 1),
#  ('male', 'Spanish Water Dog-Bichon Frise Mix', 1),
#  ('male', 'American Staffordshire Terrier-German Shepherd Dog Mix', 1),
#  ('male', 'English Cocker Spaniel-Cocker Spaniel Mix', 1),
#  ('male', 'Beagle-Boston Terrier Mix', 1),
#  ('male', 'Boykin Spaniel-Irish Setter Mix', 1),
#  ('male', 'Shih Tzu-Pomeranian Mix', 1),
#  ('male', 'Golden Retriever-Redbone Coonhound Mix', 1),
#  ('male', 'Shih Tzu- Mix', 1),
#  ('male', 'Boston Terrier-Rat Terrier Mix', 1),
#  ('male', 'Lhasa Apso- Mix', 1),
#  ('male', 'Cocker Spaniel-Golden Retriever Mix', 1),
#  ('male', 'Poodle-Newfoundland Mix', 1),
#  ('male', 'Boxer-Bull Terrier Mix', 1),
#  ('male', 'Rhodesian Ridgeback-Doberman Pinscher Mix', 1),
#  ('male', 'Lancashire Heeler-Australian Cattle Dog Mix', 1),
#  ('male', 'Black and Tan Coonhound-Labrador Retriever Mix', 1),
#  ('male', 'Shih Tzu-Lhasa Apso Mix', 1),
#  ('male', 'Dachshund-Black Russian Terrier Mix', 1),
#  ('male', 'American Foxhound-Pointer Mix', 1),
#  ...]

# %% [markdown]
# ## the top 5 heaviest breed, the number should be at least 15

# %%
# %%sql
# select  breed, count(dog_guid) as number,avg(weight) as avg_weight
# from dogs
# group by breed
# having number >=15
# order by avg_weight desc
# limit 5;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 5 rows affected.
# [('Mastiff', 45, Decimal('138.0000')),
#  ('Irish Wolfhound', 15, Decimal('118.0000')),
#  ('Newfoundland', 60, Decimal('116.6667')),
#  ('Great Dane', 141, Decimal('116.2411')),
#  ('St. Bernard', 40, Decimal('113.2500'))]
