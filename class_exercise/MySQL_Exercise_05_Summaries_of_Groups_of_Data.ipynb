# %% [markdown]
# Copyright Jana Schaich Borg/Attribution-NonCommercial 4.0 International (CC BY-NC 4.0)

# %% [markdown]
# # MySQL Exercise 5: Summaries of Groups of Data
#
# So far you've learned how to select, reformat, manipulate, order, and summarize data from a single table in database.  In this lesson, you are going to learn how to summarize multiple subsets of your data in the same query.  The method for doing this is to include a "GROUP BY" clause in your SQL query.
#
#
#
# ## The GROUP BY clause
#
# The GROUP BY clause comes after the WHERE clause, but before ORDER BY or LIMIT:
#
# <img src="https://duke.box.com/shared/static/lc0yjfz1339q3mc04ne13m2q5tkzy3x7.jpg" width=400 alt="SELECT FROM WHERE ORDER BY" />
#
# The GROUP BY clause is easy to incorporate into your queries.  In fact, it might be a little too easy to incorporate into MySQL queries, because it can be used incorrectly in MySQL queries even when no error message is displayed.  As a consequence, I suggest you adopt a healthy dose of caution every time you use the GROUP BY clause.  By the end of this lesson, you will understand why.  When used correctly, though, GROUP BY is one of the most useful and efficient parts of an SQL query, and once you are comfortable using it, you will use it very frequently.
#
# **To get started, load the SQL library and the Dognition database, and set the dognition database as the default:**

# %%
# %load_ext sql
# %sql mysql://studentuser:studentpw@localhost/dognitiondb
# %sql USE dognitiondb
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
#  * mysql://studentuser:***@localhost/dognitiondb
# 0 rows affected.
# []

# %% [markdown]
# Let's return to a question from MySQL Exercise 4.  How would you query the average rating for each of the 40 tests in the Reviews table? As we discussed, one very inefficient method to do that would be to write 40 separate queries with each one having a different test name in the WHERE conditional clause.  Then you could copy or transcribe the results from all 40 queries into one place.  But that wouldn't be very pleasant.  Here's how you could do the same thing using one query that has a GROUP BY clause:
#
# ```mySQL
# SELECT test_name, AVG(rating) AS AVG_Rating
# FROM reviews
# GROUP BY test_name
# ```
#
# This query will output the average rating for each test.  More technically, this query will instruct MySQL to average all the rows that have the same value in the test_name column.
#
# Notice that I included test_name in the SELECT statement.  As a strong rule of thumb, if you are grouping by a column, you should also include that column in the SELECT statement.  If you don't do this, you won't know to which group each row of your output corresponds.
#
# **To see what I mean, try the query above without test_name included in the SELECT statement:**

# %%
# %%sql
# SELECT test_name, AVG(rating) AS AVG_Rating
# FROM reviews
# GROUP BY test_name;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 40 rows affected.
# [('1 vs 1 Game', Decimal('3.9206')),
#  ('3 vs 1 Game', Decimal('4.2857')),
#  ('5 vs 1 Game', Decimal('3.9272')),
#  ('Arm Pointing', Decimal('4.2153')),
#  ('Cover Your Eyes', Decimal('2.6741')),
#  ('Delayed Cup Game', Decimal('3.3514')),
#  ('Different Perspective', Decimal('2.7647')),
#  ('Expression Game', Decimal('4.0000')),
#  ('Eye Contact Game', Decimal('2.9372')),
#  ('Eye Contact Warm-up', Decimal('0.9632')),
#  ('Foot Pointing', Decimal('4.0093')),
#  ('Impossible Task Game', Decimal('3.0965')),
#  ('Impossible Task Warm-up', Decimal('0.2174')),
#  ('Inferential Reasoning Game', Decimal('4.5223')),
#  ('Inferential Reasoning Warm-up', Decimal('4.3066')),
#  ('Memory versus Pointing', Decimal('3.5584')),
#  ('Memory versus Smell', Decimal('4.2623')),
#  ('Navigation Game', Decimal('2.9841')),
#  ('Navigation Learning', Decimal('2.0303')),
#  ('Navigation Warm-up', Decimal('1.9805')),
#  ('Numerosity Warm-Up', Decimal('2.6173')),
#  ('One Cup Warm-up', Decimal('1.3693')),
#  ('Physical Reasoning Game', Decimal('3.8492')),
#  ('Physical Reasoning Warm-up', Decimal('1.6625')),
#  ('Self Control Game', Decimal('3.8519')),
#  ('Shaker Game', Decimal('4.6667')),
#  ('Shaker Warm-Up', Decimal('2.1818')),
#  ('Shared Perspective', Decimal('3.2778')),
#  ('Slide', Decimal('4.5111')),
#  ('Smell Game', Decimal('4.2857')),
#  ('Stair Game', Decimal('4.2857')),
#  ('Switch', Decimal('5.5676')),
#  ('Treat Warm-up', Decimal('0.7909')),
#  ('Turn Your Back', Decimal('3.1293')),
#  ('Two Cup Warm-up', Decimal('1.6737')),
#  ('Warm-Up', Decimal('1.2020')),
#  ('Watching', Decimal('2.4594')),
#  ('Watching - Part 2', Decimal('2.6570')),
#  ('Yawn Game', Decimal('2.8477')),
#  ('Yawn Warm-up', Decimal('2.0035'))]

# %% [markdown]
# You can form groups using derived values as well as original columns.  To illustrate this, let's address another question: how many tests were completed during each month of the year?
#
# To answer this question, we need to take advantage of another datetime function described in the website below:
#
# http://www.w3resource.com/mysql/date-and-time-functions/date-and-time-functions.php
#
# MONTH() will return a number representing the month of a date entry. To get the total number of tests completed each month, you could put the MONTH function into the GROUP BY clause, in this case through an alias:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY Month;
# ```
#
# You can also group by multiple columns or derived fields.  If we wanted to determine the total number of each type of test completed each month, you could include both "test_name" and the derived "Month" field in the GROUP BY clause, separated by a comma.
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY test_name, Month;
# ```
#
# MySQL allows you to use aliases in a GROUP BY clause, but some database systems do not.  If you are using a database system that does NOT accept aliases in GROUP BY clauses, you can still group by derived fields, but you have to duplicate the calculation for the derived field in the GROUP BY clause in addition to including the derived field in the SELECT clause:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY test_name, MONTH(created_at);
# ```
#
# Try the query once with test_name first in the GROUP BY list, and once with Month first in the GROUP BY list below.  Inspect the outputs:

# %%
# %%sql
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY Month;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 12 rows affected.
# [('Delayed Cup Game', 1, 11068),
#  ('Yawn Warm-up', 2, 9122),
#  ('Yawn Warm-up', 3, 9572),
#  ('Physical Reasoning Game', 4, 7130),
#  ('Delayed Cup Game', 5, 21013),
#  ('Foot Pointing', 6, 23381),
#  ('Eye Contact Game', 7, 15977),
#  ('Memory versus Smell', 8, 13382),
#  ('Yawn Warm-up', 9, 19853),
#  ('Yawn Warm-up', 10, 39237),
#  ('Inferential Reasoning Warm-up', 11, 12652),
#  ('Inferential Reasoning Warm-up', 12, 10859)]

# %%
# %%sql
# SELECT test_name, WEEKDAY(created_at) AS Weekday, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY Weekday;
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 7 rows affected.
# [('One Cup Warm-up', 0, 30195),
#  ('Yawn Warm-up', 1, 27989),
#  ('Arm Pointing', 2, 26473),
#  ('Yawn Warm-up', 3, 24420),
#  ('Treat Warm-up', 4, 23080),
#  ('Inferential Reasoning Game', 5, 27899),
#  ('Foot Pointing', 6, 33190)]

# %% [markdown]
# Notice that in the first case, the first block of rows share the same test_name, but are broken up into separate months (for those of you who took the "Data Visualization and Communication with Tableau" course of this specialization, this is similar to what would happen if you put test_name first and created_at second on the rows or columns shelf in Tableau).
#
# In the second case, the first block of rows share the same month, but are broken up into separate tests  (this is similar to what would happen if you put created_at first and test_name second on the rows or columns shelf in Tableau).  If you were to visualize these outputs, they would look like the charts below.
#
# <img src="https://duke.box.com/shared/static/y6l3ldxg289brid5mmn886qweglt65qv.jpg" width=800 alt="ORDER" />
#
# Different database servers might default to ordering the outputs in a certain way, but you shouldn't rely on that being the case.  To ensure the output is ordered in a way you intend, add an ORDER BY clause to your grouped query using the syntax you already know and have practiced:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY test_name, Month
# ORDER BY test_name ASC, Month ASC;
# ```
#
# **Question 1: Output a table that calculates the number of distinct female and male dogs in each breed group of the Dogs table, sorted by the total number of dogs in descending order (the sex/breed_group pair with the greatest number of dogs should have 8466 unique Dog_Guids):**

# %%
# Out:
#  * mysql://studentuser:***@localhost/dognitiondb
# 2719 rows affected.
# [(1, '-American Eskimo Dog Mix', 'male'),
#  (2, '-American Pit Bull Terrier Mix', 'female'),
#  (3, '-American Pit Bull Terrier Mix', 'male'),
#  (2, '-Anatolian Shepherd Dog Mix', 'male'),
#  (1, '-Australian Cattle Dog Mix', 'female'),
#  (4, '-Australian Cattle Dog Mix', 'male'),
#  (3, '-Australian Shepherd Mix', 'female'),
#  (1, '-Beagle Mix', 'male'),
#  (1, '-Bichon Frise Mix', 'male'),
#  (1, '-Bluetick Coonhound Mix', 'male'),
#  (2, '-Border Collie Mix', 'female'),
#  (3, '-Border Collie Mix', 'male'),
#  (1, '-Boxer Mix', 'female'),
#  (2, '-Boxer Mix', 'male'),
#  (1, '-Cairn Terrier Mix', 'female'),
#  (2, '-Cavalier King Charles Spaniel Mix', 'female'),
#  (1, '-Chesapeake Bay Retriever Mix', 'male'),
#  (2, '-Chihuahua Mix', 'female'),
#  (1, '-Cocker Spaniel Mix', 'female'),
#  (1, '-Collie Mix', 'female'),
#  (5, '-German Shepherd Dog Mix', 'female'),
#  (3, '-German Shepherd Dog Mix', 'male'),
#  (2, '-Golden Retriever Mix', 'female'),
#  (1, '-Great Dane Mix', 'male'),
#  (1, '-Great Pyrenees Mix', 'male'),
#  (5, '-Labrador Retriever Mix', 'female'),
#  (6, '-Labrador Retriever Mix', 'male'),
#  (2, '-Maltese Mix', 'female'),
#  (1, '-Manchester Terrier Mix', 'male'),
#  (1, '-Otterhound Mix', 'male'),
#  (1, '-Polish Lowland Sheepdog Mix', 'female'),
#  (3, '-Pomeranian Mix', 'female'),
#  (1, '-Pomeranian Mix', 'male'),
#  (3, '-Poodle Mix', 'female'),
#  (1, '-Poodle Mix', 'male'),
#  (1, '-Pug Mix', 'male'),
#  (1, '-Rhodesian Ridgeback Mix', 'male'),
#  (1, '-Rottweiler Mix', 'male'),
#  (2, '-Russell Terrier Mix', 'female'),
#  (2, '-Shih Tzu Mix', 'female'),
#  (1, '-Shih Tzu Mix', 'male'),
#  (1, '-Siberian Husky Mix', 'female'),
#  (1, '-Staffordshire Bull Terrier Mix', 'female'),
#  (1, '-Toy Fox Terrier Mix', 'male'),
#  (1, '-Whippet Mix', 'male'),
#  (1, '-Yorkshire Terrier Mix', 'female'),
#  (4, 'Affenpinscher', 'female'),
#  (9, 'Affenpinscher', 'male'),
#  (1, 'Affenpinscher-Afghan Hound Mix', 'male'),
#  (1, 'Affenpinscher-Airedale Terrier Mix', 'male'),
#  (1, 'Affenpinscher-Alaskan Malamute Mix', 'male'),
#  (1, 'Affenpinscher-American English Coonhound Mix', 'female'),
#  (1, 'Affenpinscher-Brussels Griffon Mix', 'female'),
#  (1, 'Affenpinscher-Poodle Mix', 'female'),
#  (1, 'Affenpinscher-Poodle Mix', 'male'),
#  (1, 'Affenpinscher-Rat Terrier Mix', 'female'),
#  (1, 'Affenpinscher-Spanish Water Dog Mix', 'male'),
#  (8, 'Afghan Hound', 'female'),
#  (8, 'Afghan Hound', 'male'),
#  (1, 'Afghan Hound-Affenpinscher Mix', 'male'),
#  (1, 'Afghan Hound-Airedale Terrier Mix', 'female'),
#  (1, 'Afghan Hound-Airedale Terrier Mix', 'male'),
#  (1, 'Afghan Hound-Akita Mix', 'female'),
#  (1, 'Afghan Hound-Bloodhound Mix', 'male'),
#  (1, 'Afghan Hound-Border Collie Mix', 'male'),
#  (1, 'Afghan Hound-Golden Retriever Mix', 'female'),
#  (28, 'Airedale Terrier', 'female'),
#  (27, 'Airedale Terrier', 'male'),
#  (1, 'Airedale Terrier-Afghan Hound Mix', 'female'),
#  (1, 'Airedale Terrier-Border Collie Mix', 'male'),
#  (1, 'Airedale Terrier-Catahoula Leopard Dog Mix', 'male'),
#  (1, 'Airedale Terrier-German Shepherd Dog Mix', 'female'),
#  (1, 'Airedale Terrier-German Shorthaired Pointer Mix', 'female'),
#  (2, 'Airedale Terrier-Golden Retriever Mix', 'female'),
#  (1, 'Airedale Terrier-Golden Retriever Mix', 'male'),
#  (3, 'Airedale Terrier-Labrador Retriever Mix', 'male'),
#  (1, 'Airedale Terrier-Portuguese Podengo Pequeno Mix', 'female'),
#  (24, 'Akita', 'female'),
#  (28, 'Akita', 'male'),
#  (2, 'Akita- Mix', 'female'),
#  (1, 'Akita-Affenpinscher Mix', 'female'),
#  (1, 'Akita-Affenpinscher Mix', 'male'),
#  (2, 'Akita-Afghan Hound Mix', 'male'),
#  (1, 'Akita-Airedale Terrier Mix', 'female'),
#  (1, 'Akita-American Pit Bull Terrier Mix', 'male'),
#  (1, 'Akita-Bearded Collie Mix', 'female'),
#  (1, 'Akita-Belgian Tervuren Mix', 'male'),
#  (1, 'Akita-Bernese Mountain Dog Mix', 'female'),
#  (1, 'Akita-German Shepherd Dog Mix', 'female'),
#  (3, 'Akita-German Shepherd Dog Mix', 'male'),
#  (1, 'Akita-Labrador Retriever Mix', 'male'),
#  (1, 'Akita-Siberian Husky Mix', 'female'),
#  (1, 'Akita-Siberian Husky Mix', 'male'),
#  (20, 'Alaskan Malamute', 'female'),
#  (30, 'Alaskan Malamute', 'male'),
#  (1, 'Alaskan Malamute- Mix', 'female'),
#  (1, 'Alaskan Malamute- Mix', 'male'),
#  (1, 'Alaskan Malamute-American Pit Bull Terrier Mix', 'male'),
#  (1, 'Alaskan Malamute-Australian Kelpie Mix', 'female'),
#  (1, 'Alaskan Malamute-Beagle Mix', 'female'),
#  (1, 'Alaskan Malamute-Bernese Mountain Dog Mix', 'male'),
#  (1, 'Alaskan Malamute-Border Collie Mix', 'female'),
#  (1, 'Alaskan Malamute-Collie Mix', 'male'),
#  (1, 'Alaskan Malamute-English Cocker Spaniel Mix', 'female'),
#  (1, 'Alaskan Malamute-German Shepherd Dog Mix', 'female'),
#  (7, 'Alaskan Malamute-German Shepherd Dog Mix', 'male'),
#  (2, 'Alaskan Malamute-Labrador Retriever Mix', 'female'),
#  (1, 'Alaskan Malamute-Labrador Retriever Mix', 'male'),
#  (1, 'Alaskan Malamute-Pomeranian Mix', 'female'),
#  (2, 'Alaskan Malamute-Siberian Husky Mix', 'female'),
#  (8, 'Alaskan Malamute-Siberian Husky Mix', 'male'),
#  (1, 'American English Coonhound', 'female'),
#  (1, 'American English Coonhound', 'male'),
#  (1, 'American English Coonhound-Golden Retriever Mix', 'male'),
#  (1, 'American English Coonhound-Redbone Coonhound Mix', 'male'),
#  (1, 'American English Coonhound-Rhodesian Ridgeback Mix', 'female'),
#  (1, 'American English Coonhound-Weimaraner Mix', 'female'),
#  (32, 'American Eskimo Dog', 'female'),
#  (31, 'American Eskimo Dog', 'male'),
#  (1, 'American Eskimo Dog- Mix', 'male'),
#  (1, 'American Eskimo Dog-Australian Shepherd Mix', 'female'),
#  (1, 'American Eskimo Dog-Australian Shepherd Mix', 'male'),
#  (1, 'American Eskimo Dog-Border Collie Mix', 'male'),
#  (1, 'American Eskimo Dog-Chihuahua Mix', 'male'),
#  (1, 'American Eskimo Dog-Cocker Spaniel Mix', 'male'),
#  (1, 'American Eskimo Dog-Collie Mix', 'female'),
#  (1, 'American Eskimo Dog-English Springer Spaniel Mix', 'male'),
#  (1, 'American Eskimo Dog-Golden Retriever Mix', 'female'),
#  (1, 'American Eskimo Dog-Golden Retriever Mix', 'male'),
#  (1, 'American Eskimo Dog-Papillon Mix', 'female'),
#  (1, 'American Eskimo Dog-Pembroke Welsh Corgi Mix', 'male'),
#  (2, 'American Eskimo Dog-Pomeranian Mix', 'female'),
#  (3, 'American Eskimo Dog-Pomeranian Mix', 'male'),
#  (1, 'American Eskimo Dog-Poodle Mix', 'female'),
#  (1, 'American Eskimo Dog-Russell Terrier Mix', 'female'),
#  (1, 'American Eskimo Dog-Shiba Inu Mix', 'male'),
#  (1, 'American Eskimo Dog-Siberian Husky Mix', 'female'),
#  (1, 'American Eskimo Dog-Staffordshire Bull Terrier Mix', 'male'),
#  (5, 'American Foxhound', 'female'),
#  (1, 'American Foxhound', 'male'),
#  (1, 'American Foxhound- Mix', 'male'),
#  (1, 'American Foxhound-Anatolian Shepherd Dog Mix', 'male'),
#  (1, 'American Foxhound-Beagle Mix', 'female'),
#  (1, 'American Foxhound-German Shepherd Dog Mix', 'female'),
#  (2, 'American Foxhound-Labrador Retriever Mix', 'male'),
#  (1, 'American Foxhound-Pointer Mix', 'male'),
#  (3, 'American Hairless Terrier', 'female'),
#  (1, 'American Hairless Terrier', 'male'),
#  (1, 'American Hairless Terrier-Shetland Sheepdog Mix', 'female'),
#  (1, 'American Leopard Hound', 'female'),
#  (1, 'American Leopard Hound', 'male'),
#  (172, 'American Pit Bull Terrier', 'female'),
#  (158, 'American Pit Bull Terrier', 'male'),
#  (4, 'American Pit Bull Terrier- Mix', 'female'),
#  (2, 'American Pit Bull Terrier- Mix', 'male'),
#  (1, 'American Pit Bull Terrier-American English Coonhound Mix', 'male'),
#  (1, 'American Pit Bull Terrier-American Leopard Hound Mix', 'female'),
#  (8, 'American Pit Bull Terrier-American Staffordshire Terrier Mix', 'female'),
#  (10, 'American Pit Bull Terrier-American Staffordshire Terrier Mix', 'male'),
#  (2, 'American Pit Bull Terrier-Australian Cattle Dog Mix', 'female'),
#  (1, 'American Pit Bull Terrier-Australian Cattle Dog Mix', 'male'),
#  (3, 'American Pit Bull Terrier-Australian Shepherd Mix', 'female'),
#  (1, 'American Pit Bull Terrier-Australian Shepherd Mix', 'male'),
#  (2, 'American Pit Bull Terrier-Beagle Mix', 'female'),
#  (1, 'American Pit Bull Terrier-Beagle Mix', 'male'),
#  (1, 'American Pit Bull Terrier-Border Collie Mix', 'male'),
#  (2, 'American Pit Bull Terrier-Boston Terrier Mix', 'female'),
#  (11, 'American Pit Bull Terrier-Boxer Mix', 'female'),
#  (16, 'American Pit Bull Terrier-Boxer Mix', 'male'),
#  (1, 'American Pit Bull Terrier-Brittany Mix', 'male'),
#  (2, 'American Pit Bull Terrier-Bull Terrier Mix', 'female'),
#  (1, 'American Pit Bull Terrier-Bull Terrier Mix', 'male'),
#  (3, 'American Pit Bull Terrier-Bulldog Mix', 'female'),
#  (6, 'American Pit Bull Terrier-Bulldog Mix', 'male'),
#  (3, 'American Pit Bull Terrier-Bullmastiff Mix', 'male'),
#  (1, 'American Pit Bull Terrier-Cane Corso Mix', 'male'),
#  (1, 'American Pit Bull Terrier-Cardigan Welsh Corgi Mix', 'female'),
#  (1, 'American Pit Bull Terrier-Chinese Shar-Pei Mix', 'female'),
#  (1, 'American Pit Bull Terrier-Doberman Pinscher Mix', 'female'),
#  (1, 'American Pit Bull Terrier-Dogue de Bordeaux Mix', 'female'),
#  (1, 'American Pit Bull Terrier-German Shepherd Dog Mix', 'female'),
#  (1, 'American Pit Bull Terrier-German Shepherd Dog Mix', 'male'),
#  (4, 'American Pit Bull Terrier-Great Dane Mix', 'male'),
#  (1, 'American Pit Bull Terrier-Great Pyrenees Mix', 'female'),
#  (1, 'American Pit Bull Terrier-Greyhound Mix', 'female'),
#  (1, 'American Pit Bull Terrier-Greyhound Mix', 'male'),
#  (16, 'American Pit Bull Terrier-Labrador Retriever Mix', 'female'),
#  (15, 'American Pit Bull Terrier-Labrador Retriever Mix', 'male'),
#  (1, 'American Pit Bull Terrier-Mastiff Mix', 'female'),
#  (2, 'American Pit Bull Terrier-Mastiff Mix', 'male'),
#  (1, 'American Pit Bull Terrier-Parson Russell Terrier Mix', 'male'),
#  (2, 'American Pit Bull Terrier-Plott Mix', 'female'),
#  (2, 'American Pit Bull Terrier-Plott Mix', 'male'),
#  (2, 'American Pit Bull Terrier-Pointer Mix', 'female'),
#  (3, 'American Pit Bull Terrier-Pointer Mix', 'male'),
#  (1, 'American Pit Bull Terrier-Rhodesian Ridgeback Mix', 'female'),
#  (3, 'American Pit Bull Terrier-Rhodesian Ridgeback Mix', 'male'),
#  (1, 'American Pit Bull Terrier-Rottweiler Mix', 'female'),
#  (3, 'American Pit Bull Terrier-Siberian Husky Mix', 'female'),
#  (1, 'American Pit Bull Terrier-Staffordshire Bull Terrier Mix', 'female'),
#  (1, 'American Pit Bull Terrier-Staffordshire Bull Terrier Mix', 'male'),
#  (1, 'American Pit Bull Terrier-Treeing Tennessee Brindle Mix', 'male'),
#  (1, 'American Pit Bull Terrier-Vizsla Mix', 'female'),
#  (1, 'American Pit Bull Terrier-Vizsla Mix', 'male'),
#  (1, 'American Pit Bull Terrier-Whippet Mix', 'female'),
#  (1, 'American Pit Bull Terrier-Whippet Mix', 'male'),
#  (52, 'American Staffordshire Terrier', 'female'),
#  (58, 'American Staffordshire Terrier', 'male'),
#  (1, 'American Staffordshire Terrier- Mix', 'female'),
#  (4, 'American Staffordshire Terrier- Mix', 'male'),
#  (1, 'American Staffordshire Terrier-Airedale Terrier Mix', 'female'),
#  (8, 'American Staffordshire Terrier-American Pit Bull Terrier Mix', 'female'),
#  (10, 'American Staffordshire Terrier-American Pit Bull Terrier Mix', 'male'),
#  (1, 'American Staffordshire Terrier-Australian Shepherd Mix', 'female'),
#  (1, 'American Staffordshire Terrier-Beagle Mix', 'female'),
#  (2, 'American Staffordshire Terrier-Border Collie Mix', 'female'),
#  (4, 'American Staffordshire Terrier-Border Collie Mix', 'male'),
#  (1, 'American Staffordshire Terrier-Boston Terrier Mix', 'male'),
#  (7, 'American Staffordshire Terrier-Boxer Mix', 'female'),
#  (3, 'American Staffordshire Terrier-Boxer Mix', 'male'),
#  (2, 'American Staffordshire Terrier-Bull Terrier Mix', 'male'),
#  (5, 'American Staffordshire Terrier-Bulldog Mix', 'female'),
#  (3, 'American Staffordshire Terrier-Bullmastiff Mix', 'male'),
#  (1, 'American Staffordshire Terrier-Catahoula Leopard Dog Mix', 'female'),
#  (2, 'American Staffordshire Terrier-Chinese Shar-Pei Mix', 'male'),
#  (1, 'American Staffordshire Terrier-Chow Chow Mix', 'female'),
#  (1, 'American Staffordshire Terrier-Dalmatian Mix', 'female'),
#  (1, 'American Staffordshire Terrier-Doberman Pinscher Mix', 'female'),
#  (2, 'American Staffordshire Terrier-Dogo Argentino Mix', 'male'),
#  (1, 'American Staffordshire Terrier-Dogue de Bordeaux Mix', 'female'),
#  (1, 'American Staffordshire Terrier-Dogue de Bordeaux Mix', 'male'),
#  (2, 'American Staffordshire Terrier-German Shepherd Dog Mix', 'female'),
#  (1, 'American Staffordshire Terrier-German Shepherd Dog Mix', 'male'),
#  (1, 'American Staffordshire Terrier-German Wirehaired Pointer Mix', 'female'),
#  (2, 'American Staffordshire Terrier-Golden Retriever Mix', 'female'),
#  (1, 'American Staffordshire Terrier-Gordon Setter Mix', 'female'),
#  (1, 'American Staffordshire Terrier-Great Dane Mix', 'male'),
#  (1, 'American Staffordshire Terrier-Great Pyrenees Mix', 'female'),
#  (1, 'American Staffordshire Terrier-Greyhound Mix', 'female'),
#  (4, 'American Staffordshire Terrier-Labrador Retriever Mix', 'female'),
#  (6, 'American Staffordshire Terrier-Labrador Retriever Mix', 'male'),
#  (1, 'American Staffordshire Terrier-Lancashire Heeler Mix', 'female'),
#  (1, 'American Staffordshire Terrier-Mastiff Mix', 'female'),
#  (1, 'American Staffordshire Terrier-Mastiff Mix', 'male'),
#  (1, 'American Staffordshire Terrier-Miniature Bull Terrier Mix', 'female'),
#  (1, 'American Staffordshire Terrier-Neapolitan Mastiff Mix', 'female'),
#  (1, 'American Staffordshire Terrier-Portuguese Podengo Mix', 'male'),
#  (1, 'American Staffordshire Terrier-Redbone Coonhound Mix', 'female'),
#  (1, 'American Staffordshire Terrier-Rhodesian Ridgeback Mix', 'female'),
#  (1, 'American Staffordshire Terrier-Rhodesian Ridgeback Mix', 'male'),
#  (2, 'American Staffordshire Terrier-Staffordshire Bull Terrier Mix', 'male'),
#  (1, 'American Staffordshire Terrier-Treeing Walker Coonhound Mix', 'female'),
#  (1, 'American Staffordshire Terrier-Weimaraner Mix', 'female'),
#  (1, 'American Staffordshire Terrier-Whippet Mix', 'female'),
#  (4, 'American Water Spaniel', 'female'),
#  (4, 'American Water Spaniel', 'male'),
#  (1, 'American Water Spaniel-Dachshund Mix', 'female'),
#  (6, 'Anatolian Shepherd Dog', 'female'),
#  (9, 'Anatolian Shepherd Dog', 'male'),
#  (1, 'Anatolian Shepherd Dog-Border Collie Mix', 'female'),
#  (2, 'Anatolian Shepherd Dog-Great Pyrenees Mix', 'male'),
#  (1, 'Anatolian Shepherd Dog-Labrador Retriever Mix', 'male'),
#  (1, 'Anatolian Shepherd Dog-Mastiff Mix', 'female'),
#  (2, 'Appenzeller Sennenhunde', 'female'),
#  (2, 'Appenzeller Sennenhunde', 'male'),
#  (1, 'Appenzeller Sennenhunde- Mix', 'female'),
#  (1, 'Appenzeller Sennenhunde-Border Collie Mix', 'male'),
#  (1, 'Appenzeller Sennenhunde-Collie Mix', 'female'),
#  (82, 'Australian Cattle Dog', 'female'),
#  (87, 'Australian Cattle Dog', 'male'),
#  (3, 'Australian Cattle Dog- Mix', 'female'),
#  (2, 'Australian Cattle Dog- Mix', 'male'),
#  (3, 'Australian Cattle Dog-American Pit Bull Terrier Mix', 'female'),
#  (1, 'Australian Cattle Dog-American Pit Bull Terrier Mix', 'male'),
#  (1, 'Australian Cattle Dog-American Staffordshire Terrier Mix', 'female'),
#  (1, 'Australian Cattle Dog-Anatolian Shepherd Dog Mix', 'female'),
#  (1, 'Australian Cattle Dog-Australian Kelpie Mix', 'male'),
#  (7, 'Australian Cattle Dog-Australian Shepherd Mix', 'female'),
#  (9, 'Australian Cattle Dog-Australian Shepherd Mix', 'male'),
#  (1, 'Australian Cattle Dog-Basenji Mix', 'female'),
#  (1, 'Australian Cattle Dog-Beagle Mix', 'female'),
#  (3, 'Australian Cattle Dog-Beagle Mix', 'male'),
#  (1, 'Australian Cattle Dog-Bearded Collie Mix', 'female'),
#  (1, 'Australian Cattle Dog-Belgian Sheepdog Mix', 'female'),
#  (1, 'Australian Cattle Dog-Bernese Mountain Dog Mix', 'female'),
#  (2, 'Australian Cattle Dog-Bluetick Coonhound Mix', 'female'),
#  (13, 'Australian Cattle Dog-Border Collie Mix', 'female'),
#  (10, 'Australian Cattle Dog-Border Collie Mix', 'male'),
#  (2, 'Australian Cattle Dog-Boxer Mix', 'female'),
#  (2, 'Australian Cattle Dog-Bull Terrier Mix', 'female'),
#  (1, 'Australian Cattle Dog-Cardigan Welsh Corgi Mix', 'female'),
#  (1, 'Australian Cattle Dog-Catahoula Leopard Dog Mix', 'female'),
#  (1, 'Australian Cattle Dog-Catahoula Leopard Dog Mix', 'male'),
#  (1, 'Australian Cattle Dog-Chow Chow Mix', 'female'),
#  (2, 'Australian Cattle Dog-Cocker Spaniel Mix', 'female'),
#  (1, 'Australian Cattle Dog-Curly-Coated Retriever Mix', 'female'),
#  (1, 'Australian Cattle Dog-Doberman Pinscher Mix', 'male'),
#  (1, 'Australian Cattle Dog-German Longhaired Pointer Mix', 'female'),
#  (7, 'Australian Cattle Dog-German Shepherd Dog Mix', 'female'),
#  (6, 'Australian Cattle Dog-German Shepherd Dog Mix', 'male'),
#  (1, 'Australian Cattle Dog-Greyhound Mix', 'female'),
#  (1, 'Australian Cattle Dog-Greyhound Mix', 'male'),
#  (13, 'Australian Cattle Dog-Labrador Retriever Mix', 'female'),
#  (2, 'Australian Cattle Dog-Labrador Retriever Mix', 'male'),
#  (1, 'Australian Cattle Dog-Rat Terrier Mix', 'female'),
#  (1, 'Australian Cattle Dog-Redbone Coonhound Mix', 'female'),
#  (1, 'Australian Cattle Dog-Rottweiler Mix', 'female'),
#  (1, 'Australian Cattle Dog-Rottweiler Mix', 'male'),
#  (1, 'Australian Cattle Dog-Shetland Sheepdog Mix', 'female'),
#  (2, 'Australian Cattle Dog-Siberian Husky Mix', 'female'),
#  (2, 'Australian Cattle Dog-Siberian Husky Mix', 'male'),
#  (1, 'Australian Cattle Dog-Staffordshire Bull Terrier Mix', 'male'),
#  (1, 'Australian Cattle Dog-Treeing Walker Coonhound Mix', 'female'),
#  (1, 'Australian Cattle Dog-Weimaraner Mix', 'female'),
#  (16, 'Australian Kelpie', 'female'),
#  (6, 'Australian Kelpie', 'male'),
#  (1, 'Australian Kelpie-Australian Cattle Dog Mix', 'female'),
#  (1, 'Australian Kelpie-Basenji Mix', 'male'),
#  (1, 'Australian Kelpie-Border Collie Mix', 'female'),
#  (2, 'Australian Kelpie-Labrador Retriever Mix', 'female'),
#  (1, 'Australian Kelpie-Miniature Schnauzer Mix', 'male'),
#  (1, 'Australian Kelpie-Rottweiler Mix', 'female'),
#  (2, 'Australian Kelpie-Staffordshire Bull Terrier Mix', 'female'),
#  (1, 'Australian Kelpie-Staffordshire Bull Terrier Mix', 'male'),
#  (36, 'Australian Labradoodle', 'female'),
#  (29, 'Australian Labradoodle', 'male'),
#  (2, 'Australian Labradoodle-Poodle Mix', 'female'),
#  (2, 'Australian Labradoodle-Poodle Mix', 'male'),
#  (310, 'Australian Shepherd', 'female'),
#  (314, 'Australian Shepherd', 'male'),
#  (3, 'Australian Shepherd- Mix', 'female'),
#  (4, 'Australian Shepherd- Mix', 'male'),
#  (1, 'Australian Shepherd-Alaskan Malamute Mix', 'female'),
#  (1, 'Australian Shepherd-Alaskan Malamute Mix', 'male'),
#  (1, 'Australian Shepherd-American Pit Bull Terrier Mix', 'female'),
#  (5, 'Australian Shepherd-Australian Cattle Dog Mix', 'female'),
#  (7, 'Australian Shepherd-Australian Cattle Dog Mix', 'male'),
#  (1, 'Australian Shepherd-Basenji Mix', 'male'),
#  (1, 'Australian Shepherd-Beagle Mix', 'female'),
#  (1, 'Australian Shepherd-Beagle Mix', 'male'),
#  (1, 'Australian Shepherd-Bearded Collie Mix', 'female'),
#  (1, 'Australian Shepherd-Bloodhound Mix', 'female'),
#  (22, 'Australian Shepherd-Border Collie Mix', 'female'),
#  (22, 'Australian Shepherd-Border Collie Mix', 'male'),
#  (1, 'Australian Shepherd-Cardigan Welsh Corgi Mix', 'female'),
#  (3, 'Australian Shepherd-Catahoula Leopard Dog Mix', 'female'),
#  (1, 'Australian Shepherd-Catahoula Leopard Dog Mix', 'male'),
#  (1, 'Australian Shepherd-Chow Chow Mix', 'female'),
#  (3, 'Australian Shepherd-Chow Chow Mix', 'male'),
#  (1, 'Australian Shepherd-Cocker Spaniel Mix', 'female'),
#  (1, 'Australian Shepherd-Cocker Spaniel Mix', 'male'),
#  (3, 'Australian Shepherd-Collie Mix', 'female'),
#  (1, 'Australian Shepherd-Collie Mix', 'male'),
#  (1, 'Australian Shepherd-Doberman Pinscher Mix', 'female'),
#  (1, 'Australian Shepherd-Doberman Pinscher Mix', 'male'),
#  (1, 'Australian Shepherd-English Cocker Spaniel Mix', 'female'),
#  (1, 'Australian Shepherd-Flat-Coated Retriever Mix', 'female'),
#  (4, 'Australian Shepherd-German Shepherd Dog Mix', 'female'),
#  (3, 'Australian Shepherd-German Shepherd Dog Mix', 'male'),
#  (3, 'Australian Shepherd-Golden Retriever Mix', 'female'),
#  (5, 'Australian Shepherd-Golden Retriever Mix', 'male'),
#  (3, 'Australian Shepherd-Great Pyrenees Mix', 'female'),
#  (1, 'Australian Shepherd-Great Pyrenees Mix', 'male'),
#  (7, 'Australian Shepherd-Labrador Retriever Mix', 'female'),
#  (11, 'Australian Shepherd-Labrador Retriever Mix', 'male'),
#  (1, 'Australian Shepherd-Pembroke Welsh Corgi Mix', 'female'),
#  (3, 'Australian Shepherd-Pembroke Welsh Corgi Mix', 'male'),
#  (11, 'Australian Shepherd-Poodle Mix', 'female'),
#  (13, 'Australian Shepherd-Poodle Mix', 'male'),
#  (1, 'Australian Shepherd-Pug Mix', 'male'),
#  (1, 'Australian Shepherd-Rhodesian Ridgeback Mix', 'female'),
#  (2, 'Australian Shepherd-Rottweiler Mix', 'female'),
#  (1, 'Australian Shepherd-Rottweiler Mix', 'male'),
#  (1, 'Australian Shepherd-Schipperke Mix', 'male'),
#  (5, 'Australian Shepherd-Shetland Sheepdog Mix', 'female'),
#  (1, 'Australian Shepherd-Shiba Inu Mix', 'male'),
#  (1, 'Australian Shepherd-Shih Tzu Mix', 'female'),
#  (1, 'Australian Shepherd-Siberian Husky Mix', 'female'),
#  (3, 'Australian Shepherd-Siberian Husky Mix', 'male'),
#  (1, 'Australian Shepherd-St. Bernard Mix', 'female'),
#  (1, 'Australian Shepherd-Standard Poodle Mix', 'female'),
#  (2, 'Australian Shepherd-Standard Poodle Mix', 'male'),
#  (1, 'Australian Shepherd-Weimaraner Mix', 'male'),
#  (9, 'Australian Terrier', 'female'),
#  (14, 'Australian Terrier', 'male'),
#  (1, 'Australian Terrier-Lowchen Mix', 'female'),
#  (1, 'Australian Terrier-Parson Russell Terrier Mix', 'male'),
#  (1, 'Australian Terrier-Rottweiler Mix', 'male'),
#  (1, 'Australian Terrier-Yorkshire Terrier Mix', 'male'),
#  (1, 'Barbet', 'female'),
#  (1, 'Barbet', 'male'),
#  (10, 'Basenji', 'female'),
#  (17, 'Basenji', 'male'),
#  (1, 'Basenji- Mix', 'female'),
#  (1, 'Basenji-American Staffordshire Terrier Mix', 'female'),
#  (1, 'Basenji-American Water Spaniel Mix', 'female'),
#  (1, 'Basenji-Australian Cattle Dog Mix', 'female'),
#  (1, 'Basenji-Beagle Mix', 'female'),
#  (1, 'Basenji-Cardigan Welsh Corgi Mix', 'male'),
#  (1, 'Basenji-English Springer Spaniel Mix', 'male'),
#  (1, 'Basenji-German Shepherd Dog Mix', 'male'),
#  (1, 'Basenji-German Shorthaired Pointer Mix', 'male'),
#  (1, 'Basenji-Manchester Terrier Mix', 'male'),
#  (1, 'Basenji-Russell Terrier Mix', 'female'),
#  (1, 'Basenji-Shiba Inu Mix', 'female'),
#  (1, 'Basenji-Siberian Husky Mix', 'female'),
#  (1, 'Basenji-Whippet Mix', 'male'),
#  (48, 'Basset Hound', 'female'),
#  (55, 'Basset Hound', 'male'),
#  (1, 'Basset Hound- Mix', 'male'),
#  (1, 'Basset Hound-Airedale Terrier Mix', 'male'),
#  (1, 'Basset Hound-American English Coonhound Mix', 'male'),
#  (1, 'Basset Hound-American Pit Bull Terrier Mix', 'female'),
#  (1, 'Basset Hound-American Pit Bull Terrier Mix', 'male'),
#  (1, 'Basset Hound-American Staffordshire Terrier Mix', 'female'),
#  (1, 'Basset Hound-Australian Cattle Dog Mix', 'female'),
#  (1, 'Basset Hound-Australian Shepherd Mix', 'male'),
#  (2, 'Basset Hound-Beagle Mix', 'female'),
#  (3, 'Basset Hound-Beagle Mix', 'male'),
#  (1, 'Basset Hound-Boston Terrier Mix', 'male'),
#  (1, 'Basset Hound-Cardigan Welsh Corgi Mix', 'male'),
#  (1, 'Basset Hound-Cocker Spaniel Mix', 'male'),
#  (1, 'Basset Hound-Dachshund Mix', 'female'),
#  (1, 'Basset Hound-German Shepherd Dog Mix', 'female'),
#  (1, 'Basset Hound-German Shepherd Dog Mix', 'male'),
#  (1, 'Basset Hound-Great Pyrenees Mix', 'female'),
#  (3, 'Basset Hound-Labrador Retriever Mix', 'female'),
#  (2, 'Basset Hound-Labrador Retriever Mix', 'male'),
#  (1, 'Basset Hound-Pembroke Welsh Corgi Mix', 'male'),
#  (1, 'Basset Hound-Pointer Mix', 'male'),
#  (1, 'Basset Hound-Poodle Mix', 'male'),
#  (1, 'Basset Hound-Rottweiler Mix', 'male'),
#  (1, 'Basset Hound-Russell Terrier Mix', 'female'),
#  (1, 'Basset Hound-Russell Terrier Mix', 'male'),
#  (1, 'Basset Hound-Staffordshire Bull Terrier Mix', 'male'),
#  (151, 'Beagle', 'female'),
#  (161, 'Beagle', 'male'),
#  (1, 'Beagle- Mix', 'female'),
#  (1, 'Beagle- Mix', 'male'),
#  (1, 'Beagle-American English Coonhound Mix', 'male'),
#  (1, 'Beagle-American Eskimo Dog Mix', 'female'),
#  (1, 'Beagle-American Eskimo Dog Mix', 'male'),
#  (1, 'Beagle-American Foxhound Mix', 'female'),
#  (1, 'Beagle-American Foxhound Mix', 'male'),
#  (3, 'Beagle-Australian Cattle Dog Mix', 'female'),
#  (1, 'Beagle-Australian Cattle Dog Mix', 'male'),
#  (4, 'Beagle-Basset Hound Mix', 'female'),
#  (2, 'Beagle-Basset Hound Mix', 'male'),
#  (5, 'Beagle-Bluetick Coonhound Mix', 'female'),
#  (6, 'Beagle-Border Collie Mix', 'female'),
#  (3, 'Beagle-Border Collie Mix', 'male'),
#  (1, 'Beagle-Border Terrier Mix', 'female'),
#  (1, 'Beagle-Boston Terrier Mix', 'female'),
#  (1, 'Beagle-Boston Terrier Mix', 'male'),
#  (1, 'Beagle-Boxer Mix', 'female'),
#  (1, 'Beagle-Bulldog Mix', 'female'),
#  (2, 'Beagle-Bulldog Mix', 'male'),
#  (2, 'Beagle-Cavalier King Charles Spaniel Mix', 'female'),
#  (1, 'Beagle-Cavalier King Charles Spaniel Mix', 'male'),
#  (1, 'Beagle-Chihuahua Mix', 'female'),
#  (2, 'Beagle-Chihuahua Mix', 'male'),
#  (1, 'Beagle-Chinese Shar-Pei Mix', 'male'),
#  (1, 'Beagle-Chow Chow Mix', 'female'),
#  (2, 'Beagle-Cocker Spaniel Mix', 'female'),
#  (1, 'Beagle-Cocker Spaniel Mix', 'male'),
#  (2, 'Beagle-Collie Mix', 'female'),
#  (9, 'Beagle-Dachshund Mix', 'female'),
#  (1, 'Beagle-Dachshund Mix', 'male'),
#  (3, 'Beagle-German Shepherd Dog Mix', 'female'),
#  (1, 'Beagle-Golden Retriever Mix', 'female'),
#  (2, 'Beagle-Golden Retriever Mix', 'male'),
#  (1, 'Beagle-Greyhound Mix', 'female'),
#  (4, 'Beagle-Jack Russell Terrier Mix', 'female'),
#  (1, 'Beagle-Jack Russell Terrier Mix', 'male'),
#  (10, 'Beagle-Labrador Retriever Mix', 'female'),
#  (10, 'Beagle-Labrador Retriever Mix', 'male'),
#  (1, 'Beagle-Miniature Schnauzer Mix', 'female'),
#  (1, 'Beagle-Parson Russell Terrier Mix', 'female'),
#  (2, 'Beagle-Parson Russell Terrier Mix', 'male'),
#  (1, 'Beagle-Pekingese Mix', 'female'),
#  (2, 'Beagle-Pekingese Mix', 'male'),
#  (2, 'Beagle-Pointer Mix', 'male'),
#  (1, 'Beagle-Poodle Mix', 'female'),
#  (1, 'Beagle-Poodle Mix', 'male'),
#  (3, 'Beagle-Pug Mix', 'female'),
#  (5, 'Beagle-Pug Mix', 'male'),
#  (2, 'Beagle-Rat Terrier Mix', 'female'),
#  (2, 'Beagle-Rat Terrier Mix', 'male'),
#  (2, 'Beagle-Russell Terrier Mix', 'female'),
#  (7, 'Beagle-Russell Terrier Mix', 'male'),
#  (1, 'Beagle-Schipperke Mix', 'female'),
#  (1, 'Beagle-Shetland Sheepdog Mix', 'female'),
#  (2, 'Beagle-Siberian Husky Mix', 'female'),
#  (1, 'Beagle-Smooth Fox Terrier Mix', 'male'),
#  (1, 'Beagle-Toy Fox Terrier Mix', 'female'),
#  (2, 'Beagle-Treeing Walker Coonhound Mix', 'male'),
#  (1, 'Beagle-Whippet Mix', 'female'),
#  (5, 'Beaglier', 'female'),
#  (11, 'Beaglier', 'male'),
#  (20, 'Bearded Collie', 'female'),
#  (11, 'Bearded Collie', 'male'),
#  (1, 'Bearded Collie-Beagle Mix', 'male'),
#  (1, 'Bearded Collie-Bernese Mountain Dog Mix', 'female'),
#  (1, 'Bearded Collie-Border Collie Mix', 'female'),
#  (1, 'Bearded Collie-Border Collie Mix', 'male'),
#  (1, 'Bearded Collie-Labrador Retriever Mix', 'female'),
#  (1, 'Bearded Collie-Shih Tzu Mix', 'female'),
#  (1, 'Bearded Collie-Soft Coated Wheaten Terrier Mix', 'female'),
#  (1, 'Bearded Collie-Tibetan Terrier Mix', 'male'),
#  (6, 'Beauceron', 'female'),
#  (7, 'Beauceron', 'male'),
#  (1, 'Beauceron-Rottweiler Mix', 'male'),
#  (7, 'Bedlington Terrier', 'female'),
#  (5, 'Bedlington Terrier', 'male'),
#  (1, 'Bedlington Terrier-Belgian Laekenois Mix', 'male'),
#  (1, 'Bedlington Terrier-Whippet Mix', 'male'),
#  (1, 'Belgian Laekenois', 'male'),
#  (51, 'Belgian Malinois', 'female'),
#  (45, 'Belgian Malinois', 'male'),
#  (1, 'Belgian Malinois- Mix', 'male'),
#  (1, 'Belgian Malinois-American Staffordshire Terrier Mix', 'male'),
#  (1, 'Belgian Malinois-Belgian Tervuren Mix', 'female'),
#  (1, 'Belgian Malinois-Border Collie Mix', 'female'),
#  (1, 'Belgian Malinois-Chinese Shar-Pei Mix', 'female'),
#  (1, 'Belgian Malinois-Chow Chow Mix', 'female'),
#  (1, 'Belgian Malinois-Chow Chow Mix', 'male'),
#  (1, 'Belgian Malinois-Dutch Shepherd Mix', 'female'),
#  (1, 'Belgian Malinois-Dutch Shepherd Mix', 'male'),
#  (1, 'Belgian Malinois-German Shepherd Dog Mix', 'female'),
#  (2, 'Belgian Malinois-German Shepherd Dog Mix', 'male'),
#  (2, 'Belgian Malinois-Labrador Retriever Mix', 'female'),
#  (2, 'Belgian Malinois-Labrador Retriever Mix', 'male'),
#  (2, 'Belgian Malinois-Siberian Husky Mix', 'female'),
#  (5, 'Belgian Sheepdog', 'female'),
#  (10, 'Belgian Sheepdog', 'male'),
#  (1, 'Belgian Sheepdog- Mix', 'female'),
#  (1, 'Belgian Sheepdog-Border Collie Mix', 'male'),
#  (1, 'Belgian Sheepdog-Chow Chow Mix', 'female'),
#  (1, 'Belgian Sheepdog-Dutch Shepherd Mix', 'female'),
#  (1, 'Belgian Sheepdog-German Shepherd Dog Mix', 'female'),
#  (1, 'Belgian Sheepdog-Golden Retriever Mix', 'female'),
#  (1, 'Belgian Sheepdog-Lhasa Apso Mix', 'male'),
#  (26, 'Belgian Tervuren', 'female'),
#  (9, 'Belgian Tervuren', 'male'),
#  (1, 'Belgian Tervuren-Basenji Mix', 'male'),
#  (1, 'Belgian Tervuren-Border Collie Mix', 'female'),
#  (1, 'Belgian Tervuren-Boston Terrier Mix', 'female'),
#  (1, 'Belgian Tervuren-Whippet Mix', 'male'),
#  (1, 'Bergamasco-Old English Sheepdog Mix', 'female'),
#  (4, 'Berger Picard', 'female'),
#  (4, 'Berger Picard', 'male'),
#  (50, 'Bernese Mountain Dog', 'female'),
#  (48, 'Bernese Mountain Dog', 'male'),
#  (2, 'Bernese Mountain Dog-Border Collie Mix', 'male'),
#  (1, 'Bernese Mountain Dog-Chow Chow Mix', 'male'),
#  (1, 'Bernese Mountain Dog-English Springer Spaniel Mix', 'female'),
#  (2, 'Bernese Mountain Dog-Golden Retriever Mix', 'female'),
#  (2, 'Bernese Mountain Dog-Golden Retriever Mix', 'male'),
#  (3, 'Bernese Mountain Dog-Great Pyrenees Mix', 'female'),
#  (1, 'Bernese Mountain Dog-Great Pyrenees Mix', 'male'),
#  (1, 'Bernese Mountain Dog-Greater Swiss Mountain Dog Mix', 'female'),
#  (2, 'Bernese Mountain Dog-Labrador Retriever Mix', 'female'),
#  (1, 'Bernese Mountain Dog-Labrador Retriever Mix', 'male'),
#  (3, 'Bernese Mountain Dog-Poodle Mix', 'male'),
#  (1, 'Bernese Mountain Dog-Rottweiler Mix', 'female'),
#  (1, 'Bernese Mountain Dog-Rottweiler Mix', 'male'),
#  (1, 'Bernese Mountain Dog-Standard Poodle Mix', 'male'),
#  (77, 'Bichon Frise', 'female'),
#  (89, 'Bichon Frise', 'male'),
#  (1, 'Bichon Frise- Mix', 'male'),
#  (1, 'Bichon Frise-American Eskimo Dog Mix', 'female'),
#  (9, 'Bichon Frise-Cavalier King Charles Spaniel Mix', 'female'),
#  (7, 'Bichon Frise-Cavalier King Charles Spaniel Mix', 'male'),
#  (1, 'Bichon Frise-Chinese Crested Mix', 'male'),
#  (1, 'Bichon Frise-Cocker Spaniel Mix', 'female'),
#  (1, 'Bichon Frise-Cocker Spaniel Mix', 'male'),
#  (1, 'Bichon Frise-Golden Retriever Mix', 'male'),
#  (1, 'Bichon Frise-Havanese Mix', 'male'),
#  (1, 'Bichon Frise-Jack Russell Terrier Mix', 'male'),
#  (1, 'Bichon Frise-Lhasa Apso Mix', 'female'),
#  (3, 'Bichon Frise-Lhasa Apso Mix', 'male'),
#  (1, 'Bichon Frise-Maltese Mix', 'female'),
#  (4, 'Bichon Frise-Maltese Mix', 'male'),
#  (1, 'Bichon Frise-Miniature Schnauzer Mix', 'male'),
#  (1, 'Bichon Frise-Pomeranian Mix', 'male'),
#  (17, 'Bichon Frise-Poodle Mix', 'female'),
#  (22, 'Bichon Frise-Poodle Mix', 'male'),
#  (11, 'Bichon Frise-Shih Tzu Mix', 'female'),
#  (16, 'Bichon Frise-Shih Tzu Mix', 'male'),
#  (2, 'Bichon Frise-West Highland White Terrier Mix', 'male'),
#  (4, 'Bichon Frise-Yorkshire Terrier Mix', 'female'),
#  (1, 'Bichon Frise-Yorkshire Terrier Mix', 'male'),
#  (4, 'Black and Tan Coonhound', 'female'),
#  (3, 'Black and Tan Coonhound', 'male'),
#  (1, 'Black and Tan Coonhound- Mix', 'female'),
#  (1, 'Black and Tan Coonhound-Beagle Mix', 'female'),
#  (1, 'Black and Tan Coonhound-German Shepherd Dog Mix', 'female'),
#  (1, 'Black and Tan Coonhound-Golden Retriever Mix', 'female'),
#  (1, 'Black and Tan Coonhound-Labrador Retriever Mix', 'female'),
#  (1, 'Black and Tan Coonhound-Labrador Retriever Mix', 'male'),
#  (1, 'Black and Tan Coonhound-Plott Mix', 'female'),
#  (6, 'Black Russian Terrier', 'female'),
#  (4, 'Black Russian Terrier', 'male'),
#  (1, 'Bloodhound', 'female'),
#  (7, 'Bloodhound', 'male'),
#  (1, 'Bloodhound-Beagle Mix', 'male'),
#  (3, 'Bloodhound-Black and Tan Coonhound Mix', 'female'),
#  (1, 'Bloodhound-Bull Terrier Mix', 'female'),
#  (1, 'Bloodhound-Irish Setter Mix', 'male'),
#  (2, 'Bloodhound-Labrador Retriever Mix', 'female'),
#  (2, 'Bloodhound-Labrador Retriever Mix', 'male'),
#  (5, 'Bluetick Coonhound', 'female'),
#  (8, 'Bluetick Coonhound', 'male'),
#  (2, 'Bluetick Coonhound-Beagle Mix', 'female'),
#  (1, 'Bluetick Coonhound-German Shorthaired Pointer Mix', 'female'),
#  (1, 'Bluetick Coonhound-Jack Russell Terrier Mix', 'male'),
#  (1, 'Bluetick Coonhound-Pointer Mix', 'female'),
#  (1, 'Bluetick Coonhound-Rottweiler Mix', 'female'),
#  (1, 'Bluetick Coonhound-Treeing Walker Coonhound Mix', 'male'),
#  (4, 'Boerboel', 'female'),
#  (5, 'Boerboel', 'male'),
#  (3, 'Bolognese', 'female'),
#  (2, 'Bolognese', 'male'),
#  (328, 'Border Collie', 'female'),
#  (316, 'Border Collie', 'male'),
#  (5, 'Border Collie- Mix', 'female'),
#  (2, 'Border Collie- Mix', 'male'),
#  (1, 'Border Collie-Affenpinscher Mix', 'male'),
#  (1, 'Border Collie-Akita Mix', 'female'),
#  (2, 'Border Collie-American Eskimo Dog Mix', 'male'),
#  (1, 'Border Collie-American Foxhound Mix', 'male'),
#  (4, 'Border Collie-American Pit Bull Terrier Mix', 'female'),
#  (1, 'Border Collie-American Staffordshire Terrier Mix', 'female'),
#  (18, 'Border Collie-Australian Cattle Dog Mix', 'female'),
#  (16, 'Border Collie-Australian Cattle Dog Mix', 'male'),
#  (4, 'Border Collie-Australian Kelpie Mix', 'male'),
#  (20, 'Border Collie-Australian Shepherd Mix', 'female'),
#  (26, 'Border Collie-Australian Shepherd Mix', 'male'),
#  (2, 'Border Collie-Beagle Mix', 'female'),
#  (2, 'Border Collie-Bearded Collie Mix', 'female'),
#  (2, 'Border Collie-Bearded Collie Mix', 'male'),
#  (1, 'Border Collie-Beauceron Mix', 'male'),
#  (1, 'Border Collie-Belgian Sheepdog Mix', 'female'),
#  (1, 'Border Collie-Belgian Sheepdog Mix', 'male'),
#  (1, 'Border Collie-Belgian Tervuren Mix', 'male'),
#  (1, 'Border Collie-Bernese Mountain Dog Mix', 'female'),
#  (1, 'Border Collie-Bloodhound Mix', 'female'),
#  (3, 'Border Collie-Bluetick Coonhound Mix', 'female'),
#  (1, 'Border Collie-Bluetick Coonhound Mix', 'male'),
#  (1, 'Border Collie-Borzoi Mix', 'male'),
#  (1, 'Border Collie-Boxer Mix', 'female'),
#  (1, 'Border Collie-Boxer Mix', 'male'),
#  (3, 'Border Collie-Brittany Mix', 'female'),
#  (1, 'Border Collie-Bull Terrier Mix', 'male'),
#  (1, 'Border Collie-Cavalier King Charles Spaniel Mix', 'male'),
#  (1, 'Border Collie-Chow Chow Mix', 'female'),
#  (1, 'Border Collie-Chow Chow Mix', 'male'),
#  (4, 'Border Collie-Cocker Spaniel Mix', 'female'),
#  (3, 'Border Collie-Collie Mix', 'female'),
#  (1, 'Border Collie-Collie Mix', 'male'),
#  (2, 'Border Collie-Dalmatian Mix', 'female'),
#  (2, 'Border Collie-Dalmatian Mix', 'male'),
#  (1, 'Border Collie-English Cocker Spaniel Mix', 'female'),
#  (1, 'Border Collie-English Setter Mix', 'male'),
#  (4, 'Border Collie-English Springer Spaniel Mix', 'female'),
#  (5, 'Border Collie-English Springer Spaniel Mix', 'male'),
#  (2, 'Border Collie-Field Spaniel Mix', 'female'),
#  (2, 'Border Collie-Flat-Coated Retriever Mix', 'female'),
#  (4, 'Border Collie-Flat-Coated Retriever Mix', 'male'),
#  (10, 'Border Collie-German Shepherd Dog Mix', 'female'),
#  (8, 'Border Collie-German Shepherd Dog Mix', 'male'),
#  (1, 'Border Collie-German Shorthaired Pointer Mix', 'male'),
#  (8, 'Border Collie-Golden Retriever Mix', 'female'),
#  (6, 'Border Collie-Golden Retriever Mix', 'male'),
#  (2, 'Border Collie-Great Dane Mix', 'male'),
#  (1, 'Border Collie-Great Pyrenees Mix', 'female'),
#  (2, 'Border Collie-Great Pyrenees Mix', 'male'),
#  (6, 'Border Collie-Greyhound Mix', 'male'),
#  (1, 'Border Collie-Icelandic Sheepdog Mix', 'female'),
#  (2, 'Border Collie-Irish Setter Mix', 'male'),
#  (1, 'Border Collie-Irish Water Spaniel Mix', 'female'),
#  (1, 'Border Collie-Jack Russell Terrier Mix', 'male'),
#  (1, 'Border Collie-Keeshond Mix', 'female'),
#  (1, 'Border Collie-Kooikerhondje Mix', 'male'),
#  (37, 'Border Collie-Labrador Retriever Mix', 'female'),
#  (24, 'Border Collie-Labrador Retriever Mix', 'male'),
#  (1, 'Border Collie-Lancashire Heeler Mix', 'female'),
#  (1, 'Border Collie-Miniature Australian Shepherd Mix', 'female'),
#  (1, 'Border Collie-Miniature Pinscher Mix', 'male'),
#  (1, 'Border Collie-Newfoundland Mix', 'female'),
#  (3, 'Border Collie-Newfoundland Mix', 'male'),
#  (1, 'Border Collie-Parson Russell Terrier Mix', 'female'),
#  (1, 'Border Collie-Pembroke Welsh Corgi Mix', 'female'),
#  (3, 'Border Collie-Pembroke Welsh Corgi Mix', 'male'),
#  (1, 'Border Collie-Pointer Mix', 'male'),
#  (1, 'Border Collie-Pomeranian Mix', 'female'),
#  (1, 'Border Collie-Pomeranian Mix', 'male'),
#  (2, 'Border Collie-Poodle Mix', 'female'),
#  (1, 'Border Collie-Rhodesian Ridgeback Mix', 'female'),
#  (2, 'Border Collie-Rottweiler Mix', 'male'),
#  (2, 'Border Collie-Saluki Mix', 'male'),
#  (3, 'Border Collie-Shetland Sheepdog Mix', 'female'),
#  (3, 'Border Collie-Shetland Sheepdog Mix', 'male'),
#  (7, 'Border Collie-Siberian Husky Mix', 'female'),
#  (6, 'Border Collie-Siberian Husky Mix', 'male'),
#  (1, 'Border Collie-Soft Coated Wheaten Terrier Mix', 'female'),
#  (2, 'Border Collie-Staffordshire Bull Terrier Mix', 'female'),
#  (1, 'Border Collie-Staffordshire Bull Terrier Mix', 'male'),
#  (1, 'Border Collie-Standard Poodle Mix', 'male'),
#  (1, 'Border Collie-Standard Schnauzer Mix', 'female'),
#  (1, 'Border Collie-Welsh Springer Spaniel Mix', 'female'),
#  (1, 'Border Collie-West Highland White Terrier Mix', 'male'),
#  (2, 'Border Collie-Whippet Mix', 'female'),
#  (2, 'Border Collie-Whippet Mix', 'male'),
#  (1, 'Border Collie-Wire Fox Terrier Mix', 'female'),
#  (32, 'Border Terrier', 'female'),
#  (47, 'Border Terrier', 'male'),
#  (2, 'Border Terrier- Mix', 'female'),
#  (1, 'Border Terrier-Beagle Mix', 'female'),
#  (1, 'Border Terrier-Bernese Mountain Dog Mix', 'male'),
#  (1, 'Border Terrier-Cairn Terrier Mix', 'female'),
#  (1, 'Border Terrier-Dachshund Mix', 'male'),
#  (1, 'Border Terrier-English Cocker Spaniel Mix', 'male'),
#  (1, 'Border Terrier-Golden Retriever Mix', 'female'),
#  (3, 'Border Terrier-Lakeland Terrier Mix', 'male'),
#  (2, 'Border Terrier-Parson Russell Terrier Mix', 'female'),
#  (1, 'Border Terrier-Parson Russell Terrier Mix', 'male'),
#  (1, 'Border Terrier-Poodle Mix', 'male'),
#  (1, 'Border Terrier-Pug Mix', 'male'),
#  (1, 'Border Terrier-Russell Terrier Mix', 'male'),
#  (1, 'Border Terrier-Shih Tzu Mix', 'male'),
#  (1, 'Border Terrier-Staffordshire Bull Terrier Mix', 'male'),
#  (1, 'Border Terrier-Standard Schnauzer Mix', 'female'),
#  (1, 'Border Terrier-West Highland White Terrier Mix', 'female'),
#  (5, 'Borzoi', 'female'),
#  (5, 'Borzoi', 'male'),
#  (2, 'Borzoi-Whippet Mix', 'female'),
#  (1, 'Borzoi-Whippet Mix', 'male'),
#  (103, 'Boston Terrier', 'female'),
#  (124, 'Boston Terrier', 'male'),
#  (1, 'Boston Terrier-American Pit Bull Terrier Mix', 'male'),
#  (1, 'Boston Terrier-American Staffordshire Terrier Mix', 'male'),
#  (2, 'Boston Terrier-Beagle Mix', 'female'),
#  (2, 'Boston Terrier-Bulldog Mix', 'male'),
#  (4, 'Boston Terrier-Chihuahua Mix', 'female'),
#  (1, 'Boston Terrier-Dachshund Mix', 'female'),
#  (1, 'Boston Terrier-Danish-Swedish Farmdog Mix', 'male'),
#  (1, 'Boston Terrier-Doberman Pinscher Mix', 'male'),
#  (5, 'Boston Terrier-French Bulldog Mix', 'female'),
#  (5, 'Boston Terrier-French Bulldog Mix', 'male'),
#  (1, 'Boston Terrier-Labrador Retriever Mix', 'female'),
#  (1, 'Boston Terrier-Pomeranian Mix', 'female'),
#  (1, 'Boston Terrier-Pomeranian Mix', 'male'),
#  (2, 'Boston Terrier-Pug Mix', 'female'),
#  (1, 'Boston Terrier-Pug Mix', 'male'),
#  (1, 'Boston Terrier-Rat Terrier Mix', 'male'),
#  (1, 'Boston Terrier-Russell Terrier Mix', 'male'),
#  (29, 'Bouvier des Flandres', 'female'),
#  (17, 'Bouvier des Flandres', 'male'),
#  (1, 'Bouvier des Flandres-Airedale Terrier Mix', 'male'),
#  (1, 'Bouvier des Flandres-Standard Poodle Mix', 'male'),
#  (189, 'Boxer', 'female'),
#  (237, 'Boxer', 'male'),
#  (1, 'Boxer- Mix', 'female'),
#  (1, 'Boxer- Mix', 'male'),
#  (1, 'Boxer-Akita Mix', 'female'),
#  (1, 'Boxer-Akita Mix', 'male'),
#  (1, 'Boxer-American Foxhound Mix', 'male'),
#  (9, 'Boxer-American Pit Bull Terrier Mix', 'female'),
#  (7, 'Boxer-American Pit Bull Terrier Mix', 'male'),
#  (1, 'Boxer-American Staffordshire Terrier Mix', 'female'),
#  (6, 'Boxer-American Staffordshire Terrier Mix', 'male'),
#  (1, 'Boxer-Australian Cattle Dog Mix', 'female'),
#  (1, 'Boxer-Australian Cattle Dog Mix', 'male'),
#  (1, 'Boxer-Australian Shepherd Mix', 'male'),
#  (1, 'Boxer-Bloodhound Mix', 'female'),
#  (1, 'Boxer-Bloodhound Mix', 'male'),
#  (1, 'Boxer-Border Collie Mix', 'female'),
#  (1, 'Boxer-Border Collie Mix', 'male'),
#  (2, 'Boxer-Boston Terrier Mix', 'male'),
#  (1, 'Boxer-Bull Terrier Mix', 'female'),
#  (1, 'Boxer-Bull Terrier Mix', 'male'),
#  (4, 'Boxer-Bulldog Mix', 'female'),
#  (1, 'Boxer-Bulldog Mix', 'male'),
#  (2, 'Boxer-Bullmastiff Mix', 'male'),
#  (1, 'Boxer-Cocker Spaniel Mix', 'male'),
#  (1, 'Boxer-Dachshund Mix', 'female'),
#  (1, 'Boxer-Dalmatian Mix', 'female'),
#  (1, 'Boxer-Dalmatian Mix', 'male'),
#  (1, 'Boxer-Doberman Pinscher Mix', 'male'),
#  (2, 'Boxer-Dutch Shepherd Mix', 'female'),
#  (1, 'Boxer-English Foxhound Mix', 'female'),
#  (1, 'Boxer-English Springer Spaniel Mix', 'male'),
#  (5, 'Boxer-German Shepherd Dog Mix', 'female'),
#  (2, 'Boxer-German Shepherd Dog Mix', 'male'),
#  (1, 'Boxer-Golden Retriever Mix', 'male'),
#  (1, 'Boxer-Great Dane Mix', 'male'),
#  (1, 'Boxer-Great Pyrenees Mix', 'female'),
#  (1, 'Boxer-Greyhound Mix', 'female'),
#  (1, 'Boxer-Ibizan Hound Mix', 'male'),
#  (1, 'Boxer-Jindo Mix', 'female'),
#  (1, 'Boxer-Jindo Mix', 'male'),
#  (14, 'Boxer-Labrador Retriever Mix', 'female'),
#  (16, 'Boxer-Labrador Retriever Mix', 'male'),
#  (1, 'Boxer-Manchester Terrier Mix', 'male'),
#  (2, 'Boxer-Mastiff Mix', 'female'),
#  (1, 'Boxer-Mastiff Mix', 'male'),
#  (1, 'Boxer-Poodle Mix', 'male'),
#  (1, 'Boxer-Pug Mix', 'female'),
#  (1, 'Boxer-Redbone Coonhound Mix', 'male'),
#  (2, 'Boxer-Rhodesian Ridgeback Mix', 'female'),
#  (2, 'Boxer-Rhodesian Ridgeback Mix', 'male'),
#  (1, 'Boxer-Rottweiler Mix', 'male'),
#  (1, 'Boxer-Russell Terrier Mix', 'male'),
#  (2, 'Boxer-Siberian Husky Mix', 'female'),
#  (1, 'Boxer-St. Bernard Mix', 'male'),
#  (2, 'Boxer-Staffordshire Bull Terrier Mix', 'female'),
#  (1, 'Boxer-Staffordshire Bull Terrier Mix', 'male'),
#  (1, 'Boxer-Treeing Walker Coonhound Mix', 'female'),
#  (2, 'Boxer-Vizsla Mix', 'male'),
#  (1, 'Boxer-Weimaraner Mix', 'male'),
#  (5, 'Boykin Spaniel', 'female'),
#  (5, 'Boykin Spaniel', 'male'),
#  (1, 'Boykin Spaniel- Mix', 'male'),
#  (1, 'Boykin Spaniel-Deutscher Wachtelhund Mix', 'male'),
#  (1, 'Boykin Spaniel-English Cocker Spaniel Mix', 'female'),
#  (1, 'Boykin Spaniel-Irish Setter Mix', 'male'),
#  (1, 'Braque du Bourbonnais', 'male'),
#  (9, 'Briard', 'female'),
#  (8, 'Briard', 'male'),
#  (44, 'Brittany', 'female'),
#  (49, 'Brittany', 'male'),
#  (1, 'Brittany-Basset Hound Mix', 'female'),
#  (1, 'Brittany-Border Collie Mix', 'female'),
#  (2, 'Brittany-English Springer Spaniel Mix', 'male'),
#  (1, 'Brittany-German Shepherd Dog Mix', 'female'),
#  (3, 'Brittany-German Shorthaired Pointer Mix', 'male'),
#  (1, 'Brittany-Golden Retriever Mix', 'male'),
#  (1, 'Brittany-Irish Setter Mix', 'female'),
#  (2, 'Brittany-Labrador Retriever Mix', 'male'),
#  (1, 'Brittany-Pekingese Mix', 'female'),
#  (1, 'Brittany-Pointer Mix', 'male'),
#  (1, 'Brittany-Poodle Mix', 'female'),
#  (1, 'Brittany-Siberian Husky Mix', 'male'),
#  (5, 'Brussels Griffon', 'female'),
#  (23, 'Brussels Griffon', 'male'),
#  (1, 'Brussels Griffon-Border Terrier Mix', 'female'),
#  (1, 'Brussels Griffon-Poodle Mix', 'male'),
#  (2, 'Brussels Griffon-Pug Mix', 'male'),
#  (1, 'Brussels Griffon-Shih Tzu Mix', 'male'),
#  (3, 'Bugg', 'female'),
#  (11, 'Bugg', 'male'),
#  (24, 'Bull Terrier', 'female'),
#  (21, 'Bull Terrier', 'male'),
#  (1, 'Bull Terrier-American Foxhound Mix', 'male'),
#  (1, 'Bull Terrier-American Staffordshire Terrier Mix', 'female'),
#  (1, 'Bull Terrier-Boxer Mix', 'female'),
#  (3, 'Bull Terrier-Labrador Retriever Mix', 'male'),
#  (2, 'Bull Terrier-Staffordshire Bull Terrier Mix', 'female'),
#  (2, 'Bull Terrier-Whippet Mix', 'female'),
#  (9, 'BullBoxer', 'female'),
#  (10, 'BullBoxer', 'male'),
#  (100, 'Bulldog', 'female'),
#  (106, 'Bulldog', 'male'),
#  (1, 'Bulldog-American Pit Bull Terrier Mix', 'female'),
#  (2, 'Bulldog-American Pit Bull Terrier Mix', 'male'),
#  (1, 'Bulldog-American Staffordshire Terrier Mix', 'male'),
#  (1, 'Bulldog-Basset Hound Mix', 'male'),
#  (1, 'Bulldog-Beagle Mix', 'female'),
#  (2, 'Bulldog-Beagle Mix', 'male'),
#  (1, 'Bulldog-Boston Terrier Mix', 'male'),
#  (3, 'Bulldog-Boxer Mix', 'female'),
#  (2, 'Bulldog-Boxer Mix', 'male'),
#  (2, 'Bulldog-Bullmastiff Mix', 'male'),
#  (1, 'Bulldog-Chesapeake Bay Retriever Mix', 'female'),
#  (1, 'Bulldog-Cocker Spaniel Mix', 'male'),
#  (1, 'Bulldog-Dogo Argentino Mix', 'female'),
#  (1, 'Bulldog-French Bulldog Mix', 'male'),
#  (1, 'Bulldog-German Shepherd Dog Mix', 'female'),
#  (1, 'Bulldog-German Shorthaired Pointer Mix', 'female'),
#  (1, 'Bulldog-Great Dane Mix', 'male'),
#  (1, 'Bulldog-Labrador Retriever Mix', 'male'),
#  (1, 'Bulldog-Mastiff Mix', 'female'),
#  (1, 'Bulldog-Neapolitan Mastiff Mix', 'male'),
#  (1, 'Bulldog-Pug Mix', 'female'),
#  (1, 'Bulldog-Pug Mix', 'male'),
#  (1, 'Bulldog-Rhodesian Ridgeback Mix', 'male'),
#  (1, 'Bulldog-Rottweiler Mix', 'male'),
#  (1, 'Bulldog-Wirehaired Pointing Griffon Mix', 'male'),
#  (16, 'Bullmastiff', 'female'),
#  (13, 'Bullmastiff', 'male'),
#  (1, 'Bullmastiff- Mix', 'female'),
#  (1, 'Bullmastiff-American Pit Bull Terrier Mix', 'male'),
#  (1, 'Bullmastiff-American Staffordshire Terrier Mix', 'female'),
#  (1, 'Bullmastiff-Border Collie Mix', 'male'),
#  (1, 'Bullmastiff-Boxer Mix', 'female'),
#  (1, 'Bullmastiff-Bull Terrier Mix', 'female'),
#  (1, 'Bullmastiff-Bulldog Mix', 'male'),
#  (1, 'Bullmastiff-Chinese Shar-Pei Mix', 'female'),
#  (1, 'Bullmastiff-Chinese Shar-Pei Mix', 'male'),
#  (1, 'Bullmastiff-Dogue de Bordeaux Mix', 'male'),
#  (1, 'Bullmastiff-German Shepherd Dog Mix', 'female'),
#  (2, 'Bullmastiff-Labrador Retriever Mix', 'female'),
#  (1, 'Bullmastiff-Redbone Coonhound Mix', 'male'),
#  (4, 'Bullmastiff-Staffordshire Bull Terrier Mix', 'male'),
#  (35, 'Cairn Terrier', 'female'),
#  (47, 'Cairn Terrier', 'male'),
#  (1, 'Cairn Terrier-Airedale Terrier Mix', 'male'),
#  (1, 'Cairn Terrier-Australian Terrier Mix', 'female'),
#  (1, 'Cairn Terrier-Cocker Spaniel Mix', 'female'),
#  (1, 'Cairn Terrier-German Shepherd Dog Mix', 'male'),
#  (1, 'Cairn Terrier-Jack Russell Terrier Mix', 'female'),
#  (1, 'Cairn Terrier-Lhasa Apso Mix', 'female'),
#  (1, 'Cairn Terrier-Pomeranian Mix', 'female'),
#  (1, 'Cairn Terrier-Poodle Mix', 'male'),
#  (1, 'Cairn Terrier-Russell Terrier Mix', 'male'),
#  (1, 'Cairn Terrier-Shih Tzu Mix', 'female'),
#  (1, 'Cairn Terrier-Shih Tzu Mix', 'male'),
#  (1, 'Cairn Terrier-Smooth Fox Terrier Mix', 'male'),
#  (1, 'Cairn Terrier-West Highland White Terrier Mix', 'female'),
#  (1, 'Cairn Terrier-West Highland White Terrier Mix', 'male'),
#  (1, 'Cairn Terrier-Yorkshire Terrier Mix', 'female'),
#  (1, 'Cairn Terrier-Yorkshire Terrier Mix', 'male'),
#  (8, 'Canaan Dog', 'female'),
#  (1, 'Canaan Dog', 'male'),
#  (1, 'Canaan Dog- Mix', 'female'),
#  (17, 'Cane Corso', 'female'),
#  (17, 'Cane Corso', 'male'),
#  (20, 'Cardigan Welsh Corgi', 'female'),
#  (19, 'Cardigan Welsh Corgi', 'male'),
#  (1, 'Cardigan Welsh Corgi-American Eskimo Dog Mix', 'female'),
#  (2, 'Cardigan Welsh Corgi-American Pit Bull Terrier Mix', 'male'),
#  (1, 'Cardigan Welsh Corgi-American Staffordshire Terrier Mix', 'female'),
#  (1, 'Cardigan Welsh Corgi-Australian Cattle Dog Mix', 'male'),
#  (1, 'Cardigan Welsh Corgi-Australian Shepherd Mix', 'male'),
#  (1, 'Cardigan Welsh Corgi-Beagle Mix', 'female'),
#  (1, 'Cardigan Welsh Corgi-Cairn Terrier Mix', 'female'),
#  (1, 'Cardigan Welsh Corgi-Catahoula Leopard Dog Mix', 'female'),
#  (3, 'Cardigan Welsh Corgi-German Shepherd Dog Mix', 'female'),
#  (1, 'Cardigan Welsh Corgi-Labrador Retriever Mix', 'male'),
#  (1, 'Cardigan Welsh Corgi-Lancashire Heeler Mix', 'female'),
#  (1, 'Cardigan Welsh Corgi-Pomeranian Mix', 'male'),
#  (1, 'Cardigan Welsh Corgi-Russell Terrier Mix', 'female'),
#  (1, 'Cardigan Welsh Corgi-Russell Terrier Mix', 'male'),
#  (1, 'Cardigan Welsh Corgi-Yorkshire Terrier Mix', 'female'),
#  (22, 'Catahoula Leopard Dog', 'female'),
#  (18, 'Catahoula Leopard Dog', 'male'),
#  (1, 'Catahoula Leopard Dog- Mix', 'female'),
#  (1, 'Catahoula Leopard Dog-American Leopard Hound Mix', 'female'),
#  (1, 'Catahoula Leopard Dog-American Pit Bull Terrier Mix', 'male'),
#  (2, 'Catahoula Leopard Dog-Australian Cattle Dog Mix', 'female'),
#  (4, 'Catahoula Leopard Dog-Australian Cattle Dog Mix', 'male'),
#  (2, 'Catahoula Leopard Dog-Australian Shepherd Mix', 'female'),
#  (2, 'Catahoula Leopard Dog-Bluetick Coonhound Mix', 'male'),
#  (1, 'Catahoula Leopard Dog-Border Collie Mix', 'female'),
#  (1, 'Catahoula Leopard Dog-Border Collie Mix', 'male'),
#  (1, 'Catahoula Leopard Dog-Boxer Mix', 'male'),
#  (1, 'Catahoula Leopard Dog-German Shepherd Dog Mix', 'male'),
#  (7, 'Catahoula Leopard Dog-Labrador Retriever Mix', 'female'),
#  (4, 'Catahoula Leopard Dog-Labrador Retriever Mix', 'male'),
#  (1, 'Catahoula Leopard Dog-Plott Mix', 'male'),
#  (1, 'Catahoula Leopard Dog-Pointer Mix', 'female'),
#  (1, 'Catahoula Leopard Dog-Rottweiler Mix', 'male'),
#  (1, 'Catahoula Leopard Dog-Shetland Sheepdog Mix', 'male'),
#  (1, 'Catahoula Leopard Dog-Siberian Husky Mix', 'female'),
#  (2, 'Caucasian Ovcharka', 'male'),
#  (93, 'Cavalier King Charles Spaniel', 'female'),
#  (104, 'Cavalier King Charles Spaniel', 'male'),
#  (1, 'Cavalier King Charles Spaniel-Australian Shepherd Mix', 'female'),
#  (1, 'Cavalier King Charles Spaniel-Beagle Mix', 'male'),
#  (10, 'Cavalier King Charles Spaniel-Bichon Frise Mix', 'female'),
#  (9, 'Cavalier King Charles Spaniel-Bichon Frise Mix', 'male'),
#  (2, 'Cavalier King Charles Spaniel-Cocker Spaniel Mix', 'female'),
#  (2, 'Cavalier King Charles Spaniel-Cocker Spaniel Mix', 'male'),
#  (2, 'Cavalier King Charles Spaniel-Coton de Tulear Mix', 'male'),
#  (1, 'Cavalier King Charles Spaniel-English Springer Spaniel Mix', 'male'),
#  (1, 'Cavalier King Charles Spaniel-Maltese Mix', 'male'),
#  (1, 'Cavalier King Charles Spaniel-Papillon Mix', 'male'),
#  (1, 'Cavalier King Charles Spaniel-Pekingese Mix', 'female'),
#  (1, 'Cavalier King Charles Spaniel-Pomeranian Mix', 'female'),
#  (16, 'Cavalier King Charles Spaniel-Poodle Mix', 'female'),
#  (15, 'Cavalier King Charles Spaniel-Poodle Mix', 'male'),
#  (1, 'Cavalier King Charles Spaniel-Shih Tzu Mix', 'male'),
#  (1, 'Cavalier King Charles Spaniel-Standard Poodle Mix', 'male'),
#  (1, 'Central Asian Shepherd Dog', 'female'),
#  (1, 'Central Asian Shepherd Dog-Golden Retriever Mix', 'female'),
#  (1, 'Cesky Terrier', 'female'),
#  (16, 'Chesapeake Bay Retriever', 'female'),
#  (15, 'Chesapeake Bay Retriever', 'male'),
#  (1, 'Chesapeake Bay Retriever-American Staffordshire Terrier Mix', 'male'),
#  (1, 'Chesapeake Bay Retriever-Beagle Mix', 'male'),
#  (1, 'Chesapeake Bay Retriever-German Shepherd Dog Mix', 'female'),
#  (4, 'Chesapeake Bay Retriever-Labrador Retriever Mix', 'male'),
#  (1, 'Chesapeake Bay Retriever-Shih Tzu Mix', 'male'),
#  (2, 'Chesapeake Bay Retriever-Siberian Husky Mix', 'male'),
#  (204, 'Chihuahua', 'female'),
#  (185, 'Chihuahua', 'male'),
#  (3, 'Chihuahua- Mix', 'female'),
#  (4, 'Chihuahua- Mix', 'male'),
#  (1, 'Chihuahua-Airedale Terrier Mix', 'female'),
#  ...]

# %% [markdown]
# Some database servers, including MySQL, allow you to use numbers in place of field names in the GROUP BY or ORDER BY fields to reduce the overall length of the queries.  I tend to avoid this abbreviated method of writing queries because I find it challenging to troubleshoot when you are writing complicated queries with many fields, but it does allow you to write queries faster.  To use this method, assign each field in your SELECT statement a number acording to the order the field appears in the SELECT statement.  In the following statement:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# ```
#
# test_name would be #1, Month would be #2, and Num_Completed_Tests would be #3.  You could then rewrite the query above to read:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# GROUP BY 1, 2
# ORDER BY 1 ASC, 2 ASC;
# ```
#
# **Question 2: Revise the query your wrote in Question 1 so that it uses only numbers in the GROUP BY and ORDER BY fields.**

# %% [markdown]
# ## The HAVING clause
#
# Just like you can query subsets of rows using the WHERE clause, you can query subsets of aggregated groups using the HAVING clause.  However, wheras the expression that follows a WHERE clause has to be applicable to each row of data in a column, the expression that follows a HAVING clause has to be applicable or computable using a group of data.
#
# If you wanted to examine the number of tests completed only during the winter holiday months of November and December, you would need to use a WHERE clause, because the month a test was completed in is recorded in each row.  Your query might look like this:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# WHERE MONTH(created_at)=11 OR MONTH(created_at)=12
# GROUP BY 1, 2
# ORDER BY 3 DESC;
# ```
# If you then wanted to output only the test-month pairs that had at least 20 records in them, you would add a HAVING clause, because the stipulation of at least 20 records only makes sense and is only computable at the aggregated group level:
#
# ```mySQL
# SELECT test_name, MONTH(created_at) AS Month, COUNT(created_at) AS Num_Completed_Tests
# FROM complete_tests
# WHERE MONTH(created_at)=11 OR MONTH(created_at)=12
# GROUP BY 1, 2
# HAVING COUNT(created_at)>=20
# ORDER BY 3 DESC;
# ```
#
# **Question 3: Revise the query your wrote in Question 2 so that it (1) excludes the NULL and empty string entries in the breed_group field, and (2) excludes any groups that don't have at least 1,000 distinct Dog_Guids in them.  Your result should contain 8 rows.  (HINT: sometimes empty strings are registered as non-NULL values.  You might want to include the following line somewhere in your query to exclude these values as well):**
#
# ```mySQL
# breed_group!=""
# ```

# %% [markdown]
# We will review several issues that can be tricky about using GROUP BY in your queries in the next lesson, but those issues will make more sense once you are sure you are comfortable with the basic functionality of the GROUP BY and HAVING clauses.
#
#
#
# ## Practice incorporating GROUP BY and HAVING into your own queries.
#
# **Question 4: Write a query that outputs the average number of tests completed and average mean inter-test-interval for every breed type, sorted by the average number of completed tests in descending order (popular hybrid should be the first row in your output).**

# %% [markdown]
# **Question 5: Write a query that outputs the average amount of time it took customers to complete each type of test where any individual reaction times over 6000 hours are excluded and only average reaction times that are greater than 0 seconds are included (your output should end up with 67 rows).**

# %% [markdown]
# **Question 6: Write a query that outputs the total number of unique User_Guids in each combination of State and ZIP code (postal code) in the United States, sorted first by state name in ascending alphabetical order, and second by total number of unique User_Guids in descending order (your first state should be AE and there should be 5043 rows in total in your output).**

# %% [markdown]
# **Question 7: Write a query that outputs the total number of unique User_Guids in each combination of State and ZIP code in the United States *that have at least 5 users*, sorted first by state name in ascending alphabetical order, and second by total number of unique User_Guids in descending order (your first state/ZIP code combination should be AZ/86303).**

# %% [markdown]
# <mark>**Be sure to watch the next video before beginning Exercise 6, the next set of MySQL exercises</mark>,** **and feel free to practice any other queries you wish below!**
